# %%
import numpy as np
import pandas as pd
import re

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# the dataset contains THREE YEARS of recorded incidents ("alarms") of broken fridges with some specific infos:
# * When the fridge breaks down this is reported in the computer system and the CMS company sends an ingeneer to fix it and they it asks the Supermarket to pay for the service (maybe its a good business in Colombia ;)
# * the original file has 150MB
# * 600.000 records from 2012-2015

# %% [markdown]
# The questions are:
# * If the company has details (data, logs etc) on all the "alarms" in the year 2012 - 2015, it wants to predicts how many alarms in each store in each month will happen in 2016?
# * why?
# * which shops has largest smallest number of alarms (maybe normalize per size of the shop)
# * what data would you suggest the manager to collect to make the dataser more complete
# * report and ask questions

# %% [markdown]
# Lets look at the data
# * Work Order Number ----------------------------------------- 12939001 (like a factura, work done was stored as a number)
# * Site Number -------------------------------------------------- A0052 (each store that company maintains has a number)
# * Site Type ---------------------------------------------- SUPERMARKET (type of store: Supermarket(big)/Convenience(small))
# * Date Created -------------------------------------- 02/02/2012 09:45 (date and time that the alarm occured)
# * Date Completed  ----------------------------------- 02/02/2012 21:10 (date and time that the alarm was silenced)
# * Provider Name  ------------------------------- CMS Solutions Limited (name of the maintenance company)
# * WO Current Status ---------------------------------------------- EOL (I dont remember)
# * Asset Category --------------------------------------- REFRIGERATION (type of asset, they also fix aircond, light etc)
# * Problem Type Name ---------- Fixture Critical Over Temperature Alarm (type of alarm)
# * Requested By ---------------------------- Urgent Refrigeration Alarm (priority of the alarm)
# * WO Priority ------------------------------------------- Standard SLA (for accountancy of the company)
# * Manufacturer ---------------------------------------------- LINDE AG (manufacturer of the asset that made the alarm)
# * Asset In-Service Date ----------------------------- 23/05/2012 05:00 (when the machine was first connected)
# * Level 1 Organization Name ------------------------------- Region S01 (the company divied the country into regions)
# * Site Zipcode ----------------------------------------------- CR0 4XT (postal code of the store - helps to locate it)
# * Sales Sq. Ft. ---------------------------------------------- 48409.0 (the size of the stor in square feet)
# * Asset Barcode ------------------------------------------ SSL00319496 (number of the assed (fridge), a label)
# * Client Product Name -------------------------------------------- NaN (dont remember)
# * Asset Type ---------------------------------------- REMOTE MULTIDECK (fridge can be open, closed, cabinet etc)
# * Asset Status ---------------------------------------------- Inactive (is the asset active today -time of generating dataset)

# %%
data = pd.read_csv("data/CPT_PREDICTIVE_PPM.csv",encoding='windows-1252')
data.head()
# Out:
#    Work Order Number Site Number    Site Type      Date Created  \
# 0           12904684       A0892  SUPERMARKET  01/02/2012 03:05
# 1           12904685       A0892  SUPERMARKET  01/02/2012 03:05
# 2           12904853       A0892  SUPERMARKET  01/02/2012 05:10
# 3           12927899       A0416  SUPERMARKET  01/02/2012 08:40
# 4           12932231       A0003  SUPERMARKET  01/02/2012 13:33
#
#      Date Completed                   Provider Name WO Current Status  \
# 0  01/02/2012 10:00  Space Engineering services LTD               EOL
# 1  01/02/2012 09:59  Space Engineering services LTD               EOL
# 2  01/02/2012 10:01  Space Engineering services LTD               EOL
# 3  02/02/2012 13:03           CMS Solutions Limited               EOL
# 4  08/02/2012 19:39           CMS Solutions Limited               EOL
#
#   Asset Category                        Problem Type Name  \
# 0  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 1  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 2  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 3  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                  Requested By   WO Priority            Manufacturer  \
# 0  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 1  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 2  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 3  Urgent Refrigeration Alarm  Standard SLA                   LINDE
# 4  Urgent Refrigeration Alarm  Standard SLA  RADFORD RETAIL SYSTEMS
#
#   Asset In-Service Date Level 1 Organization Name Site Zipcode  Sales Sq. Ft.  \
# 0      01/06/2011 15:19                Region N10     DN31 1UF        42639.0
# 1      01/06/2011 15:19                Region N10     DN31 1UF        42639.0
# 2      01/06/2011 15:19                Region N10     DN31 1UF        42639.0
# 3      01/08/2002 05:00                Region S01      BR4 0PU        13423.0
# 4      15/03/2009 04:00                Region S02     DA11 8JH        37870.0
#
#   Asset Barcode                  Client Product Name              Asset Type  \
# 0   SSL00567391           Frozen Food (-18C or less)  HALF GLASS DOOR & WELL
# 1   SSL00567398           Frozen Food (-18C or less)         FULL GLASS DOOR
# 2   SSL00567399           Frozen Food (-18C or less)         FULL GLASS DOOR
# 3   SSL00225160  Meat, Fish and Poultry (3C or less)        REMOTE MULTIDECK
# 4   SSL00583503                                  NaN         FULL GLASS DOOR
#
#   Asset Status
# 0   In Service
# 1   In Service
# 2   In Service
# 3   In Service
# 4     Scrapped

# %% [markdown]
# ### Organizar columnas para llamar posteriormente

# %%
col = []
for columns in data.columns:
    temp = columns.replace(" ","_")
    temp = temp.replace("-","_")
    temp = temp.replace(".","")
    temp = temp.lower()
    col.append(temp)
data.columns = col
data.head()
# Out:
#    work_order_number site_number    site_type      date_created  \
# 0           12904684       A0892  SUPERMARKET  01/02/2012 03:05
# 1           12904685       A0892  SUPERMARKET  01/02/2012 03:05
# 2           12904853       A0892  SUPERMARKET  01/02/2012 05:10
# 3           12927899       A0416  SUPERMARKET  01/02/2012 08:40
# 4           12932231       A0003  SUPERMARKET  01/02/2012 13:33
#
#      date_completed                   provider_name wo_current_status  \
# 0  01/02/2012 10:00  Space Engineering services LTD               EOL
# 1  01/02/2012 09:59  Space Engineering services LTD               EOL
# 2  01/02/2012 10:01  Space Engineering services LTD               EOL
# 3  02/02/2012 13:03           CMS Solutions Limited               EOL
# 4  08/02/2012 19:39           CMS Solutions Limited               EOL
#
#   asset_category                        problem_type_name  \
# 0  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 1  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 2  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 3  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                  requested_by   wo_priority            manufacturer  \
# 0  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 1  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 2  Urgent Refrigeration Alarm  Standard SLA                  CARTER
# 3  Urgent Refrigeration Alarm  Standard SLA                   LINDE
# 4  Urgent Refrigeration Alarm  Standard SLA  RADFORD RETAIL SYSTEMS
#
#   asset_in_service_date level_1_organization_name site_zipcode  sales_sq_ft  \
# 0      01/06/2011 15:19                Region N10     DN31 1UF      42639.0
# 1      01/06/2011 15:19                Region N10     DN31 1UF      42639.0
# 2      01/06/2011 15:19                Region N10     DN31 1UF      42639.0
# 3      01/08/2002 05:00                Region S01      BR4 0PU      13423.0
# 4      15/03/2009 04:00                Region S02     DA11 8JH      37870.0
#
#   asset_barcode                  client_product_name              asset_type  \
# 0   SSL00567391           Frozen Food (-18C or less)  HALF GLASS DOOR & WELL
# 1   SSL00567398           Frozen Food (-18C or less)         FULL GLASS DOOR
# 2   SSL00567399           Frozen Food (-18C or less)         FULL GLASS DOOR
# 3   SSL00225160  Meat, Fish and Poultry (3C or less)        REMOTE MULTIDECK
# 4   SSL00583503                                  NaN         FULL GLASS DOOR
#
#   asset_status
# 0   In Service
# 1   In Service
# 2   In Service
# 3   In Service
# 4     Scrapped

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609989 entries, 0 to 609988
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   work_order_number          609989 non-null  int64
#  1   site_number                609989 non-null  object
#  2   site_type                  609989 non-null  object
#  3   date_created               609989 non-null  object
#  4   date_completed             577602 non-null  object
#  5   provider_name              609989 non-null  object
#  6   wo_current_status          609989 non-null  object
#  7   asset_category             609989 non-null  object
#  8   problem_type_name          609989 non-null  object
#  9   requested_by               527644 non-null  object
#  10  wo_priority                609989 non-null  object
#  11  manufacturer               609989 non-null  object
#  12  asset_in_service_date      506751 non-null  object
#  13  level_1_organization_name  609989 non-null  object
#  14  site_zipcode               609989 non-null  object
#  15  sales_sq_ft                480451 non-null  float64
#  16  asset_barcode              609989 non-null  object
#  17  client_product_name        467909 non-null  object
#  18  asset_type                 527644 non-null  object
#  19  asset_status               526005 non-null  object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 93.1+ MB

# %% [markdown]
# Se observan 7 columnas incompletas, se revisan primero estas:

# %% [markdown]
# ### **date_created | date_completed | asset_in_service_date**

# %%
data.date_completed[0] # formato: Fecha más horas y minutos	YYYY-MM-DDThh:mmTZD
# Out:
# '01/02/2012 10:00'

# %%
print( "Numero de valores en 'date_completed' con nan:",data[data.date_completed.isnull()]["work_order_number"].count() ) # valores con NaN en date_completed
print( "Porcentaje de datos perdidos respecto al tamaño del Dataset: "+str(round((32387/609989)*100 ,2))+"%" )
print( "Formato de valores en la columna:",type(data.date_completed[0]) )
# Out:
# Numero de valores en 'date_completed' con nan: 32387
# Porcentaje de datos perdidos respecto al tamaño del Dataset: 5.31%
# Formato de valores en la columna: <class 'str'>

# %%
# %%time
data["date_created"] = pd.DatetimeIndex(data.date_created)
data["date_completed"] = pd.DatetimeIndex(data.date_completed)
data["asset_in_service_date"] = pd.DatetimeIndex(data.asset_in_service_date)
# Out:
# CPU times: total: 34.1 s
# Wall time: 2min 21s

# %%
data[data.date_completed.isnull()].head(3)
# Out:
#     work_order_number site_number    site_type        date_created  \
# 13           12940592       A0003  SUPERMARKET 2012-02-02 12:02:00
# 15           12940828       A0003  SUPERMARKET 2012-02-02 12:26:00
# 25           12953604       A2221  SUPERMARKET 2012-03-02 20:15:00
#
#    date_completed                   provider_name wo_current_status  \
# 13            NaT           CMS Solutions Limited         Cancelled
# 15            NaT           CMS Solutions Limited         Cancelled
# 25            NaT  Space Engineering services LTD         Cancelled
#
#    asset_category                        problem_type_name  \
# 13  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 15  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 25  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                   requested_by   wo_priority            manufacturer  \
# 13  Urgent Refrigeration Alarm  Standard SLA  RADFORD RETAIL SYSTEMS
# 15  Urgent Refrigeration Alarm  Standard SLA                      ND
# 25  Urgent Refrigeration Alarm  Standard SLA               CRIOSBANC
#
#    asset_in_service_date level_1_organization_name site_zipcode  sales_sq_ft  \
# 13   2009-03-15 04:00:00                Region S02     DA11 8JH      37870.0
# 15   2009-03-15 04:00:00                Region S02     DA11 8JH      37870.0
# 25   2009-06-17 05:00:00                Region C01      GL2 5SA          NaN
#
#                asset_barcode client_product_name       asset_type asset_status
# 13               SSL00583504                 NaN  FULL GLASS DOOR     Inactive
# 15  SSL00836662 -duplicate-1                 NaN  FULL GLASS DOOR     Scrapped
# 25               SSL00624924                 NaN     FISH COUNTER   In Service

# %% [markdown]
# Considerando que hay fechas que el mismo dia se activo y se silencio la alarma, entonces completamos los resultados faltantes de date_completed usando el metodo ffill de pandas el cual llena valores faltantes entre cada gap de nan por un valor valido.

# %%
data.date_completed.fillna(axis=0,method='ffill',inplace=True)

# %%
data[(data.work_order_number == 12940592) | (data.work_order_number == 12940828)]
# Out:
#     work_order_number site_number    site_type        date_created  \
# 13           12940592       A0003  SUPERMARKET 2012-02-02 12:02:00
# 15           12940828       A0003  SUPERMARKET 2012-02-02 12:26:00
#
#         date_completed          provider_name wo_current_status  \
# 13 2012-02-02 13:38:00  CMS Solutions Limited         Cancelled
# 15 2012-02-02 14:01:00  CMS Solutions Limited         Cancelled
#
#    asset_category                        problem_type_name  \
# 13  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 15  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                   requested_by   wo_priority            manufacturer  \
# 13  Urgent Refrigeration Alarm  Standard SLA  RADFORD RETAIL SYSTEMS
# 15  Urgent Refrigeration Alarm  Standard SLA                      ND
#
#    asset_in_service_date level_1_organization_name site_zipcode  sales_sq_ft  \
# 13   2009-03-15 04:00:00                Region S02     DA11 8JH      37870.0
# 15   2009-03-15 04:00:00                Region S02     DA11 8JH      37870.0
#
#                asset_barcode client_product_name       asset_type asset_status
# 13               SSL00583504                 NaN  FULL GLASS DOOR     Inactive
# 15  SSL00836662 -duplicate-1                 NaN  FULL GLASS DOOR     Scrapped

# %% [markdown]
# Observamos que para las ordenes "12940592" y "12940828" el valor que completa los NaT son validos en comparacion a datos que estan completos. Similarmente ocurre con la columna "asset_in_service_date"

# %%
data[data.asset_in_service_date.isnull()].head(3)
# Out:
#       work_order_number site_number    site_type        date_created  \
# 3964           13342929       A0852  SUPERMARKET 2012-09-03 12:15:00
# 4070           13346368       A0893  SUPERMARKET 2012-09-03 18:55:00
# 4743           13359685       A0893  SUPERMARKET 2012-11-03 21:05:00
#
#           date_completed                   provider_name  wo_current_status  \
# 3964 2012-10-03 12:36:00  Space Engineering services LTD                EOL
# 4070 2012-10-03 18:02:00    Montgomery Refrigeration Ltd  Invoice Processed
# 4743 2012-11-04 14:27:00    Montgomery Refrigeration Ltd  Invoice Processed
#
#      asset_category                        problem_type_name  \
# 3964  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4070  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4743  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                     requested_by   wo_priority  manufacturer  \
# 3964  Urgent Refrigeration Alarm  Standard SLA         LINDE
# 4070  Urgent Refrigeration Alarm  Standard SLA  RMS CONTROLS
# 4743  Urgent Refrigeration Alarm  Standard SLA  RMS CONTROLS
#
#      asset_in_service_date level_1_organization_name site_zipcode  \
# 3964                   NaT                Region N11     LE11 5AS
# 4070                   NaT                Region N03      G74 4UN
# 4743                   NaT                Region N03      G74 4UN
#
#       sales_sq_ft asset_barcode client_product_name              asset_type  \
# 3964      28039.0   SSL00633639                 NaN                    WELL
# 4070      38116.0   SSL00017276                 NaN  COLDROOM CONTROL PANEL
# 4743      38116.0   SSL00017276                 NaN  COLDROOM CONTROL PANEL
#
#      asset_status
# 3964     Scrapped
# 4070   In Service
# 4743   In Service

# %%
data.asset_in_service_date.fillna(axis=0,method='ffill',inplace=True)

# %%
data[(data.work_order_number == 13342929) | (data.work_order_number == 13346368) | (data.work_order_number == 13359685)]
# Out:
#       work_order_number site_number    site_type        date_created  \
# 3964           13342929       A0852  SUPERMARKET 2012-09-03 12:15:00
# 4070           13346368       A0893  SUPERMARKET 2012-09-03 18:55:00
# 4743           13359685       A0893  SUPERMARKET 2012-11-03 21:05:00
#
#           date_completed                   provider_name  wo_current_status  \
# 3964 2012-10-03 12:36:00  Space Engineering services LTD                EOL
# 4070 2012-10-03 18:02:00    Montgomery Refrigeration Ltd  Invoice Processed
# 4743 2012-11-04 14:27:00    Montgomery Refrigeration Ltd  Invoice Processed
#
#      asset_category                        problem_type_name  \
# 3964  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4070  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 4743  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                     requested_by   wo_priority  manufacturer  \
# 3964  Urgent Refrigeration Alarm  Standard SLA         LINDE
# 4070  Urgent Refrigeration Alarm  Standard SLA  RMS CONTROLS
# 4743  Urgent Refrigeration Alarm  Standard SLA  RMS CONTROLS
#
#      asset_in_service_date level_1_organization_name site_zipcode  \
# 3964   2011-02-14 05:00:00                Region N11     LE11 5AS
# 4070   2009-05-15 05:00:00                Region N03      G74 4UN
# 4743   2009-06-26 17:12:00                Region N03      G74 4UN
#
#       sales_sq_ft asset_barcode client_product_name              asset_type  \
# 3964      28039.0   SSL00633639                 NaN                    WELL
# 4070      38116.0   SSL00017276                 NaN  COLDROOM CONTROL PANEL
# 4743      38116.0   SSL00017276                 NaN  COLDROOM CONTROL PANEL
#
#      asset_status
# 3964     Scrapped
# 4070   In Service
# 4743   In Service

# %% [markdown]
# Efectivamente asset_in_service_date debe ser un resultado menor que date_created dado la descripcion del dataset, por lo que es una buena aproximacion este resultado para completar los datos faltantes.

# %%
print( "Numero de valores en 'date_created' con nan:",data[data.date_created.isnull()]["work_order_number"].count() )
print( "Numero de valores en 'date_completed' con nan:",data[data.date_completed.isnull()]["work_order_number"].count() )
print( "Numero de valores en 'asset_in_service_date' con nan:",data[data.asset_in_service_date.isnull()]["work_order_number"].count() )
# Out:
# Numero de valores en 'date_created' con nan: 0
# Numero de valores en 'date_completed' con nan: 0
# Numero de valores en 'asset_in_service_date' con nan: 0

# %% [markdown]
# ### **requested_by**

# %%
type(data.requested_by[0]) # tipo de variable
# Out:
# str

# %%
print(data.requested_by.unique()[:5])
print(len(data.requested_by.unique()))
# Out:
# ['Urgent Refrigeration Alarm'
#  'URGENT Refrigeration Fixture Communication Alarm'
#  'URGENT Refrigeration Fixture Monitoring Alarm'
#  'Valve Open >50% for 3hrs sustained for 3 times within 24hrs (All Cabinets and Coldrooms) LIVE '
#  'AirOn/Off Temp Diff >5°C for 8hr within 24hr period(ProvCab) LIVE ']
# 112

# %%
data[~data.requested_by.isnull()].tail()
# Out:
#         work_order_number site_number          site_type        date_created  \
# 527639           32704393       A0756        SUPERMARKET 2015-01-11 20:35:00
# 527640           32704394       A0885        SUPERMARKET 2015-01-11 20:35:00
# 527641           32704402       A4261  CONVENIENCE STORE 2015-01-11 20:38:00
# 527642           32704447       A4248  CONVENIENCE STORE 2015-01-11 20:50:00
# 527643           32704448       A0816        SUPERMARKET 2015-01-11 20:50:00
#
#             date_completed                   provider_name wo_current_status  \
# 527639 2015-01-11 20:08:00            Carter Refrigeration             Pend.
# 527640 2015-01-11 20:08:00                    KB (Carters)          Assigned
# 527641 2015-01-11 20:08:00  Space Engineering services LTD          Assigned
# 527642 2015-01-11 20:08:00           CMS Solutions Limited          Assigned
# 527643 2015-01-11 20:08:00  Space Engineering services LTD             Pend.
#
#        asset_category                        problem_type_name  \
# 527639  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 527640  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 527641  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 527642  REFRIGERATION  Fixture Critical Over Temperature Alarm
# 527643  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                       requested_by   wo_priority             manufacturer  \
# 527639  Urgent Refrigeration Alarm  Standard SLA                  NUTTALL
# 527640  Urgent Refrigeration Alarm  Standard SLA   WILLIAMS REFRIGERATION
# 527641  Urgent Refrigeration Alarm  Standard SLA                    VERCO
# 527642  Urgent Refrigeration Alarm  Standard SLA                     EPTA
# 527643  Urgent Refrigeration Alarm  Standard SLA  CARTER RETAIL EQUIPMENT
#
#        asset_in_service_date level_1_organization_name site_zipcode  \
# 527639   2011-09-16 06:29:00                Region C02     ST16 2TF
# 527640   2010-10-28 00:00:00                Region N03      G53 7RH
# 527641   2012-11-21 05:00:00                Region S09      PO4 0JT
# 527642   2012-11-05 05:00:00              Region S04-2       E8 4HR
# 527643   2011-10-20 05:00:00                Region N11     NG16 2LY
#
#         sales_sq_ft asset_barcode  \
# 527639      41385.0   SSL00827276
# 527640      35575.0   SSL00769586
# 527641          NaN   SSL00495507
# 527642          NaN   SSL00818570
# 527643      24743.0   SSL00803138
#
#                                       client_product_name  \
# 527639  Provisions, Dairy and Prepared Produce (5C or ...
# 527640                         Frozen Food (-18C or less)
# 527641                         Frozen Food (-18C or less)
# 527642                Meat, Fish and Poultry (3C or less)
# 527643                         Frozen Food (-18C or less)
#
#                  asset_type asset_status
# 527639           SERVE OVER   In Service
# 527640     INTEGRAL FREEZER   In Service
# 527641      FULL GLASS DOOR   In Service
# 527642     REMOTE MULTIDECK   In Service
# 527643  HALF GLASS DOOR END   In Service

# %% [markdown]
# Los valores no nulos de "requested_by" avanzan desde el indice (0) hasta el indice (527643) sin saltos.

# %%
data[data.requested_by.isnull()].head()
# Out:
#         work_order_number site_number          site_type        date_created  \
# 527644           12917191       D0470              DEPOT 2012-01-02 05:59:00
# 527645           12920048       A2154        SUPERMARKET 2012-01-02 06:02:00
# 527646           12920042       A2031        SUPERMARKET 2012-01-02 06:02:00
# 527647           12920044       A2017        SUPERMARKET 2012-01-02 06:02:00
# 527648           12920032       A4676  CONVENIENCE STORE 2012-01-02 06:02:00
#
#             date_completed                 provider_name wo_current_status  \
# 527644 2012-03-02 10:47:00             CMS Self Delivery               EOL
# 527645 2012-03-13 13:14:00  Montgomery Refrigeration Ltd               EOL
# 527646 2012-05-03 14:26:00  Montgomery Refrigeration Ltd               EOL
# 527647 2012-08-03 13:28:00  Montgomery Refrigeration Ltd               EOL
# 527648 2012-03-30 13:26:00  Montgomery Refrigeration Ltd               EOL
#
#        asset_category                                  problem_type_name  \
# 527644  REFRIGERATION      CMS S D - Ammonia Checks   (Dartford) - Daily
# 527645  REFRIGERATION  Montgomery - REMOTE AIR COOLED EXTERNAL CONDEN...
# 527646  REFRIGERATION  Montgomery - REMOTE AIR COOLED EXTERNAL CONDEN...
# 527647  REFRIGERATION  Montgomery - REMOTE AIR COOLED EXTERNAL CONDEN...
# 527648  REFRIGERATION  Montgomery - REMOTE AIR COOLED EXTERNAL CONDEN...
#
#        requested_by wo_priority     manufacturer asset_in_service_date  \
# 527644          NaN         PPM  No Manufacturer   2011-10-20 05:00:00
# 527645          NaN         PPM  No Manufacturer   2011-10-20 05:00:00
# 527646          NaN         PPM  No Manufacturer   2011-10-20 05:00:00
# 527647          NaN         PPM  No Manufacturer   2011-10-20 05:00:00
# 527648          NaN         PPM  No Manufacturer   2011-10-20 05:00:00
#
#        level_1_organization_name site_zipcode  sales_sq_ft asset_barcode  \
# 527644                     Depot      DA1 5PR          NaN      No Asset
# 527645                Region N02     EH11 2QW      49471.0      No Asset
# 527646                Region N03      G51 4BP      46224.0      No Asset
# 527647                Region N02      KY8 4LQ      13650.0      No Asset
# 527648              Region N02-2     AB25 1EP          NaN      No Asset
#
#        client_product_name asset_type asset_status
# 527644                 NaN        NaN          NaN
# 527645                 NaN        NaN          NaN
# 527646                 NaN        NaN          NaN
# 527647                 NaN        NaN          NaN
# 527648                 NaN        NaN          NaN

# %% [markdown]
# Vemos que a partir del indice (527643) todos los valores de la columna "requested_by" son nulos

# %%
print( "Numero de valores en 'requested_by' con nan:",data[data.requested_by.isnull()]["work_order_number"].count() )
# Out:
# Numero de valores en 'requested_by' con nan: 82345

# %% [markdown]
# ### **sales_sq_ft**

# %%
type(data.sales_sq_ft[0]) # tipo de variable
# Out:
# numpy.float64

# %%
data[(data.site_number == "A2221") & (data.sales_sq_ft.isnull())].head(3)
# Out:
#      work_order_number site_number    site_type        date_created  \
# 25            12953604       A2221  SUPERMARKET 2012-03-02 20:15:00
# 26            12954198       A2221  SUPERMARKET 2012-04-02 02:00:00
# 277           13031014       A2221  SUPERMARKET 2012-11-02 01:55:00
#
#          date_completed                   provider_name wo_current_status  \
# 25  2012-04-02 09:00:00  Space Engineering services LTD         Cancelled
# 26  2012-07-02 21:21:00  Space Engineering services LTD               EOL
# 277 2012-11-02 18:49:00  Space Engineering services LTD               EOL
#
#     asset_category                        problem_type_name  \
# 25   REFRIGERATION  Fixture Critical Over Temperature Alarm
# 26   REFRIGERATION  Fixture Critical Over Temperature Alarm
# 277  REFRIGERATION  Fixture Critical Over Temperature Alarm
#
#                    requested_by   wo_priority             manufacturer  \
# 25   Urgent Refrigeration Alarm  Standard SLA                CRIOSBANC
# 26   Urgent Refrigeration Alarm  Standard SLA                CRIOSBANC
# 277  Urgent Refrigeration Alarm  Standard SLA  CARTER RETAIL EQUIPMENT
#
#     asset_in_service_date level_1_organization_name site_zipcode  sales_sq_ft  \
# 25    2009-06-17 05:00:00                Region C01      GL2 5SA          NaN
# 26    2009-06-17 05:00:00                Region C01      GL2 5SA          NaN
# 277   2009-06-17 05:00:00                Region C01      GL2 5SA          NaN
#
#     asset_barcode         client_product_name    asset_type asset_status
# 25    SSL00624924                         NaN  FISH COUNTER   In Service
# 26    SSL00624924                         NaN  FISH COUNTER   In Service
# 277   SSL00615845  Frozen Food (-18C or less)          WELL   In Service

# %% [markdown]
# Indentificando el site_number (numero que representa la tienda) y buscando si tiene alojado algun nombre no logra identificar coincidencias, quiere decir que todos los resultados para esa tienda no contienen la columna "sales_sq_ft". como es un numero que representa el tamaño de la tienda entonces no se pueden completar los NaN con 0. debe ser un tamaño adecuado por lo que una aproximacion para las faltantes seria la media de la columna entera.

# %%
data.sales_sq_ft.fillna(value=data.sales_sq_ft.mean(),inplace=True)

# %%
print( "Numero de valores en 'sales_sq_ft' con nan:",data[data.sales_sq_ft.isnull()]["work_order_number"].count() )
# Out:
# Numero de valores en 'sales_sq_ft' con nan: 0

# %% [markdown]
# ### **client_product_name**

# %%
print(data.client_product_name.unique().tolist())
print("tamaño de categorias:",len(data.client_product_name.unique()))
# Out:
# ['Frozen Food (-18C or less)', 'Meat, Fish and Poultry (3C or less)', nan, 'Provisions, Dairy and Prepared Produce (5C or less)', 'Soft Drinks/BWS (5C or less - alarms at 12C)', 'Produce (7C or less)', 'Pharmacy (2 - 8C)']
# tamaño de categorias: 7

# %% [markdown]
# El nombre de la columna no tiene relacion con los valores que muestra, parece ser que es mas que todo una columna que muestra el tipo de uso que se le da a la nevera junto con su rango de enfriamiento. contiene 7 categorias (se puede separar una columna con las categorias y otra con el rango de enfriamiento)

# %%
type_of_use = []
cooling_range = []
for i in range(len(data)):
    try:
        type_temp = data.client_product_name[i].split("(")[0]
        max_cool_temp = re.findall("(-\d+|\d+)",data.client_product_name[i].split("(")[1])
        if len(max_cool_temp) > 1: cool_temp = f"({max_cool_temp[0]}-{max_cool_temp[1]})C - less"
        else: cool_temp = f"{max_cool_temp[0]}C - less"
        #print(cool_temp)
        type_of_use.append(type_temp)
        cooling_range.append(cool_temp)
    except:
        type_of_use.append(np.nan)
        cooling_range.append(np.nan)

data.insert(0,"preserves",type_of_use)
data.insert(0,"cooling_range",cooling_range)

# %%
data.head()
# Out:
#   cooling_range                preserves  work_order_number site_number  \
# 0   -18C - less             Frozen Food            12904684       A0892
# 1   -18C - less             Frozen Food            12904685       A0892
# 2   -18C - less             Frozen Food            12904853       A0892
# 3     3C - less  Meat, Fish and Poultry            12927899       A0416
# 4           NaN                      NaN           12932231       A0003
#
#      site_type        date_created      date_completed  \
# 0  SUPERMARKET 2012-01-02 03:05:00 2012-01-02 10:00:00
# 1  SUPERMARKET 2012-01-02 03:05:00 2012-01-02 09:59:00
# 2  SUPERMARKET 2012-01-02 05:10:00 2012-01-02 10:01:00
# 3  SUPERMARKET 2012-01-02 08:40:00 2012-02-02 13:03:00
# 4  SUPERMARKET 2012-01-02 13:33:00 2012-08-02 19:39:00
#
#                     provider_name wo_current_status asset_category  ...  \
# 0  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 1  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 2  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 3           CMS Solutions Limited               EOL  REFRIGERATION  ...
# 4           CMS Solutions Limited               EOL  REFRIGERATION  ...
#
#     wo_priority            manufacturer asset_in_service_date  \
# 0  Standard SLA                  CARTER   2011-01-06 15:19:00
# 1  Standard SLA                  CARTER   2011-01-06 15:19:00
# 2  Standard SLA                  CARTER   2011-01-06 15:19:00
# 3  Standard SLA                   LINDE   2002-01-08 05:00:00
# 4  Standard SLA  RADFORD RETAIL SYSTEMS   2009-03-15 04:00:00
#
#   level_1_organization_name site_zipcode sales_sq_ft asset_barcode  \
# 0                Region N10     DN31 1UF     42639.0   SSL00567391
# 1                Region N10     DN31 1UF     42639.0   SSL00567398
# 2                Region N10     DN31 1UF     42639.0   SSL00567399
# 3                Region S01      BR4 0PU     13423.0   SSL00225160
# 4                Region S02     DA11 8JH     37870.0   SSL00583503
#
#                    client_product_name              asset_type asset_status
# 0           Frozen Food (-18C or less)  HALF GLASS DOOR & WELL   In Service
# 1           Frozen Food (-18C or less)         FULL GLASS DOOR   In Service
# 2           Frozen Food (-18C or less)         FULL GLASS DOOR   In Service
# 3  Meat, Fish and Poultry (3C or less)        REMOTE MULTIDECK   In Service
# 4                                  NaN         FULL GLASS DOOR     Scrapped
#
# [5 rows x 22 columns]

# %%
print(data.preserves.unique().tolist())
print("tamaño de categorias:",len(data.preserves.unique()))
# Out:
# ['Frozen Food ', 'Meat, Fish and Poultry ', nan, 'Provisions, Dairy and Prepared Produce ', 'Soft Drinks/BWS ', 'Produce ', 'Pharmacy ']
# tamaño de categorias: 7

# %%
print(data.cooling_range.unique().tolist())
print("tamaño de categorias:",len(data.cooling_range.unique()))
# Out:
# ['-18C - less', '3C - less', nan, '5C - less', '(5-12)C - less', '7C - less', '(2-8)C - less']
# tamaño de categorias: 7

# %% [markdown]
# Ahora podemos eliminar la columna "client_product_name"

# %%
data.drop("client_product_name",axis=1,inplace=True)

# %% [markdown]
# ### **asset_type | asset_status**

# %% [markdown]
# Aparentemente requested_by, wo_priority y asset_type comparten valores vacios desde el indice (527644)

# %% [markdown]
# asset_type contiene una categoria llamada: "No Asset Type" lo que podria ser el mismo caso de los NaN presente en esta categoria

# %%
data[data.requested_by.isnull()].head(3)
# Out:
#        cooling_range preserves  work_order_number site_number    site_type  \
# 527644           NaN       NaN           12917191       D0470        DEPOT
# 527645           NaN       NaN           12920048       A2154  SUPERMARKET
# 527646           NaN       NaN           12920042       A2031  SUPERMARKET
#
#               date_created      date_completed                 provider_name  \
# 527644 2012-01-02 05:59:00 2012-03-02 10:47:00             CMS Self Delivery
# 527645 2012-01-02 06:02:00 2012-03-13 13:14:00  Montgomery Refrigeration Ltd
# 527646 2012-01-02 06:02:00 2012-05-03 14:26:00  Montgomery Refrigeration Ltd
#
#        wo_current_status asset_category  ... requested_by wo_priority  \
# 527644               EOL  REFRIGERATION  ...          NaN         PPM
# 527645               EOL  REFRIGERATION  ...          NaN         PPM
# 527646               EOL  REFRIGERATION  ...          NaN         PPM
#
#            manufacturer asset_in_service_date level_1_organization_name  \
# 527644  No Manufacturer   2011-10-20 05:00:00                     Depot
# 527645  No Manufacturer   2011-10-20 05:00:00                Region N02
# 527646  No Manufacturer   2011-10-20 05:00:00                Region N03
#
#        site_zipcode   sales_sq_ft  asset_barcode asset_type asset_status
# 527644      DA1 5PR  33424.599678       No Asset        NaN          NaN
# 527645     EH11 2QW  49471.000000       No Asset        NaN          NaN
# 527646      G51 4BP  46224.000000       No Asset        NaN          NaN
#
# [3 rows x 21 columns]

# %%
data[~data.requested_by.isnull()].tail()
# Out:
#        cooling_range                                preserves  \
# 527639     5C - less  Provisions, Dairy and Prepared Produce
# 527640   -18C - less                             Frozen Food
# 527641   -18C - less                             Frozen Food
# 527642     3C - less                  Meat, Fish and Poultry
# 527643   -18C - less                             Frozen Food
#
#         work_order_number site_number          site_type        date_created  \
# 527639           32704393       A0756        SUPERMARKET 2015-01-11 20:35:00
# 527640           32704394       A0885        SUPERMARKET 2015-01-11 20:35:00
# 527641           32704402       A4261  CONVENIENCE STORE 2015-01-11 20:38:00
# 527642           32704447       A4248  CONVENIENCE STORE 2015-01-11 20:50:00
# 527643           32704448       A0816        SUPERMARKET 2015-01-11 20:50:00
#
#             date_completed                   provider_name wo_current_status  \
# 527639 2015-01-11 20:08:00            Carter Refrigeration             Pend.
# 527640 2015-01-11 20:08:00                    KB (Carters)          Assigned
# 527641 2015-01-11 20:08:00  Space Engineering services LTD          Assigned
# 527642 2015-01-11 20:08:00           CMS Solutions Limited          Assigned
# 527643 2015-01-11 20:08:00  Space Engineering services LTD             Pend.
#
#        asset_category  ...                requested_by   wo_priority  \
# 527639  REFRIGERATION  ...  Urgent Refrigeration Alarm  Standard SLA
# 527640  REFRIGERATION  ...  Urgent Refrigeration Alarm  Standard SLA
# 527641  REFRIGERATION  ...  Urgent Refrigeration Alarm  Standard SLA
# 527642  REFRIGERATION  ...  Urgent Refrigeration Alarm  Standard SLA
# 527643  REFRIGERATION  ...  Urgent Refrigeration Alarm  Standard SLA
#
#                    manufacturer asset_in_service_date  \
# 527639                  NUTTALL   2011-09-16 06:29:00
# 527640   WILLIAMS REFRIGERATION   2010-10-28 00:00:00
# 527641                    VERCO   2012-11-21 05:00:00
# 527642                     EPTA   2012-11-05 05:00:00
# 527643  CARTER RETAIL EQUIPMENT   2011-10-20 05:00:00
#
#        level_1_organization_name site_zipcode   sales_sq_ft  asset_barcode  \
# 527639                Region C02     ST16 2TF  41385.000000    SSL00827276
# 527640                Region N03      G53 7RH  35575.000000    SSL00769586
# 527641                Region S09      PO4 0JT  33424.599678    SSL00495507
# 527642              Region S04-2       E8 4HR  33424.599678    SSL00818570
# 527643                Region N11     NG16 2LY  24743.000000    SSL00803138
#
#                  asset_type asset_status
# 527639           SERVE OVER   In Service
# 527640     INTEGRAL FREEZER   In Service
# 527641      FULL GLASS DOOR   In Service
# 527642     REMOTE MULTIDECK   In Service
# 527643  HALF GLASS DOOR END   In Service
#
# [5 rows x 21 columns]

# %%
data.requested_by.value_counts()
# Out:
# Urgent Refrigeration Alarm                                                                        419344
# Valve Open >50% for 3hrs sustained for 3 times within 24hrs (All Cabinets and Coldrooms) LIVE      42841
# Air Temp Diff is Negative for a sustained 30mins within 24hr period (Cabinets) LIVE                 9444
# Air Temp Diff is Negative for a sustained 40mins within 24hr period (Cabinets) LIVE                 5021
# Superheat >11°C for 2hrs sustained within 24hrs LIVE                                                5020
#                                                                                                    ...
#  AirOn/Off Temp Diff >8°C for 8hr within 24hr period(ProvCab) LIVE                                     1
# AEL Engineer                                                                                           1
# Urgent Refrigeration Alarm/K Desmond                                                                   1
# AirOn/Off Temp Diff >8°C for 8hr within 24hr period(ProvCab) LIVE                                      1
# ASL                                                                                                    1
# Name: requested_by, Length: 111, dtype: int64

# %%
data[data.wo_priority == "PPM"].head(3)
# Out:
#        cooling_range preserves  work_order_number site_number    site_type  \
# 527644           NaN       NaN           12917191       D0470        DEPOT
# 527645           NaN       NaN           12920048       A2154  SUPERMARKET
# 527646           NaN       NaN           12920042       A2031  SUPERMARKET
#
#               date_created      date_completed                 provider_name  \
# 527644 2012-01-02 05:59:00 2012-03-02 10:47:00             CMS Self Delivery
# 527645 2012-01-02 06:02:00 2012-03-13 13:14:00  Montgomery Refrigeration Ltd
# 527646 2012-01-02 06:02:00 2012-05-03 14:26:00  Montgomery Refrigeration Ltd
#
#        wo_current_status asset_category  ... requested_by wo_priority  \
# 527644               EOL  REFRIGERATION  ...          NaN         PPM
# 527645               EOL  REFRIGERATION  ...          NaN         PPM
# 527646               EOL  REFRIGERATION  ...          NaN         PPM
#
#            manufacturer asset_in_service_date level_1_organization_name  \
# 527644  No Manufacturer   2011-10-20 05:00:00                     Depot
# 527645  No Manufacturer   2011-10-20 05:00:00                Region N02
# 527646  No Manufacturer   2011-10-20 05:00:00                Region N03
#
#        site_zipcode   sales_sq_ft  asset_barcode asset_type asset_status
# 527644      DA1 5PR  33424.599678       No Asset        NaN          NaN
# 527645     EH11 2QW  49471.000000       No Asset        NaN          NaN
# 527646      G51 4BP  46224.000000       No Asset        NaN          NaN
#
# [3 rows x 21 columns]

# %%
len(data[data.wo_priority == "PPM"])
# Out:
# 82345

# %%
data[data.asset_type.isnull()].head(3)
# Out:
#        cooling_range preserves  work_order_number site_number    site_type  \
# 527644           NaN       NaN           12917191       D0470        DEPOT
# 527645           NaN       NaN           12920048       A2154  SUPERMARKET
# 527646           NaN       NaN           12920042       A2031  SUPERMARKET
#
#               date_created      date_completed                 provider_name  \
# 527644 2012-01-02 05:59:00 2012-03-02 10:47:00             CMS Self Delivery
# 527645 2012-01-02 06:02:00 2012-03-13 13:14:00  Montgomery Refrigeration Ltd
# 527646 2012-01-02 06:02:00 2012-05-03 14:26:00  Montgomery Refrigeration Ltd
#
#        wo_current_status asset_category  ... requested_by wo_priority  \
# 527644               EOL  REFRIGERATION  ...          NaN         PPM
# 527645               EOL  REFRIGERATION  ...          NaN         PPM
# 527646               EOL  REFRIGERATION  ...          NaN         PPM
#
#            manufacturer asset_in_service_date level_1_organization_name  \
# 527644  No Manufacturer   2011-10-20 05:00:00                     Depot
# 527645  No Manufacturer   2011-10-20 05:00:00                Region N02
# 527646  No Manufacturer   2011-10-20 05:00:00                Region N03
#
#        site_zipcode   sales_sq_ft  asset_barcode asset_type asset_status
# 527644      DA1 5PR  33424.599678       No Asset        NaN          NaN
# 527645     EH11 2QW  49471.000000       No Asset        NaN          NaN
# 527646      G51 4BP  46224.000000       No Asset        NaN          NaN
#
# [3 rows x 21 columns]

# %%
len(data[data.asset_type.isnull()])
# Out:
# 82345

# %% [markdown]
# ### Seleccion de dataset sin contar filas con muy poca informacion

# %%
data2 = data[:527644]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527644 entries, 0 to 527643
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   cooling_range              467909 non-null  object
#  1   preserves                  467909 non-null  object
#  2   work_order_number          527644 non-null  int64
#  3   site_number                527644 non-null  object
#  4   site_type                  527644 non-null  object
#  5   date_created               527644 non-null  datetime64[ns]
#  6   date_completed             527644 non-null  datetime64[ns]
#  7   provider_name              527644 non-null  object
#  8   wo_current_status          527644 non-null  object
#  9   asset_category             527644 non-null  object
#  10  problem_type_name          527644 non-null  object
#  11  requested_by               527644 non-null  object
#  12  wo_priority                527644 non-null  object
#  13  manufacturer               527644 non-null  object
#  14  asset_in_service_date      527644 non-null  datetime64[ns]
#  15  level_1_organization_name  527644 non-null  object
#  16  site_zipcode               527644 non-null  object
#  17  sales_sq_ft                527644 non-null  float64
#  18  asset_barcode              527644 non-null  object
#  19  asset_type                 527644 non-null  object
#  20  asset_status               526005 non-null  object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(16)
# memory usage: 84.5+ MB

# %%
data2.preserves.isnull().value_counts()
# Out:
# False    467909
# True      59735
# Name: preserves, dtype: int64

# %%
data2[(data2.preserves.isnull())]["site_type"].value_counts()
# Out:
# SUPERMARKET          47359
# CONVENIENCE STORE     6489
# SHARED SITE           5233
# PFS                    654
# Name: site_type, dtype: int64

# %%
def printProgressBar (iteration, total, prefix = '', suffix = '', decimals = 1, length = 100, fill = '█', printEnd = "\r"):
    """
    Call in a loop to create terminal progress bar
    @params:
        iteration   - Required  : current iteration (Int)
        total       - Required  : total iterations (Int)
        prefix      - Optional  : prefix string (Str)
        suffix      - Optional  : suffix string (Str)
        decimals    - Optional  : positive number of decimals in percent complete (Int)
        length      - Optional  : character length of bar (Int)
        fill        - Optional  : bar fill character (Str)
        printEnd    - Optional  : end character (e.g. "\r", "\r\n") (Str)
    """
    percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '-' * (length - filledLength)
    print(f'\r{prefix} |{bar}| {percent}% {suffix}', end = printEnd)
    # Print New Line on Complete
    if iteration == total: 
        print()

# %%
data_tc = data2[data2.preserves.isnull()] # datos que son nulos de preserves

# %%
data2[data2.site_type == "SUPERMARKET"]["preserves"].value_counts()
# Out:
# Frozen Food                                146553
# Provisions, Dairy and Prepared Produce     100718
# Meat, Fish and Poultry                      87014
# Produce                                     14660
# Soft Drinks/BWS                               446
# Pharmacy                                       14
# Name: preserves, dtype: int64

# %%
pres_completed = []
for i in range(len(data_tc)):
    if data_tc.site_type.tolist()[i] == "SUPERMARKET":
        pres_completed.append("Frozen Food")
    elif data_tc.site_type.tolist()[i] == "CONVENIENCE STORE":
        pres_completed.append("Provisions, Dairy and Prepared Produce")
    elif data_tc.site_type.tolist()[i] == "SHARED SITE":
        pres_completed.append("Frozen Food")
    else:
        pres_completed.append("Provisions, Dairy and Prepared Produce")
    printProgressBar(i,len(data_tc)-1)
# Out:
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%

# %% [markdown]
# La mejor forma de hacerlo es investigando el "asset_barcode", ya que se puede investigar el origen y funcionamiento del producto y asociarlo a las categorias presentadas en la columna "preserves". el problema es que "asset_barcode" es un valor unico por cada fila lo que implica realizar una busqueda manual de 527644 assets lo que no es aceptable dado los tiempos del proyecto y la cantidad de personas que se encuentran analizando los resultados.

# %%
data_tc["preserves"] = pres_completed # completar valores faltantes en el dataset de valores nulos de preserves

# %%
data_tc = data_tc[["preserves","work_order_number"]] # work_order_number es unico y se puede usar como key para hacer un left join (merge)
data_tc.head(3)
# Out:
#      preserves  work_order_number
# 4  Frozen Food           12932231
# 5  Frozen Food           12932240
# 7  Frozen Food           12938545

# %%
C = data2.merge(data_tc, on="work_order_number", suffixes=('', '_y'), how='left') # se crea dataset con columna nueva llamada preserves_y

# %%
C["preserves"] = C["preserves"].fillna(C['preserves_y']) # se llena los vacios de preserves con los valores de preserves_y
C.head()
# Out:
#   cooling_range                preserves  work_order_number site_number  \
# 0   -18C - less             Frozen Food            12904684       A0892
# 1   -18C - less             Frozen Food            12904685       A0892
# 2   -18C - less             Frozen Food            12904853       A0892
# 3     3C - less  Meat, Fish and Poultry            12927899       A0416
# 4           NaN              Frozen Food           12932231       A0003
#
#      site_type        date_created      date_completed  \
# 0  SUPERMARKET 2012-01-02 03:05:00 2012-01-02 10:00:00
# 1  SUPERMARKET 2012-01-02 03:05:00 2012-01-02 09:59:00
# 2  SUPERMARKET 2012-01-02 05:10:00 2012-01-02 10:01:00
# 3  SUPERMARKET 2012-01-02 08:40:00 2012-02-02 13:03:00
# 4  SUPERMARKET 2012-01-02 13:33:00 2012-08-02 19:39:00
#
#                     provider_name wo_current_status asset_category  ...  \
# 0  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 1  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 2  Space Engineering services LTD               EOL  REFRIGERATION  ...
# 3           CMS Solutions Limited               EOL  REFRIGERATION  ...
# 4           CMS Solutions Limited               EOL  REFRIGERATION  ...
#
#     wo_priority            manufacturer asset_in_service_date  \
# 0  Standard SLA                  CARTER   2011-01-06 15:19:00
# 1  Standard SLA                  CARTER   2011-01-06 15:19:00
# 2  Standard SLA                  CARTER   2011-01-06 15:19:00
# 3  Standard SLA                   LINDE   2002-01-08 05:00:00
# 4  Standard SLA  RADFORD RETAIL SYSTEMS   2009-03-15 04:00:00
#
#   level_1_organization_name site_zipcode sales_sq_ft asset_barcode  \
# 0                Region N10     DN31 1UF     42639.0   SSL00567391
# 1                Region N10     DN31 1UF     42639.0   SSL00567398
# 2                Region N10     DN31 1UF     42639.0   SSL00567399
# 3                Region S01      BR4 0PU     13423.0   SSL00225160
# 4                Region S02     DA11 8JH     37870.0   SSL00583503
#
#                asset_type asset_status  preserves_y
# 0  HALF GLASS DOOR & WELL   In Service          NaN
# 1         FULL GLASS DOOR   In Service          NaN
# 2         FULL GLASS DOOR   In Service          NaN
# 3        REMOTE MULTIDECK   In Service          NaN
# 4         FULL GLASS DOOR     Scrapped  Frozen Food
#
# [5 rows x 22 columns]

# %% [markdown]
# "cooling_range" no es importante para el analisis, por lo que se puede eliminar del dataset.

# %%
C.drop("cooling_range",axis=1,inplace=True)
C.drop("preserves_y",axis=1,inplace=True)

# %%
C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527644 entries, 0 to 527643
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   preserves                  527644 non-null  object
#  1   work_order_number          527644 non-null  int64
#  2   site_number                527644 non-null  object
#  3   site_type                  527644 non-null  object
#  4   date_created               527644 non-null  datetime64[ns]
#  5   date_completed             527644 non-null  datetime64[ns]
#  6   provider_name              527644 non-null  object
#  7   wo_current_status          527644 non-null  object
#  8   asset_category             527644 non-null  object
#  9   problem_type_name          527644 non-null  object
#  10  requested_by               527644 non-null  object
#  11  wo_priority                527644 non-null  object
#  12  manufacturer               527644 non-null  object
#  13  asset_in_service_date      527644 non-null  datetime64[ns]
#  14  level_1_organization_name  527644 non-null  object
#  15  site_zipcode               527644 non-null  object
#  16  sales_sq_ft                527644 non-null  float64
#  17  asset_barcode              527644 non-null  object
#  18  asset_type                 527644 non-null  object
#  19  asset_status               526005 non-null  object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(15)
# memory usage: 84.5+ MB

# %%
C.asset_status.unique().tolist()
# Out:
# ['In Service',
#  'Scrapped',
#  'Inactive',
#  'Not Verified',
#  'Storage - Operable',
#  'Planned Refit Removal',
#  'Not Found',
#  'Not Applicable',
#  'Storage - Hold',
#  'Storage - Needs Review',
#  'Sold',
#  nan]

# %% [markdown]
# Dado que una categoria similar a NaN es Not Found, se reemplaza para reducir resultados nulos

# %%
C.asset_status.fillna("Not Found",inplace=True)

# %%
C.to_csv("./data/datacll.csv",index=None) # guarda los resultados del dataset con valores completos
