# %% [markdown]
# # animation using command line

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import scipy.stats as stats
import random
x=[]
y=[]

i=0

def update_plot(j): 

    global i,latency,sample
    i=i+1
    response=random.randint(1,10)
    y.append(float(response))
    x.append(float(i))
    
    ax.plot(x,y,'-k')
    ax.grid(True)
    ax.set_xlabel('time')
    ax.set_ylabel('ping') 

fig,ax = plt.subplots(1,1,figsize=(5.4,3.3))
animation = animation.FuncAnimation(fig, update_plot, repeat=True, interval=1000)
plt.show()

# %% [markdown]
# # animation using jupyter notebook

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import time


x=[]
y=[]

fig, ax = plt.subplots(1, 1)

i=0

while (True): 
    ax.cla()     # limpiar plot para actualizacion
    i=i+1
    response=random.randint(1,10)
    y.append(float(response))
    x.append(float(i))

    
    ax.plot(x,y, 's-')    # plot del ajuste

    fig.canvas.draw() # actualizacion del plot
    time.sleep(1.0)   # esperar 1 segundo
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_90527/3444714522.py in <module>
#      22     ax.plot(x,y, 's-')    # plot del ajuste
#      23
# ---> 24     fig.canvas.draw() # actualizacion del plot
#      25     time.sleep(1.0)   # esperar 1 segundo
#      26
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     188             super().draw()
#     189         finally:
# ...
