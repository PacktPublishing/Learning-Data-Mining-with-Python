# %% [markdown]
# # animation using command line

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import scipy.stats as stats
import random
x=[]
y=[]

i=0

def update_plot(j): 

    global i,latency,sample
    i=i+1
    response=random.randint(1,10)
    y.append(float(response))
    x.append(float(i))
    
    ax.plot(x,y,'-k')
    ax.grid(True)
    ax.set_xlabel('time')
    ax.set_ylabel('ping') 

fig,ax = plt.subplots(1,1,figsize=(5.4,3.3))
animation = animation.FuncAnimation(fig, update_plot, repeat=False, interval=1000)
plt.show()

# %% [markdown]
# # animation using jupyter notebook

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import time
fig, ax = plt.subplots(1, 1)

x=[]
y=[]

i=0

while (True): 
    ax.cla()     # limpiar plot para actualizacion
    i=i+1
    response=random.randint(1,10)
    y.append(float(response))
    x.append(float(i))

    
    ax.plot(x,y)    # plot del ajuste

    fig.canvas.draw() # actualizacion del plot
    time.sleep(1.0)   # esperar 1 segundo
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b6ad1d747baf> in <module>
#      21
#      22     fig.canvas.draw() # actualizacion del plot
# ---> 23     time.sleep(1.0)   # esperar 1 segundo
#      24
#
# KeyboardInterrupt:
