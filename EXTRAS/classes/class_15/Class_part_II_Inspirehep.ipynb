# %% [markdown]
# # lets look at the website inspirehep High Energy Physics Community
#   * inspirehep.net
#   * inspirehep.net/api
#   * we can access the data of the website using standard HTML way or API:

# %% [markdown]
# * go to https://inspirehep.net
# * if your in literature section type: laser and `enter`
# * copy link the link and paste it to new tab
# * add `api` between: `https://inspirehep.net/api/.......`

# %%
c='Austria'

# %%
import requests

# %%
institution_link=requests.get('https://inspirehep.net/api/institutions?q=Austria')

# %%
institution_link.status_code
# Out:
# 200

# %%
institution_link.json().get('hits')

# %%
institution_link.json().get('hits').get('hits')
# Out:
# [{'created': '2010-07-09T00:00:00+00:00',
#   'updated': '2021-06-25T15:56:02.412237+00:00',
#   'metadata': {'addresses': [{'country_code': 'AT',
#      'postal_address': ['Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 147,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/912282'},
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Unlisted, AT',
#    'control_number': 912282,
#    'legacy_version': '20130819034837.0',
#    'legacy_creation_date': '2010-07-09',
#    'external_system_identifiers': [{'value': 'INST-113433',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/912282?format=json'},
#   'id': '912282'},
#  {'created': '1993-04-02T00:00:00+00:00',
#   'updated': '2021-06-25T22:08:17.801006+00:00',
#   'metadata': {'addresses': [{'cities': ['Weiz'],
#      'country_code': 'AT',
#      'postal_address': ['ELIN Energieanwendung GMBH', 'A-8160 Weiz, Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 5,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/906322'},
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'ELIN, Weiz',
#    'control_number': 906322,
#    'legacy_version': '20130819034309.0',
#    'legacy_creation_date': '1993-04-02',
#    'external_system_identifiers': [{'value': 'INST-45730',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/906322?format=json'},
#   'id': '906322'},
#  {'created': '1989-07-27T00:00:00+00:00',
#   'updated': '2021-06-25T15:56:57.856641+00:00',
#   'metadata': {'addresses': [{'cities': ['Seibersdorf'],
#      'country_code': 'AT',
#      'postal_address': ['Austrian Research Center',
#       'Seibersdorf LTD.',
#       'A-2444 Seibersdorf AUSTRIA'],
#      'country': 'Austria'}],
#    'number_of_papers': 35,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Seibersdorf, Reaktorzentrum',
#    'extra_words': ['Physics Institute, Research Center',
#     'Res. Ctr.',
#     'limited',
#     'centre',
#     'phys',
#     'inst'],
#    'control_number': 904184,
#    'legacy_version': '20161012160116.0',
#    'legacy_creation_date': '1989-07-27',
#    'external_system_identifiers': [{'value': 'INST-20001',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/904184?format=json'},
#   'id': '904184'},
#  {'created': '1995-04-25T00:00:00+00:00',
#   'updated': '2021-06-26T01:17:56.924487+00:00',
#   'metadata': {'addresses': [{'cities': ['Graz'],
#      'country_code': 'AT',
#      'postal_address': ['Joanneum Research',
#       'Anstalt fur Tieftemperaturforschung',
#       'A-8010 Graz, Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 5,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/906854'},
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Joanneum Research, Graz',
#    'control_number': 906854,
#    'legacy_version': '20130819034355.0',
#    'legacy_creation_date': '1995-04-25',
#    'external_system_identifiers': [{'value': 'INST-51560',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/906854?format=json'},
#   'id': '906854'},
#  {'created': '2010-03-08T00:00:00+00:00',
#   'updated': '2021-06-25T15:55:58.007146+00:00',
#   'metadata': {'addresses': [{'cities': ['Seibersdorf'],
#      'country_code': 'AT',
#      'postal_address': ['Austrian Inst. of Technology GmbH',
#       'A-2444 Seibersdorf, Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 7,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/911923'},
#    'urls': [{'value': 'http://www.ait.ac.at/'}],
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Austrian Inst. Tech., Seibersdorf',
#    'extra_words': ['AIT', 'Institute, Technol'],
#    'control_number': 911923,
#    'legacy_version': '20161012160533.0',
#    'legacy_creation_date': '2010-03-08',
#    'external_system_identifiers': [{'value': 'INST-108740',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/911923?format=json'},
#   'id': '911923'},
#  {'created': '2022-08-18T09:27:25.897794+00:00',
#   'updated': '2022-08-18T09:31:43.447818+00:00',
#   'metadata': {'addresses': [{'cities': ['Wiener Neustadt'],
#      'postal_code': '2700',
#      'country_code': 'AT',
#      'postal_address': ['Marie Curie-Strasse 5'],
#      'country': 'Austria'}],
#    'number_of_papers': 1,
#    'ICN': ['MedAustron'],
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/2137098'},
#    'urls': [{'value': 'https://www.medaustron.at/'}],
#    '$schema': 'https://inspirehep.net/api/schemas/records/institutions.json',
#    'legacy_ICN': 'MedAustron',
#    'control_number': 2137098,
#    'institution_type': ['Research Center'],
#    'external_system_identifiers': [{'value': 'https://ror.org/056nqp360',
#      'schema': 'ROR'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/2137098?format=json'},
#   'id': '2137098'},
#  {'created': '1989-07-27T00:00:00+00:00',
#   'updated': '2021-06-26T06:29:29.643214+00:00',
#   'metadata': {'addresses': [{'cities': ['Graz'],
#      'country_code': 'AT',
#      'postal_address': ['Tech. Univ. Graz',
#       'Inst. fur Theor. Physik',
#       'PetersGasse 16',
#       'A-8010 Graz, AUSTRIA'],
#      'country': 'Austria'}],
#    'number_of_papers': 108,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/904725'},
#    'urls': [{'value': 'http://www.tugraz.at/'}],
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Graz, Tech. U.',
#    'extra_words': ['TUG, Erzherzog-Johann Univ.',
#     'Universitaet, University',
#     'institute',
#     'physics',
#     'phys',
#     'TUG/ITP'],
#    'control_number': 904725,
#    'legacy_version': '20161012160126.0',
#    'institution_type': ['University'],
#    'legacy_creation_date': '1989-07-27',
#    'external_system_identifiers': [{'value': 'INST-27162',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/904725?format=json'},
#   'id': '904725'},
#  {'created': '2005-05-31T00:00:00+00:00',
#   'updated': '2021-06-26T05:17:33.053206+00:00',
#   'metadata': {'addresses': [{'cities': ['Vienna'],
#      'latitude': 48.2248956,
#      'longitude': 16.356965,
#      'country_code': 'AT',
#      'postal_address': ['European Centre for Parallel Computing',
#       'Nordbergstrasse 15/C/3',
#       'A-1090 Vienna, Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 0,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/1241079'},
#    'urls': [{'value': 'http://www.vcpc.univie.ac.at/'}],
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'VCPC, Vienna',
#    'extra_words': ['Ctr., Center, Comput.'],
#    'control_number': 1241079,
#    'legacy_version': '20161019033501.0',
#    'legacy_creation_date': '2005-05-31',
#    'external_system_identifiers': [{'value': 'INST-90433',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/1241079?format=json'},
#   'id': '1241079'},
#  {'created': '1994-08-11T00:00:00+00:00',
#   'updated': '2021-06-26T04:27:20.571514+00:00',
#   'metadata': {'addresses': [{'cities': ['Vienna'],
#      'country_code': 'AT',
#      'postal_address': ['Inst. fur Radiumforschung',
#       'und Kernphysik',
#       'Boltzmanngasse 3',
#       'A-1090 Vienna, Austria'],
#      'country': 'Austria'}],
#    'number_of_papers': 9,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/903791'},
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'inactive': True,
#    'legacy_ICN': 'Vienna, Inst. Radium. Kernphys.',
#    'extra_words': ['Institut fur Radiumforschung und K',
#     'Wien',
#     'Stefan Meyer Institut fur subatoma',
#     'institute'],
#    'control_number': 903791,
#    'legacy_version': '20161012160107.0',
#    'legacy_creation_date': '1994-08-11',
#    'external_system_identifiers': [{'value': 'INST-15490',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/903791?format=json'},
#   'id': '903791'},
#  {'created': '2002-08-05T00:00:00+00:00',
#   'updated': '2021-06-26T01:21:01.312343+00:00',
#   'metadata': {'addresses': [{'cities': ['Wiender Neustadt'],
#      'country_code': 'AT',
#      'postal_address': ['Fachhochschule fur Wirtschaft und',
#       'Technik',
#       'Johann Gutenberg Strasse 3',
#       'A-2700 Wiener Neustadt',
#       'AUSTRIA'],
#      'country': 'Austria'}],
#    'number_of_papers': 90,
#    'self': {'$ref': 'https://inspirehep.net/api/institutions/908873'},
#    'urls': [{'value': 'http://www.fhwn.ac.at/'}],
#    '$schema': 'https://inspirehep.net/schemas/records/institutions.json',
#    'legacy_ICN': 'Fachhochsch., Wiener Neustadt',
#    'control_number': 908873,
#    'legacy_version': '20130819034638.0',
#    'legacy_creation_date': '2002-08-05',
#    'external_system_identifiers': [{'value': 'INST-75442',
#      'schema': 'SPIRES'}]},
#   'links': {'json': 'https://inspirehep.net/api/institutions/908873?format=json'},
#   'id': '908873'}]

# %%
for institution in institution_link.json().get('hits').get('hits'):
    print(institution.get('metadata').get('legacy_ICN'))
# Out:
# Unlisted, AT
# ELIN, Weiz
# Seibersdorf, Reaktorzentrum
# Joanneum Research, Graz
# Austrian Inst. Tech., Seibersdorf
# MedAustron
# Graz, Tech. U.
# VCPC, Vienna
# Vienna, Inst. Radium. Kernphys.
# Fachhochsch., Wiener Neustadt

# %% [markdown]
# #### better list comprehension

# %%
[institution.get('metadata').get('legacy_ICN') for institution in institution_link.json().get('hits').get('hits')]
# Out:
# ['Unlisted, AT',
#  'ELIN, Weiz',
#  'Seibersdorf, Reaktorzentrum',
#  'Joanneum Research, Graz',
#  'Austrian Inst. Tech., Seibersdorf',
#  'MedAustron',
#  'Graz, Tech. U.',
#  'VCPC, Vienna',
#  'Vienna, Inst. Radium. Kernphys.',
#  'Fachhochsch., Wiener Neustadt']

# %%
institution_link.json().get('hits').get('hits')[5]
# Out:
# {'created': '2022-08-18T09:27:25.897794+00:00',
#  'updated': '2022-08-18T09:31:43.447818+00:00',
#  'metadata': {'addresses': [{'cities': ['Wiener Neustadt'],
#     'postal_code': '2700',
#     'country_code': 'AT',
#     'postal_address': ['Marie Curie-Strasse 5'],
#     'country': 'Austria'}],
#   'number_of_papers': 1,
#   'ICN': ['MedAustron'],
#   'self': {'$ref': 'https://inspirehep.net/api/institutions/2137098'},
#   'urls': [{'value': 'https://www.medaustron.at/'}],
#   '$schema': 'https://inspirehep.net/api/schemas/records/institutions.json',
#   'legacy_ICN': 'MedAustron',
#   'control_number': 2137098,
#   'institution_type': ['Research Center'],
#   'external_system_identifiers': [{'value': 'https://ror.org/056nqp360',
#     'schema': 'ROR'}]},
#  'links': {'json': 'https://inspirehep.net/api/institutions/2137098?format=json'},
#  'id': '2137098'}

# %%
legacy_ICN=[d.get('metadata').get('legacy_ICN') for d in institution_link.json().get('hits').get('hits')][2]

# %%
legacy_ICN
# Out:
# 'Seibersdorf, Reaktorzentrum'

# %%
literature_link=f"https://inspirehep.net/api/literature?sort=mostrecent&page=1&q=aff+{legacy_ICN.replace(' ','+')}+and+ac+1->+10"
literature_link
# Out:
# 'https://inspirehep.net/api/literature?sort=mostrecent&page=1&q=aff+Seibersdorf,+Reaktorzentrum+and+ac+1->+10'

# %%
literature_link=requests.get(literature_link)

# %%
literature_link.status_code
# Out:
# 200

# %%
literature_link.json().get('hits').get('hits')
# Out:
# [{'links': {'bibtex': 'https://inspirehep.net/api/literature/1860247?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/1860247?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/1860247?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/1860247?format=json',
#    'cv': 'https://inspirehep.net/api/literature/1860247?format=cv',
#    'citations': 'https://inspirehep.net/api/literature/?q=refersto%3Arecid%3A1860247'},
#   'id': '1860247',
#   'updated': '2021-06-25T13:49:36.126815+00:00',
#   'created': '2021-04-23T00:00:00+00:00',
#   'metadata': {'citation_count': 1,
#    'citation_count_without_self_citations': 0,
#    'authors': [{'raw_affiliations': [{'value': 'Austrian Academy of Sciences (AT)'}],
#      'full_name_unicode_normalized': 'hoch, michael',
#      'full_name': 'Hoch, Michael',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/1005850'},
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Hoch.1'}],
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'last_name': 'Hoch',
#      'bai': 'M.Hoch.1',
#      'signature_block': 'HACHm',
#      'uuid': '5a819715-50c5-4681-8a1a-5335ab45c470',
#      'first_name': 'Michael',
#      'recid': 1005850}],
#    'documents': [{'filename': 'PoS(ICHEP2020)946.pdf',
#      'attachment': {'content': 'P\no\nS\n(\nI\nC\nH\nE\nP\n2\n0\n2\n0\n)\n9\n4\n6\n\n \n\n\uf0e3 Copyright owned by the author(s) under the terms of the Creative Commons \nAttribution-NonCommercial-NoDerivatives 4.0 International License (CC BY-NC-ND 4.0). https://pos.sissa.it/ \n\nCultural Collisions, a cross disciplinary science education format \n\nMichael Hoch \n\nHEPHY, Austrian Academy of Science (AT), \n\nNikolsdorfergasse 18, 1050 Vienna, Austria \n\nE-mail: Michael.Hoch@cern.ch \n\n \n\n \n\n“Cultural Collisions” is a cross-disciplinary science and art engagement and networking program with \n\nspecial emphasis on educational methodologies. It is designed to trigger curiosity, creativity, and foster \n\ncritical thinking in school students to help them overcome the scientific and technological challenges of \n\nthe 21st century. \n\n \n\nThe Cultural Collisions format has been implemented and tested in several European countries - Austria, \n\nGermany, Switzerland, Montenegro and recently in the Czech Republic. During ICHEP2020 the final \n\nstudent artworks of Cultural Collisions Czech will be presented. Furthermore, it was the key component \n\nof a research project sponsored by the Ontario Ministry of Education, Canada, which assessed the \n\neducational impact on participating students. In the presentation, cross-disciplinary methodologies will be \n\ndiscussed and results will be presented. The evaluation shows that the programme demonstrated its \n\ncapacity to increase motivation and interest in science via creative science engagement and increased the \n\neducational outcome. \n\n \n\nThe format was developed and evaluated within the EU funded project CREATIONS, the CMS \n\nexperiment at CERN and recently by the ORIGIN collaboration. ORIGIN is a cooperation of scientific \n\ncollaborations working on the secrets of the origin of the universe in the fields of particle physics, \n\ngravitational waves, neutrino physics, cosmology and astrophysics, which supports interdisciplinary \n\nscience engagement. \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n \n\n \n\n \n\n \n\n \n\n40th International Conference on High Energy physics - ICHEP2020 \n\nJuly 28 - August 6, 2020 \n\nPrague, Czech Republic (virtual meeting)\n\nhttp://pos.sissa.it/\nhttp://pos.sissa.it/\nhttp://pos.sissa.it/\nmailto:Michael.Hoch@cern.ch\n\n\nP\no\nS\n(\nI\nC\nH\nE\nP\n2\n0\n2\n0\n)\n9\n4\n6\n\nCultural Collisions, a cross-disciplinary science education format M.Hoch \n\n2 \n\n1. Introduction \n\nCultural Collisions is an innovative, interdisciplinary experience designed for teachers \n\nand students to explore the possibilities for learning when the arts and sciences are integrated. As \n\na means of reconceptualising traditional models of interdisciplinary education, Cultural Collisions \n\nfacilitates combining multiple perspectives between the arts and science in order to create an \n\nenvironment where thinking and learning transform into merging perspectives, strategies, tools \n\nand skills in order to discover the science in art and the art in science. \n\nCultural Collisions is an education and networking format that allows students to gain \n\nauthentic and personal access to scientific fields and scientific communities while they  are \n\napproaching complex topics through artistic practices. By contact and networking with people \n\nwho are active in the respective fields, a lasting impact is generated for all participants involved. \n\nThe overall goal is to present science as a creative activity and the arts as a serious examination \n\nof the subject matter.  \n\n \n\nScience&Art@School is a cross disciplinary science and art education project format which was \n\nintroduced in 2013 for Austrian schools in Graz and Vienna. It is the predecessor format from \n\nwhich Cultural Collisons developed and was presented at the 14th ICATPP conference [1]. Both \n\nformats have been developed at CERN by the international particle physics c ...
#      'fulltext': True,
#      'source': 'PoS',
#      'key': '3f7f380ea4363e364b38d99e7f8c7304',
#      'url': 'https://inspirehep.net/files/3f7f380ea4363e364b38d99e7f8c7304'}],
#    'publication_info': [{'journal_volume': 'ICHEP2020',
#      'artid': '946',
#      'conference_record': {'$ref': 'https://inspirehep.net/api/conferences/1677252'},
#      'year': 2021,
#      'journal_record': {'$ref': 'https://inspirehep.net/api/journals/1213080'},
#      'page_start': '946',
#      'journal_title': 'PoS',
#      'parent_record': {'$ref': 'https://inspirehep.net/api/literature/1859861'},
#      'cnum': 'C20-07-30'}],
#    'citeable': True,
#    '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#    'references': [{'reference': {'label': '1',
#       'publication_info': {'year': 2013},
#       'title': {'title': 'ART@CMS and SCIENCE&ART@SCHOOL: Novel Education and Communication Channels for Particle Physics'},
#       'misc': ['Proceedings of the 14th ICATPP Conference, Vol.1 728-736'],
#       'authors': [{'full_name': 'Hoch, M.'}]}},
#     {'reference': {'label': '2',
#       'publication_info': {'year': 2016},
#       'title': {'title': 'art@CMS SciArt Workshops'},
#       'misc': ['38th International Conference on High Energy Physics, Chicago, 3-10 August'],
#       'authors': [{'full_name': 'Hoch, M.'},
#        {'full_name': 'Alexopoulos, A.'},
#        {'full_name': 'Preece, S.'},
#        {'full_name': 'Storr, M.'},
#        {'full_name': 'Petrilli, A.'}]}},
#     {'reference': {'label': '3',
#       'publication_info': {'year': 2020},
#       'misc': ['HEU funded project CREATIONS - Developing an Engaging Science Classroom']}},
#     {'reference': {'urls': [{'value': 'http://creations-project.eu/'}],
#       'label': '3'}},
#     {'reference': {'label': '4',
#       'publication_info': {'year': 2016},
#       'title': {'title': 'STEAM: Education and Communication with Art at ATLAS and CMS'},
#       'misc': ['LHCP Fourth Annual LHCP conference. Lund, June 13-18 June'],
#       'authors': [{'full_name': 'Paolucci, P.'},
#        {'full_name': 'Alexopoulos, A.'},
#        {'full_name': 'M., Hoch.'},
#        {'full_name': 'Adam-Bourdarios, C.'}]}},
#     {'reference': {'label': '5',
#       'publication_info': {'year': 2015},
#       'title': {'title': 'ATLAS and CMS Virtual Visits: Bringing Cutting Edge Science into the Classroom and Beyond'},
#       'misc': ['The EPSConference on High Energy Physics, Vienna 22-29 July'],
#       'authors': [{'full_name': 'L., Aguirre'},
#        {'full_name': 'C., Adam-Bourdarios'},
#        {'full_name': 'A., Alexopoulos'},
#        {'full_name': 'N., Beni'},
#        {'full_name': 'S., Goldfarb'},
#        {'full_name': 'M., Hoch'},
#        {'full_name': 'M., Lapka'},
#        {'full_name': 'A., Petrilli'},
#        {'full_name': 'Z., Zsillasi'}]}}],
#    'number_of_pages': 5,
#    'legacy_version': '20210423183814.0',
#    'inspire_categories': [{'term': 'Other'}],
#    'legacy_creation_date': '2021-04-23',
#    'author_count': 1,
#    'first_author': {'full_name': 'Hoch, Michael',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Hoch.1'}],
#     'last_name': 'Hoch',
#     'first_name': 'Michael',
#     'recid': 1005850},
#    'control_number': 1860247,
#    'dois': [{'source': 'SISSA', 'value': '10.22323/1.390.0946'}],
#    'earliest_date': '2021-01-20',
#    'document_type': ['conference paper'],
#    'texkeys': ['Hoch:2021vlp'],
#    'abstracts': [{'source': 'SISSA',
#      'value': '“Cultural Collisions” is a cross-disciplinary science and art engagement and networking program with special emphasis on educational methodologies. It is designed to trigger curiosity, creativity, and foster critical thinking in school students to help them overcome the scientific and technological challenges of the 21st century.The Cultural Collisions format has been implemented and tested in several European countries - Austria, Germany, Switzerland, Montenegro and recently in the Czech Republic. During ICHEP2020 the final student artworks of Cultural Collisions Czech will be presented. Furthermore, it was the key component of a research project sponsored by the Ontario Ministry of Education, Canada, which assessed the educational impact on participating students. In the presentation, cross-disciplinary methodologies will be discussed and results will be presented. The evaluation shows that the programme demonstrated its capacity to increase motivation and interest in science via creative science engagement and increased the educational outcome.The format was developed and evaluated within the EU funded project CREATIONS, the CMS experiment at CERN and recently by the ORIGIN collaboration. ORIGIN is a cooperation of scientific collaborations working on the secrets of the origin of the universe in the fields of particle physics, gravitational waves, neutrino physics, cosmology and astrophysics, which supports interdisciplinary science engagement.',
#      'abstract_source_suggest': {'input': 'SISSA'}}],
#    'titles': [{'source': 'SISSA',
#      'title': 'Cultural Collisions, a cross disciplinary science education format'}],
#    'facet_author_name': ['1005850_Michael Hoch'],
#    'license': [{'license': 'CC-BY-NC-ND-4.0', 'imposing': 'SISSA'}],
#    'imprints': [{'date': '2021-01-20', 'publisher': 'SISSA'}],
#    'curated': False,
#    'journal_title_variants': ['PoS']}},
#  {'links': {'bibtex': 'https://inspirehep.net/api/literature/788228?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/788228?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/788228?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/788228?format=json',
#    'cv': 'https://inspirehep.net/api/literature/788228?format=cv',
#    'citations': 'https://inspirehep.net/api/literature/?q=refersto%3Arecid%3A788228'},
#   'id': '788228',
#   'updated': '2021-06-25T16:14:47.473807+00:00',
#   'created': '2008-06-15T00:00:00+00:00',
#   'metadata': {'citation_count': 7,
#    'citation_count_without_self_citations': 6,
#    'authors': [{'full_name_unicode_normalized': 'tajmar, m.',
#      'full_name': 'Tajmar, M.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/986853'},
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#      'last_name': 'Tajmar',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'bai': 'M.Tajmar.1',
#      'signature_block': 'TAJNARm',
#      'first_name': 'M.',
#      'uuid': 'f0e38530-2f8a-415c-a0f7-77f6f744e22c',
#      'recid': 986853},
#     {'full_name_unicode_normalized': 'plesescu, f.',
#      'full_name': 'Plesescu, F.',
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'F.Plesescu.1'}],
#      'last_name': 'Plesescu',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'bai': 'F.Plesescu.1',
#      'signature_block': 'PLASASCf',
#      'first_name': 'F.',
#      'uuid': '87e45f98-adf9-46ed-b291-fcc72617dafb'},
#     {'full_name_unicode_normalized': 'seifert, b.',
#      'full_name': 'Seifert, B.',
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'B.Seifert.1'}],
#      'last_name': 'Seifert',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'bai': 'B.Seifert.1',
#      'signature_block': 'SAFADb',
#      'first_name': 'B.',
#      'uuid': '7e6fc856-08c7-4770-a36b-ff23d7b8a707'}],
#    'publication_info': [{'journal_volume': '150',
#      'artid': '032101',
#      'conference_record': {'$ref': 'https://inspirehep.net/api/conferences/979331'},
#      'year': 2009,
#      'journal_record': {'$ref': 'https://inspirehep.net/api/journals/1212279'},
#      'journal_title': 'J.Phys.Conf.Ser.',
#      'parent_record': {'$ref': 'https://inspirehep.net/api/literature/878877'},
#      'cnum': 'C08-08-06'},
#     {'conference_record': {'$ref': 'https://inspirehep.net/api/conferences/979331'},
#      'cnum': 'C08-08-06'}],
#    'citeable': True,
#    '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#    'references': [{'reference': {'publication_info': {'journal_volume': '331',
#        'artid': '958',
#        'page_start': '958',
#        'journal_title': 'Nature'}}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0612103',
#       'publication_info': {'journal_volume': '76',
#        'artid': '061101',
#        'journal_title': 'Phys.Rev.D'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/734809'}},
#     {'reference': {'publication_info': {'journal_volume': '98',
#        'artid': '081101',
#        'journal_title': 'Phys.Rev.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/747576'}},
#     {'reference': {'publication_info': {'journal_volume': '70',
#        'artid': '701',
#        'page_start': '701',
#        'journal_title': 'Phys.Rev.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/370742'}},
#     {'reference': {'publication_info': {'journal_volume': '30',
#        'artid': '130',
#        'page_start': '130',
#        'journal_title': 'Phys.Rev.D'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/14419'}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0203033',
#       'publication_info': {'journal_volume': '385',
#        'artid': '551',
#        'page_start': '551',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/583909'}},
#     {'reference': {'publication_info': {'journal_volume': '420',
#        'artid': '56',
#        'page_start': '56',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/651508'}},
#     {'reference': {'publication_info': {'journal_volume': '432',
#        'artid': '167',
#        'page_start': '167',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/711372'}},
#     {'reference': {'publication_info': {'journal_volume': '62',
#        'artid': '845',
#        'page_start': '845',
#        'journal_title': 'Phys.Rev.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/294104'}},
#     {'reference': {'publication_info': {'journal_volume': '42',
#        'artid': '7885',
#        'page_start': '7885',
#        'journal_title': 'Phys.Rev.B'}}},
#     {'reference': {'publication_info': {'journal_volume': '372',
#        'artid': '2496',
#        'page_start': '2496',
#        'journal_title': 'Phys.Lett.A'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/784305'}},
#     {'reference': {'arxiv_eprint': '0709.2373'},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/760898'}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0603033'},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/712065'}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0610015',
#       'publication_info': {'journal_volume': '880',
#        'artid': '1071',
#        'page_start': '1071',
#        'journal_title': 'AIP Conf.Proc.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/727915'}},
#     {'reference': {'publication_info': {'journal_volume': '969',
#        'artid': '1080',
#        'page_start': '1080',
#        'journal_title': 'AIP Conf.Proc.'}}},
#     {'reference': {'publication_info': {'journal_volume': '468',
#        'artid': '383',
#        'page_start': '383',
#        'journal_title': 'Physica C'}}}],
#    'number_of_pages': 8,
#    'legacy_creation_date': '2008-06-15',
#    'preprint_date': '2008-06',
#    'author_count': 3,
#    'earliest_date': '2008-06',
#    'external_system_identifiers': [{'schema': 'ADS',
#      'value': '2009JPhCS.150c2101T'},
#     {'schema': 'SPIRES', 'value': 'SPIRES-7787626'}],
#    'facet_author_name': ['986853_Martin Tajmar',
#     'NOREC_F. Plesescu',
#     'NOREC_B. Seifert'],
#    'core': True,
#    'journal_title_variants': ['J. Phys. Conf. Ser.', 'J.Phys.Conf.Ser.'],
#    'arxiv_eprints': [{'categories': ['gr-qc'], 'value': '0806.2271'}],
#    'referenced_authors_bais': ['A.J.Silenko.1',
#     'A.Pulido.Paton.1',
#     'B.Cabrera.2',
#     'B.Seifert.1',
#     'C.Beck.4',
#     'C.C.Speake.1',
#     'C.Jacinto.de.Matos.1',
#     'C.J.de.Matos.1',
#     'C.Trenkel.1',
#     'Daniel.Brandt.1',
#     'D.J.Raine.1',
#     'F.A.Wilczek.1',
#     'F.Plesescu.1',
#     'G.D.Hammond.1',
#     'G.Fraser.1',
#     'G.T.Gillies.1',
#     'J.E.Moody.1',
#     'J.M.Anderson.1',
#     'J.Tate.1',
#     'K.Marhold.1',
#     'L.I.Winkler.1',
#     'M.Tajmar.1',
#     'O.V.Teryaev.1',
#     'R.C.Ritter.1',
#     'S.B.Felch.1'],
#    'legacy_version': '20161205114123.0',
#    'inspire_categories': [{'term': 'Gravitation and Cosmology'}],
#    'first_author': {'full_name': 'Tajmar, M.',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#     'last_name': 'Tajmar',
#     'first_name': 'M.',
#     'recid': 986853},
#    'control_number': 788228,
#    'dois': [{'value': '10.1088/1742-6596/150/3/032101'}],
#    'document_type': ['conference paper'],
#    'texkeys': ['Tajmar:2008aj'],
#    'abstracts': [{'source': 'arXiv',
#      'value': "Precision fiber optic gyroscopes were mounted mechanically de-coupled above spinning rings inside a cryostat. Below a critical temperature (typically <30 K), the gyroscopes measure a significant deviation from their usual Earth rotation offset proportional to the applied angular ring velocity with maximum signals towards lower temperatures. The anomalous gyroscope signal is about 8 orders of magnitude smaller then the applied angular ring velocity, compensating about one third of the Earth rotation offset at an angular top speed of 420 rad/s. Moreover, our data shows a parity violation as the effect appears to be dominant for rotation against the Earth's spin. No systematic effect was found to explain this effect including the magnetic environment, vibration and helium gas friction suggesting that our observation is a new low temperature phenomenon. Tests in various configurations suggest that the anomalous signals is originating from the rotating helium in our facilities.",
#      'abstract_source_suggest': {'input': 'arXiv'}}],
#    'primary_arxiv_category': ['gr-qc'],
#    'titles': [{'title': 'Anomalous Fiber Optic Gyroscope Signals Observed above Spinning Rings at Low Temperature'},
#     {'source': 'arXiv',
#      'title': 'Anomalous Fiber Optic Gyroscope Signals Observed above Spinning Rings at Low Temperature'}],
#    'curated': True}},
#  {'links': {'bibtex': 'https://inspirehep.net/api/literature/808498?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/808498?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/808498?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/808498?format=json',
#    'cv': 'https://inspirehep.net/api/literature/808498?format=cv',
#    'citations': 'https://inspirehep.net/api/literature/?q=refersto%3Arecid%3A808498'},
#   'id': '808498',
#   'updated': '2021-06-26T00:33:03.487207+00:00',
#   'created': '2009-02-20T00:00:00+00:00',
#   'metadata': {'citation_count': 1,
#    'citation_count_without_self_citations': 0,
#    'authors': [{'full_name_unicode_normalized': 'agosteo, s.',
#      'full_name': 'Agosteo, S.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/1423542'},
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/903394'},
#        'value': 'Milan Polytechnic'},
#       {'record': {'$ref': 'https://inspirehep.net/api/institutions/902882'},
#        'value': 'INFN, Milan'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'S.Agosteo.1'}],
#      'last_name': 'Agosteo',
#      'bai': 'S.Agosteo.1',
#      'signature_block': 'AGASTs',
#      'first_name': 'S.',
#      'uuid': '920b4ef2-cdd4-46bc-8035-f4a6ce1b7994',
#      'recid': 1423542},
#     {'full_name_unicode_normalized': 'rollet, s.',
#      'full_name': 'Rollet, S.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/991382'},
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'S.Rollet.1'}],
#      'last_name': 'Rollet',
#      'bai': 'S.Rollet.1',
#      'signature_block': 'RALATs',
#      'first_name': 'S.',
#      'uuid': 'da58ffee-9fd4-40f3-b3af-8de09d6289f3',
#      'recid': 991382},
#     {'full_name_unicode_normalized': 'silari, m.',
#      'full_name': 'Silari, M.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/988706'},
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/902725'},
#        'value': 'CERN'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Silari.1'}],
#      'last_name': 'Silari',
#      'bai': 'M.Silari.1',
#      'signature_block': 'SALARm',
#      'first_name': 'M.',
#      'uuid': 'c1d51998-4c6b-4c52-ad17-f8da7a55debb',
#      'recid': 988706},
#     {'full_name_unicode_normalized': 'theis, c.',
#      'full_name': 'Theis, C.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/986256'},
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/902725'},
#        'value': 'CERN'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'C.Theis.1'}],
#      'last_name': 'Theis',
#      'bai': 'C.Theis.1',
#      'signature_block': 'Tc',
#      'first_name': 'C.',
#      'uuid': '154befd1-49cf-40a4-8a27-cb7b029e59d3',
#      'recid': 986256}],
#    'publication_info': [{'journal_volume': '43',
#      'page_end': '1032',
#      'year': 2008,
#      'journal_record': {'$ref': 'https://inspirehep.net/api/journals/1212967'},
#      'page_start': '1024',
#      'journal_title': 'Radiat.Meas.'}],
#    'citeable': True,
#    '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#    'keywords': [{'source': 'author', 'value': 'Dosimetry'},
#     {'source': 'author', 'value': 'Proton accelerator'},
#     {'source': 'author', 'value': 'Ionization chamber'},
#     {'source': 'author', 'value': 'Bubble detector'},
#     {'source': 'author', 'value': 'Tissue equivalent proportional counter'},
#     {'source': 'author', 'value': 'Silicon microdosimeter'},
#     {'source': 'author', 'value': 'Calibration'},
#     {'source': 'author', 'value': 'Monte Carlo'},
#     {'schema': 'INSPIRE', 'value': 'p: accelerator'},
#     {'schema': 'INSPIRE', 'value': 'dosimetry'},
#     {'schema': 'INSPIRE', 'value': 'calibration'},
#     {'schema': 'INSPIRE', 'value': 'ionization chamber'},
#     {'schema': 'INSPIRE', 'value': 'sensitivity'},
#     {'schema': 'INSPIRE', 'value': 'monitoring'},
#     {'schema': 'INSPIRE', 'value': 'silicon'},
#     {'schema': 'INSPIRE', 'value': 'detector: bubble'},
#     {'schema': 'INSPIRE', 'value': 'numerical calculations: Monte Carlo'}],
#    'references': [{'reference': {'report_numbers': ['DOCUMENTA/2005002']}},
#     {'reference': {'publication_info': {'journal_volume': '297',
#        'artid': '250',
#        'page_start': '250',
#        'journal_title': 'Nucl.Instrum.Meth.A'}}},
#     {'reference': {'publication_info': {'journal_volume': '324',
#        'artid': '232',
#        'page_start': '232',
#        'journal_title': 'Nucl.Instrum.Meth.A'}}},
#     {'reference': {'publication_info': {'journal_volume': '184',
#        'artid': '229',
#        'page_start': '229',
#        'journal_title': 'Nucl.Instrum.Meth.B'}}},
#     {'reference': {'report_numbers': ['ECONFC/0303241']}},
#     {'reference': {'arxiv_eprint': 'hep-ph/0306267',
#       'publication_info': {'journal_volume': 'C0303241',
#        'artid': 'MOMT005',
#        'journal_title': 'eConf'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/622230'}},
#     {'reference': {'publication_info': {'journal_volume': '27',
#        'artid': '1',
#        'page_start': '1',
#        'journal_title': 'Nucl.Tracks Radiat.Meas.'}}},
#     {'reference': {'publication_info': {'journal_volume': '63',
#        'artid': '529',
#        'page_start': '529',
#        'journal_title': 'Int.J.Appl.Radiat.Isotopes'}}},
#     {'reference': {'publication_info': {'journal_volume': '432',
#        'artid': '1',
#        'page_start': '1',
#        'journal_title': 'Nucl.Instrum.Meth.A'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/508811'}},
#     {'reference': {'publication_info': {'journal_volume': '426',
#        'artid': '436',
#        'page_start': '436',
#        'journal_title': 'Nucl.Instrum.Meth.A'}}},
#     {'reference': {'publication_info': {'journal_volume': '162',
#        'artid': '603',
#        'page_start': '603',
#        'journal_title': 'Nucl.Instrum.Meth.'}}}],
#    'number_of_pages': 9,
#    'legacy_creation_date': '2009-02-20',
#    'preprint_date': '2008',
#    'author_count': 4,
#    'earliest_date': '2008',
#    'refereed': True,
#    'external_system_identifiers': [{'schema': 'CDS', 'value': '1069446'},
#     {'schema': 'SPIRES', 'value': 'SPIRES-8184232'}],
#    'facet_author_name': ['986256_Christian Theis',
#     '988706_Marco Silari',
#     '991382_Sofia Rollet',
#     '1423542_Stefano Giulini Castiglioni Agosteo'],
#    'core': True,
#    'journal_title_variants': ['Radiat.Meas.', 'Radiat. Meas.'],
#    'referenced_authors_bais': ['A.Empl.1',
#     'A.Fasso.1',
#     'Anna.Ferrari.1',
#     'A.Ottolenghi.1',
#     'E.Gadioli.2',
#     'Fabio.Cerutti.1',
#     'F.Ballarini.1',
#     'G.Battistoni.1',
#     'J.C.Gaborit.1',
#     'J.Ranft.1',
#     'L.Ulrici.1',
#     'M.Silari.1',
#     'M.V.Garzelli.2',
#     'P.Sala.2',
#     'S.Agosteo.1',
#     'S.Roesler.1'],
#    'legacy_version': '20210120170201.0',
#    'inspire_categories': [{'term': 'Instrumentation'}],
#    'first_author': {'full_name': 'Agosteo, S.',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'S.Agosteo.1'}],
#     'last_name': 'Agosteo',
#     'first_name': 'S.',
#     'recid': 1423542},
#    'control_number': 808498,
#    'dois': [{'value': '10.1016/j.radmeas.2007.10.010'}],
#    'document_type': ['conference paper'],
#    'texkeys': ['Agosteo:2008zz'],
#    'abstracts': [{'source': 'Elsevier',
#      'value': 'Radiation dosimetry at high-energy proton accelerators is a difficult task because of the complexity of the stray radiation field. A good knowledge of this mixed radiation field is very important to be able to select the type of detectors (active and/or passive) to be employed for routine area monitoring and to choose the personal dosimeter legally required for estimating the effective dose received by individuals. At the same time, the response function of the detectors to the mixed field must be thoroughly understood. A proper calibration of a device, which may involve a complex series of measurements in various reference fields, is needed. Monte Carlo simulations provide a complementary—and sometimes the principal—mean of determining the response function. The ambient dose equivalent rates during operation range from a few hundreds of\nμ\nSv\nper year to a few mSv per year. To measure such rates one needs detectors of high sensitivity and/or capable of integrating over long periods.\n\nThe main challenges to be met by a radiation monitoring system are the capability of discriminating the various radiation types, of correctly measuring the high-energy part of the neutron energy distribution—often responsible for a large fraction of the total ambient dose equivalent—and of operating in the pulsed field sometimes encountered around high-energy accelerators. The paper first briefly reviews the most relevant techniques and then concentrates on a few devices pointing to some recent results and developments: the tissue equivalent proportional counter, the silicon-based microdosimeter, the superheated drop detector and high-pressure argon- and hydrogen-filled ionization chambers to be employed for the radiological surveillance of the Large Hadron Collider at CERN. Examples and comparisons between measurements and Monte Carlo predictions are given.',
#      'abstract_source_suggest': {'input': 'Elsevier'}}],
#    'titles': [{'title': 'Dosimetry in radiation fields around high-energy proton accelerators'}],
#    'curated': True}},
#  {'links': {'bibtex': 'https://inspirehep.net/api/literature/756680?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/756680?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/756680?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/756680?format=json',
#    'cv': 'https://inspirehep.net/api/literature/756680?format=cv',
#    'citations': 'https://inspirehep.net/api/literature/?q=refersto%3Arecid%3A756680'},
#   'id': '756680',
#   'updated': '2021-10-06T22:52:24.738586+00:00',
#   'created': '2007-07-25T00:00:00+00:00',
#   'metadata': {'citation_count': 3,
#    'citation_count_without_self_citations': 3,
#    'authors': [{'full_name_unicode_normalized': 'tajmar, m.',
#      'full_name': 'Tajmar, M.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/986853'},
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#      'last_name': 'Tajmar',
#      'bai': 'M.Tajmar.1',
#      'signature_block': 'TAJNARm',
#      'uuid': 'b4993844-af94-4b33-93a4-24933bdd4c76',
#      'first_name': 'M.',
#      'recid': 986853},
#     {'full_name_unicode_normalized': 'plesescu, f.',
#      'full_name': 'Plesescu, F.',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'F.Plesescu.1'}],
#      'last_name': 'Plesescu',
#      'bai': 'F.Plesescu.1',
#      'signature_block': 'PLASASCf',
#      'uuid': 'c1a8676a-fdd6-4b0e-ad11-aeb54226982c',
#      'first_name': 'F.'},
#     {'full_name_unicode_normalized': 'seifert, b.',
#      'full_name': 'Seifert, B.',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'B.Seifert.1'}],
#      'last_name': 'Seifert',
#      'bai': 'B.Seifert.1',
#      'signature_block': 'SAFADb',
#      'uuid': 'fce77650-c4ae-4873-bd9c-77c7f94bd6aa',
#      'first_name': 'B.'},
#     {'full_name_unicode_normalized': 'schnitzer, r.',
#      'full_name': 'Schnitzer, R.',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'R.Schnitzer.1'}],
#      'last_name': 'Schnitzer',
#      'bai': 'R.Schnitzer.1',
#      'signature_block': 'SNATSARr',
#      'uuid': 'ec61061d-128c-42b7-91df-d8da4d3d0632',
#      'first_name': 'R.'},
#     {'full_name_unicode_normalized': 'vasiljevich, i.',
#      'full_name': 'Vasiljevich, I.',
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'I.Vasiljevich.1'}],
#      'last_name': 'Vasiljevich',
#      'bai': 'I.Vasiljevich.1',
#      'signature_block': 'VASALJAFACHi',
#      'uuid': '74ffe204-5cc2-4748-a4b8-a99346babf7c',
#      'first_name': 'I.'}],
#    'citeable': True,
#    '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#    'keywords': [{'schema': 'PACS', 'value': '04.80.-y'},
#     {'schema': 'PACS', 'value': '04.40.Nr'},
#     {'schema': 'PACS', 'value': '74.62.Yb'},
#     {'source': 'author', 'value': 'Gravitomagnetism'},
#     {'source': 'author', 'value': 'London Moment'}],
#    'references': [{'reference': {'title': {'title': 'Millikan Oil Drops as Quantum Transducers between Electromagnetic and Gravitational Radiation'},
#       'misc': ['(2007)'],
#       'authors': [{'full_name': 'Chiao, R.Y.'}]}},
#     {'reference': {'urls': [{'value': 'http://arxiv.org/abs/gr-qc/0702100v2'}],
#       'misc': ['accessed July 25, 2007']}},
#     {'reference': {'title': {'title': 'Vibration Rectification in Silicon Machined Accelerometers'},
#       'misc': ['in'],
#       'authors': [{'full_name': 'Christel, L.A.'},
#        {'full_name': 'Bernstein, M.'},
#        {'full_name': 'Craddock, R.'},
#        {'full_name': 'Peterson, K.'}]}},
#     {'reference': {'imprint': {'publisher': 'IEEE'},
#       'misc': ['the proceedings of the International Conference on Sensors and Actuators,  Conference Proceedings, San Francisco']}},
#     {'reference': {'misc': ['1991, pp. 89-92']}},
#     {'reference': {'title': {'title': 'A Confirmation of the General Relativistic Prediction of the Lense-Thirring Effect'},
#       'misc': ['Nature 431'],
#       'authors': [{'full_name': 'Ciufolini, I.'},
#        {'full_name': 'Pavlis, E.C.'}]}},
#     {'reference': {'misc': [': 958 (2004) 960']}},
#     {'reference': {'misc': ['Gravitation and Inertia, Princeton University Press, New Jersey, 1995, pp. 365-374'],
#       'authors': [{'full_name': 'Ciufolini, I.'},
#        {'full_name': 'Wheeler, J.A.'}]}},
#     {'reference': {'title': {'title': 'Gravitomagnetic London Moment and the Graviton Mass inside a Superconductor'},
#       'misc': ['Physica;C'],
#       'authors': [{'full_name': 'de Matos, C.J.'},
#        {'full_name': 'Tajmar, M.'}]}},
#     {'reference': {'misc': [': 432 (2005) 167']}},
#     {'reference': {'title': {'title': 'Possible Measurable Effects of Dark Energy in Rotating Superconductors'},
#       'misc': ['(2007)'],
#       'authors': [{'full_name': 'de Matos, C.J.'},
#        {'full_name': 'Beck, C.'}]}},
#     {'reference': {'urls': [{'value': 'http://arxiv.org/abs/0707.1797v1'}],
#       'misc': ['accessed July 25, 2007']}},
#     {'reference': {'title': {'title': 'Advanced Propulsion Systems from Artificial Acceleration Fields'},
#       'misc': ['43rd'],
#       'authors': [{'full_name': 'Dröscher, W.'},
#        {'full_name': 'J., Hauser'}]}},
#     {'reference': {'publication_info': {'journal_volume': '2007',
#        'artid': '5595',
#        'page_start': '5595',
#        'journal_title': 'AIAA J.'},
#       'misc': ['AIAA J./ASME/SAE/ASEE Joint Propulsion Conference and Exhibit, Cincinnati, OH, July 8-11']}},
#     {'reference': {'urls': [{'value': 'http://einstein.stanford.edu/content/aps_posters/APS_talk_Everitt.pdf'}],
#       'title': {'title': 'First Results from Gravity Probe B'},
#       'misc': ['(2007)'],
#       'authors': [{'full_name': 'Everitt, F.'}]}},
#     {'reference': {'misc': ['accessed July 25, 2007']}},
#     {'reference': {'title': {'title': 'General Relativity for the Experimentalist'},
#       'misc': ['Proceedings of the IRE, : 892 (1961) 586'],
#       'authors': [{'full_name': 'Forward, R.L.'}]}},
#     {'reference': {'title': {'title': 'Evidence for Patch Effect Forces on the Gravity Probe B Gyroscopes'},
#       'misc': ['(2007)'],
#       'authors': [{'full_name': 'Gill, D.K.'}, {'full_name': 'Buchman, S.'}]}},
#     {'reference': {'urls': [{'value': 'http://einstein.stanford.edu/content/aps_posters/EvidenceForPatchEffectForces.pdf'}],
#       'misc': ['accessed August 10, 2007']}},
#     {'reference': {'misc': ['"Experiment to Detect Frame-Dragging in a Lead'],
#       'authors': [{'full_name': 'Graham, R.D.'},
#        {'full_name': 'Hurst, R.B.'},
#        {'full_name': 'Thirkettle, R.J.'},
#        {'full_name': 'Rowe, C.H.'},
#        {'full_name': 'Butler, B.H.'}]}},
#     {'reference': {'urls': [{'value': 'http://www2.phys.canterbury.ac.nz/~physrin/papers/SuperFrameDragging2007.pdf'}],
#       'misc': ['Superconductor," (2007), , accessed July']}},
#     {'reference': {'misc': ['25, 2007']}},
#     {'reference': {'misc': ['"Anomalous Weight Reduction on a Gyroscope’s Right Rotations around the Vertical Axis on'],
#       'authors': [{'full_name': 'Hayasaka, H.'},
#        {'full_name': 'Tageuchi, S.'}]}},
#     {'reference': {'publication_info': {'journal_volume': '63',
#        'artid': '2701',
#        'page_start': '2701',
#        'journal_title': 'Phys.Rev.Lett.'},
#       'misc': ['the Earth,"']},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/294121'}},
#     {'reference': {'misc': ['"Possibility for the Existence of Anti-Gravity Evidance'],
#       'authors': [{'full_name': 'Hayasaka, H.'},
#        {'full_name': 'Tanaka, H.'},
#        {'full_name': 'Hashida, T.'},
#        {'full_name': 'Chubachi, T.'},
#        {'full_name': 'Sugiyama, T.'}]}},
#     {'reference': {'publication_info': {'journal_volume': '20',
#        'artid': '173',
#        'page_start': '173',
#        'journal_title': 'Speculations Sci.Tech.'},
#       'misc': ['from a Free-Fall Experiment using a Spinning Gyro,"']}},
#     {'reference': {'title': {'title': 'Rotating Superconductors and the London Moment Thermodynamics versus Microscopics'},
#       'misc': ['Physical'],
#       'authors': [{'full_name': 'Jiang, Y.'}, {'full_name': 'Liu, M.'}]}},
#     {'reference': {'misc': [': 63 (2001) 184506'],
#       'authors': [{'full_name': 'B, Review'}]}},
#     {'reference': {'misc': ['"The Expected Performance of the Gravity'],
#       'authors': [{'full_name': 'Keiser, G.M.'},
#        {'full_name': 'Buchman, S.'},
#        {'full_name': 'Bencze, W.'},
#        {'full_name': 'DeBra, D.B.'}]}},
#     {'reference': {'misc': ['Electrically'],
#       'authors': [{'full_name': 'B, Probe'}]}},
#     {'reference': {'misc': ['Suspended Gyroscopes as Differential Accelerometers," in the proceedings of Second International LISA Symposium on the']}},
#     {'reference': {'misc': ['Detection and Observation of Gravitational Waves in Space, , AIP Conf.Proc. 456'],
#       'authors': [{'full_name': 'Folkner, W.M.'}]}},
#     {'reference': {'misc': ['Melville, New York, 1998, pp. 188-198']}},
#     {'reference': {'misc': ['"Calculation of the Viscosity of Gaseous He3'],
#       'authors': [{'full_name': 'Keller, W.E.'}]}},
#     {'reference': {'misc': ['and He4']}},
#     {'reference': {'publication_info': {'journal_volume': '105',
#        'artid': '41',
#        'page_start': '41',
#        'journal_title': 'Phys.Rev.'},
#       'misc': ['at Low Temperatures,"']}},
#     {'reference': {'label': '1957'}},
#     {'reference': {'misc': ['"Null Result for Violation of the Equivalence Principle with Free-Fall Rotating'],
#       'authors': [{'full_name': 'Luo, J.'},
#        {'full_name': 'Nie, Y.X.'},
#        {'full_name': 'Zhang, Y.X.'},
#        {'full_name': 'Zhou, Z.B.'}]}},
#     {'reference': {'misc': ['Gyroscopes," Phys.Rev. D, : 65 (2002) 42005']}},
#     {'reference': {'publication_info': {'journal_volume': '81',
#        'artid': '3223',
#        'page_start': '3223',
#        'journal_title': 'Phys.Rev.Lett.'},
#       'title': {'title': 'Rotating Superconductors and the Frame-Independent London Equation'},
#       'authors': [{'full_name': 'Liu, M.'}]},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/493207'}},
#     {'reference': {'label': '1998'}},
#     {'reference': {'misc': ['Muhlfelder., B., private communication, (2007)']}},
#     {'reference': {'misc': ['"On the Detectability of the Lense-Thirring Field from Rotating Laboratory'],
#       'authors': [{'full_name': 'Stedman, G.E.'},
#        {'full_name': 'Schreiber, K.U.'},
#        {'full_name': 'Bilger, H.R.'}]}},
#     {'reference': {'publication_info': {'journal_volume': '20',
#        'artid': '2527',
#        'page_start': '2527',
#        'journal_title': 'Class.Quant.Grav.'},
#       'misc': ['Masses using Ring Laser Gyroscope Interferometers,"']},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/623433'}},
#     {'reference': {'title': {'title': 'Gravitomagnetic Field of a Rotating Superconductor and of a Rotating Superfluid'},
#       'misc': ['Physica;C'],
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'de Matos, C.J.'}]}},
#     {'reference': {'misc': [': 385 (2003) 551']}},
#     {'reference': {'title': {'title': 'Extended Analysis of Gravitomagnetic Fields in Rotating Superconductors and Superfluids'},
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'de Matos, C.J.'}]}},
#     {'reference': {'publication_info': {'journal_volume': '420',
#        'artid': '56',
#        'page_start': '56',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/651508'}},
#     {'reference': {'misc': ['"Gravitomagnetic Fields in Rotating Superconductors to Solve Tate’s Cooper Pair Mass'],
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'de Matos, C.J.'}]}},
#     {'reference': {'misc': ['Anomaly," in the proceedings of Space Technology and Applications International Forum (STAIF-2006), edited by M.S. El']}},
#     {'reference': {'misc': ['Genk, AIP Conf.Proc. 813, Issue 1, Melville, New York, 2006a, pp. 1415-1420']}},
#     {'reference': {'urls': [{'value': 'http://arxiv.org/abs/gr'}],
#       'title': {'title': 'Local Photon and Graviton Mass and its Consequences'},
#       'misc': ['(2006)'],
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'de Matos, C.J.'}]}},
#     {'reference': {'misc': ['qc/0603032, accessed October 17, 2006b']}},
#     {'reference': {'title': {'title': 'Experimental Detection of the Gravitomagnetic London Moment'},
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'Plesescu, F.'},
#        {'full_name': 'Marhold, K.'},
#        {'full_name': 'de Matos, C.J.'}]}},
#     {'reference': {'urls': [{'value': 'http://arxiv.org/abs/gr-qc/0603033'}],
#       'label': '2006',
#       'misc': ['accessed October 17, 2006']}},
#     {'reference': {'misc': ['"Measurement (London) of Gravitomagnetic and Acceleration Fields Around'],
#       'authors': [{'full_name': 'Tajmar, M.'},
#        {'full_name': 'Plesescu, F.'},
#        {'full_name': 'Seifert, K.'},
#        {'full_name': 'Marhold, K.'}]}},
#     {'reference': {'misc': ['Rotating Superconductors," in the proceedings of Space Technology and Applications International Forum (STAIF-2007)']}},
#     {'reference': {'misc': ['AIP Conf.Proc. 880, Melville, New York, 2007, pp. 1071-1082'],
#       'authors': [{'full_name': 'El-Genk, M.S.'}]}},
#     {'reference': {'title': {'title': 'Precise Determination of the Cooper-Pair Mass'},
#       'misc': ['Phys.Rev.Lett'],
#       'authors': [{'full_name': 'Tate, J.'},
#        {'full_name': 'Cabrera, B.'},
#        {'full_name': 'Felch, S.B.'},
#        {'full_name': 'Anderson, J.T.'}]}},
#     {'reference': {'misc': [': 62 (1989) 845']}},
#     {'reference': {'title': {'title': 'Determination of the Cooper-Pair Mass in Niobium'},
#       'misc': ['Phys.Rev. B'],
#       'authors': [{'full_name': 'Tate, J.'},
#        {'full_name': 'Cabrera, B.'},
#        {'full_name': 'Felch, S.B.'},
#        {'full_name': 'Anderson, J.T.'}]}},
#     {'reference': {'misc': [': 42 (1990) 7885']}},
#     {'reference': {'title': {'title': 'Gravitational Spin Interaction'},
#       'misc': ['Phys.Rev. D, : 6 (1972) 406'],
#       'authors': [{'full_name': 'Wald, R.'}]}}],
#    'number_of_pages': 16,
#    'referenced_authors_bais': ['C.J.de.Matos.1',
#     'G.E.Stedman.1',
#     'H.Hayasaka.1',
#     'H.R.Bilger.1',
#     'K.U.Schreiber.1',
#     'M.Liu.8',
#     'M.Tajmar.1',
#     'S.Takeuchi.2'],
#    'legacy_version': '20200415082350.0',
#    'inspire_categories': [{'term': 'Gravitation and Cosmology'}],
#    'legacy_creation_date': '2007-07-25',
#    'preprint_date': '2007-07',
#    'author_count': 5,
#    'first_author': {'full_name': 'Tajmar, M.',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#     'last_name': 'Tajmar',
#     'first_name': 'M.',
#     'recid': 986853},
#    'public_notes': [{'source': 'arXiv',
#      'value': 'Paper presented at the 18th International Conference on General Relativity & Gravitation, Sydney, Jul 2007'}],
#    'control_number': 756680,
#    'earliest_date': '2007-07',
#    'document_type': ['article'],
#    'texkeys': ['Tajmar:2007fp'],
#    'abstracts': [{'source': 'arXiv',
#      'value': 'The search for frame dragging around massive rotating objects such as the Earth is an important test for general relativity and is actively pursued with the LAGEOS and Gravity Probe-B satellites. Within the classical framework, frame dragging is independent of the state (normal or coherent) of the test mass. This was recently challenged by proposing that a large frame-dragging field could be responsible for a reported anomaly of the Cooper-pair mass found in Niobium superconductors. In 2003, a test program was initiated at the Austrian Research Centers to investigate this conjecture using sensitive accelerometers and fiber optic gyroscopes in the close vicinity of fast spinning superconducting rings. The sensors are mounted in close proximity to the superconductor in a separate evacuated, mechanically and thermally de-coupled chamber. Recently obtained high-precision data indicate that the angular velocity and acceleration applied to the superconductor can indeed be seen as an inertial-like reaction on the sensors. The signal amplitude is 8 orders of magnitude below the values applied to the ring for the case of Niobium at 4 Kelvin. The origin of the observed signals so far is not clear. Our measurements and analysis suggest that the signal can not be explained by mechanical influence or by carefully monitored magnetic fields surrounding the sensors. If the frame dragging-like signals are confirmed, their explanation must be sought outside of general relativity. This paper will give an overview of the experimental program and discuss in particular the latest measurements using fiber optic gyroscopes including a comparison with results obtained by the Canterbury Ring Laser Group. Possible error sources as well as the experimental difficulties are reviewed and discussed.',
#      'abstract_source_suggest': {'input': 'arXiv'}}],
#    'primary_arxiv_category': ['gr-qc'],
#    'titles': [{'title': 'Search for Frame-Dragging in the Vicinity of Spinning Superconductors'},
#     {'title': 'FRAME DRAGGING'},
#     {'source': 'arXiv',
#      'title': 'Search for Frame-Dragging in the Vicinity of Spinning Superconductors'}],
#    'external_system_identifiers': [{'schema': 'SPIRES',
#      'value': 'SPIRES-7270461'}],
#    'facet_author_name': ['986853_Martin Tajmar',
#     'NOREC_F. Plesescu',
#     'NOREC_B. Seifert',
#     'NOREC_R. Schnitzer',
#     'NOREC_I. Vasiljevich'],
#    'curated': True,
#    'arxiv_eprints': [{'categories': ['gr-qc'], 'value': '0707.3806'}]}},
#  {'links': {'bibtex': 'https://inspirehep.net/api/literature/776280?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/776280?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/776280?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/776280?format=json',
#    'cv': 'https://inspirehep.net/api/literature/776280?format=cv',
# ...
#        'artid': '958',
#        'page_start': '958',
#        'journal_title': 'Nature'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/662653'}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0603032'},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/712064'}},
#     {'reference': {'publication_info': {'journal_volume': '15',
#        'artid': '2047',
#        'page_start': '2047',
#        'journal_title': 'Phys.Rev.D'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/112131'}},
#     {'reference': {'publication_info': {'journal_volume': '31',
#        'artid': '166',
#        'page_start': '166',
#        'journal_title': 'Am.J.Phys.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/42554'}},
#     {'reference': {'publication_info': {'journal_volume': '25',
#        'artid': '1188',
#        'page_start': '1188',
#        'journal_title': 'Adv.Space Res.'}}},
#     {'reference': {'publication_info': {'journal_volume': '203',
#        'artid': '441',
#        'page_start': '441',
#        'journal_title': 'Phys.Rev.C'}}},
#     {'reference': {'arxiv_eprint': 'cond-mat/9701074'}}],
#    'number_of_pages': 28,
#    'referenced_authors_bais': ['B.Cabrera.2',
#     'C.J.de.Matos.1',
#     'C.M.Caves.1',
#     'E.C.Pavlis.1',
#     'I.Ciufolini.1',
#     'J.M.Anderson.1',
#     'J.Tate.1',
#     'Kip.S.Thorne.1',
#     'M.Liu.8',
#     'M.Tajmar.1',
#     'R.L.Forward.1',
#     'S.B.Felch.1',
#     'V.B.Braginsky.1'],
#    'legacy_version': '20190508205427.0',
#    'inspire_categories': [{'term': 'Gravitation and Cosmology'}],
#    'legacy_creation_date': '2006-03-09',
#    'preprint_date': '2006-03',
#    'author_count': 4,
#    'first_author': {'full_name': 'Tajmar, Martin',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#     'last_name': 'Tajmar',
#     'first_name': 'Martin',
#     'recid': 986853},
#    'public_notes': [{'value': 'Submitted to Physica.C'}],
#    'control_number': 712065,
#    'earliest_date': '2006-03',
#    'document_type': ['article'],
#    'texkeys': ['Tajmar:2006fg'],
#    'abstracts': [{'source': 'arXiv',
#      'value': 'It is well known that a rotating superconductor produces a magnetic field proportional to its angular velocity. The authors conjectured earlier, that in addition to this so-called London moment, also a large gravitomagnetic field should appear to explain an apparent mass increase of Niobium Cooper-pairs. This phenomenon was indeed observed and induced acceleration fields outside the superconductor in the order of about 10^-4 g were found. The field appears to be directly proportional to the applied angular acceleration of the superconductor following our theoretical motivations. If confirmed, a gravitomagnetic field of measurable magnitude was produced for the first time in a laboratory environment. These results may open up a new experimental window on testing general relativity and its consequences using coherent matter.',
#      'abstract_source_suggest': {'input': 'arXiv'}}],
#    'primary_arxiv_category': ['gr-qc'],
#    'titles': [{'title': 'Experimental detection of the gravitomagnetic London moment'},
#     {'source': 'arXiv',
#      'title': 'Experimental Detection of the Gravitomagnetic London Moment'}],
#    'external_system_identifiers': [{'schema': 'SPIRES',
#      'value': 'SPIRES-6556159'}],
#    'facet_author_name': ['2022951_Clovis Jacinto de Matos',
#     '986853_Martin Tajmar',
#     'NOREC_Florin Plesescu',
#     'NOREC_Klaus Marhold'],
#    'curated': True,
#    'arxiv_eprints': [{'categories': ['gr-qc'], 'value': 'gr-qc/0603033'}]}},
#  {'links': {'bibtex': 'https://inspirehep.net/api/literature/722115?format=bibtex',
#    'latex-eu': 'https://inspirehep.net/api/literature/722115?format=latex-eu',
#    'latex-us': 'https://inspirehep.net/api/literature/722115?format=latex-us',
#    'json': 'https://inspirehep.net/api/literature/722115?format=json',
#    'cv': 'https://inspirehep.net/api/literature/722115?format=cv',
#    'citations': 'https://inspirehep.net/api/literature/?q=refersto%3Arecid%3A722115'},
#   'id': '722115',
#   'updated': '2022-02-01T08:25:46.078075+00:00',
#   'created': '2006-07-23T00:00:00+00:00',
#   'metadata': {'citation_count': 5,
#    'citation_count_without_self_citations': 5,
#    'authors': [{'full_name_unicode_normalized': 'tajmar, m.',
#      'full_name': 'Tajmar, M.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/986853'},
#      'last_name': 'Tajmar',
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/904184'},
#        'value': 'Seibersdorf, Reaktorzentrum'}],
#      'bai': 'M.Tajmar.1',
#      'signature_block': 'TAJNARm',
#      'first_name': 'M.',
#      'uuid': '72345219-430c-4554-af68-7e48e1088d08',
#      'recid': 986853},
#     {'full_name_unicode_normalized': 'de matos, clovis j.',
#      'full_name': 'de Matos, Clovis J.',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/2022951'},
#      'last_name': 'de Matos',
#      'ids': [{'schema': 'INSPIRE BAI', 'value': 'C.J.de.Matos.1'}],
#      'affiliations': [{'record': {'$ref': 'https://inspirehep.net/api/institutions/907792'},
#        'value': 'European Space Agency'}],
#      'bai': 'C.J.de.Matos.1',
#      'signature_block': 'MATc',
#      'first_name': 'Clovis J.',
#      'uuid': '94096004-7f69-4019-b1dd-35156918f0d7',
#      'recid': 2022951}],
#    'publication_info': [{'journal_volume': '813',
#      'page_end': '1420',
#      'conference_record': {'$ref': 'https://inspirehep.net/api/conferences/978139'},
#      'year': 2006,
#      'journal_record': {'$ref': 'https://inspirehep.net/api/journals/1213302'},
#      'page_start': '1415',
#      'journal_issue': '1',
#      'journal_title': 'AIP Conf.Proc.',
#      'parent_record': {'$ref': 'https://inspirehep.net/api/literature/1716340'},
#      'cnum': 'C06-02-12.2'}],
#    'citeable': True,
#    '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#    'keywords': [{'schema': 'PACS', 'value': '04.25.Nx'},
#     {'schema': 'PACS', 'value': '04.80.Cc'},
#     {'schema': 'PACS', 'value': '74.90.+n'},
#     {'source': 'author', 'value': 'gravitomagnetism'},
#     {'source': 'author', 'value': 'superconductors'},
#     {'source': 'author', 'value': 'Cooper-pair mass'},
#     {'source': 'author', 'value': 'London moment'},
#     {'source': 'author', 'value': 'graviton mass'}],
#    'references': [{'reference': {'publication_info': {'journal_volume': '15',
#        'artid': '2047',
#        'page_start': '2047',
#        'journal_title': 'Phys.Rev.D'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/112131'}},
#     {'reference': {'publication_info': {'journal_volume': '25',
#        'artid': '1177',
#        'page_start': '1177',
#        'journal_title': 'Adv.Space Res.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/1419812'}},
#     {'reference': {'arxiv_eprint': 'cond-mat/0406761'}},
#     {'reference': {'publication_info': {'journal_volume': '16',
#        'artid': '1092',
#        'page_start': '1092',
#        'journal_title': 'Phys.Rev.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/50381'}},
#     {'reference': {'publication_info': {'journal_volume': '24',
#        'artid': '1092',
#        'page_start': '1092',
#        'journal_title': 'Phys.Rev.Lett.'}}},
#     {'reference': {'publication_info': {'journal_volume': '49',
#        'artid': '892',
#        'page_start': '892',
#        'journal_title': 'Proc.Ire.'}}},
#     {'reference': {'publication_info': {'journal_volume': '31',
#        'artid': '166',
#        'page_start': '166',
#        'journal_title': 'Am.J.Phys.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/42554'}},
#     {'reference': {'publication_info': {'journal_volume': '12',
#        'artid': '201',
#        'page_start': '201',
#        'journal_title': 'Found.Phys.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/1359113'}},
#     {'reference': {'publication_info': {'journal_volume': '385',
#        'artid': '488',
#        'page_start': '488',
#        'journal_title': 'Physica C'}}},
#     {'reference': {'publication_info': {'journal_volume': '15',
#        'artid': '1983',
#        'page_start': '1983',
#        'journal_title': 'Class.Quant.Grav.'}}},
#     {'reference': {'publication_info': {'journal_volume': '49',
#        'artid': '704',
#        'page_start': '704',
#        'journal_title': 'Phys.Rev.B'}}},
#     {'reference': {'publication_info': {'journal_volume': '43',
#        'artid': '457',
#        'page_start': '457',
#        'journal_title': 'Phys.Rev.D'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/331944'}},
#     {'reference': {'publication_info': {'journal_volume': '281',
#        'artid': '260',
#        'page_start': '260',
#        'journal_title': 'Physica C'}}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0107073',
#       'publication_info': {'journal_volume': '18',
#        'artid': '683',
#        'page_start': '683',
#        'journal_title': 'Mod.Phys.Lett.A'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/560430'}},
#     {'reference': {'publication_info': {'journal_volume': '20',
#        'artid': 'L67',
#        'page_start': 'L67',
#        'journal_title': 'Class.Quant.Grav.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/600015'}},
#     {'reference': {'publication_info': {'journal_volume': '203',
#        'artid': '441',
#        'page_start': '441',
#        'journal_title': 'Physica C'}}},
#     {'reference': {'arxiv_eprint': 'physics/9705043'}},
#     {'reference': {'arxiv_eprint': 'gr-qc/0203033',
#       'publication_info': {'journal_volume': '385',
#        'artid': '551',
#        'page_start': '551',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/583909'}},
#     {'reference': {'publication_info': {'journal_volume': '420',
#        'artid': '56',
#        'page_start': '56',
#        'journal_title': 'Physica C'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/651508'}},
#     {'reference': {'publication_info': {'journal_volume': '62',
#        'artid': '845',
#        'page_start': '845',
#        'journal_title': 'Phys.Rev.Lett.'}},
#      'curated_relation': False,
#      'record': {'$ref': 'https://inspirehep.net/api/literature/294104'}},
#     {'reference': {'publication_info': {'journal_volume': '42',
#        'artid': '7885',
#        'page_start': '7885',
#        'journal_title': 'Phys.Rev.B'}}}],
#    'number_of_pages': 6,
#    'legacy_creation_date': '2006-07-23',
#    'preprint_date': '2006-07',
#    'author_count': 2,
#    'earliest_date': '2006-02-01',
#    'external_system_identifiers': [{'schema': 'ADS',
#      'value': '2006AIPC..813.1415T'},
#     {'schema': 'SPIRES', 'value': 'SPIRES-6852130'}],
#    'publication_type': ['review'],
#    'facet_author_name': ['2022951_Clovis Jacinto de Matos',
#     '986853_Martin Tajmar'],
#    'journal_title_variants': ['AIP Conf. Proc.', 'AIP Conf.Proc.'],
#    'arxiv_eprints': [{'categories': ['gr-qc'], 'value': 'gr-qc/0607086'}],
#    'referenced_authors_bais': ['A.Neves.1',
#     'B.Cabrera.2',
#     'B.Muhlfelder.1',
#     'B.Parkinson.1',
#     'B.S.DeWitt.1',
#     'C.J.de.Matos.1',
#     'C.M.Caves.1',
#     'C.W.F.Everitt.1',
#     'D.Bardas.1',
#     'D.DeBra.1',
#     'D.Gill.1',
#     'D.G.Torr.2',
#     'D.H.Gwo.1',
#     'E.G.Harris.2',
#     'G.Gutt.1',
#     'G.M.Keiser.1',
#     'G.Modanese.1',
#     'J.A.Lipa.1',
#     'J.Lockhart.2',
#     'J.M.Anderson.1',
#     'J.Mester.1',
#     'J.P.Turneaure.1',
#     'J.Tate.1',
#     'Kip.S.Thorne.1',
#     'M.Novello.1',
#     'M.Taber.1',
#     'M.Tajmar.1',
#     'N.Li.6',
#     'P.Zhou.2',
#     'R.Brumley.1',
#     'R.L.Forward.1',
#     'S.B.Felch.1',
#     'S.Buchman.1',
#     'Shou.Jun.Wang.1',
#     'V.B.Braginsky.1',
#     'W.Bencze.1',
#     'Yong.Xiao.1'],
#    'legacy_version': '20190122213318.0',
#    'inspire_categories': [{'term': 'Gravitation and Cosmology'}],
#    'urls': [{'description': 'Science Blog article',
#      'value': 'http://www.scienceblog.com/cms/scientists_find_evidence_for_artifical_gravity_10282.html'}],
#    'first_author': {'full_name': 'Tajmar, M.',
#     'last_name': 'Tajmar',
#     'ids': [{'schema': 'INSPIRE BAI', 'value': 'M.Tajmar.1'}],
#     'first_name': 'M.',
#     'recid': 986853},
#    'control_number': 722115,
#    'dois': [{'value': '10.1063/1.2169327'}],
#    'document_type': ['conference paper'],
#    'texkeys': ['Tajmar:2006qn'],
#    'abstracts': [{'source': 'AIP',
#      'value': 'Superconductors have often been used to claim gravitational anomalies in the context of breakthrough propulsion. The experiments could not be reproduced by others up to now, and the theories were either shown to be wrong or are often based on difficult to prove assumptions. We will show that superconductors indeed could be used to produce non‐classical gravitational fields, based on the established disagreement between theoretical prediction and measured Cooper‐pair mass in Niobium. Tate et al failed to measure the Cooper‐pair mass in Niobium as predicted by quantum theory. This has been discussed in the literature without any apparent solution. Based on the work from DeWitt to include gravitomagnetism in the canonical momentum of Cooper‐pairs, the authors published a number of papers discussing a possibly involved gravitomagnetic field in rotating superconductors to solve Tate’s measured anomaly. Although one possibility to match Tate’s measurement, a number of reasons were developed by the authors over the last years to show that the gravitomagnetic field in a rotating quantum material must be different from its classical value and that Tate’s result is actually the first experimental sign for it. This paper reviews the latest theoretical approaches to solve the Tate Cooper‐pair anomaly based on gravitomagnetic fields in rotating superconductors.',
#      'abstract_source_suggest': {'input': 'AIP'}},
#     {'source': 'arXiv',
#      'value': "Superconductors have often been used to claim gravitational anomalies in the context of breakthrough propulsion. The experiments could not be reproduced by others up to now, and the theories were either shown to be wrong or are often based on difficult to prove assumptions. We will show that superconductors indeed could be used to produce non-classical gravitational fields, based on the established disagreement between theoretical prediction and measured Cooper-pair mass in Niobium. Tate et al failed to measure the Cooper-pair mass in Niobium as predicted by quantum theory. This has been discussed in the literature without any apparent solution. Based on the work from DeWitt to include gravitomagnetism in the canonical momentum of Cooper-pairs, the authors published a number of papers discussing a possibly involved gravitomagnetic field in rotating superconductors to solve Tate's measured anomaly. Although one possibility to match Tate's measurement, a number of reasons were developed by the authors over the last years to show that the gravitomagnetic field in a rotating quantum material must be different from its classical value and that Tate's result is actually the first experimental sign for it. This paper reviews the latest theoretical approaches to solve the Tate Cooper-pair anomaly based on gravitomagnetic fields in rotating superconductors.",
#      'abstract_source_suggest': {'input': 'arXiv'}}],
#    'primary_arxiv_category': ['gr-qc'],
#    'titles': [{'title': "Gravitomagnetic Fields in Rotating Superconductors to Solve Tate's Cooper Pair Mass Anomaly"},
#     {'source': 'arXiv',
#      'title': "Gravitomagnetic fields in rotating superconductors to solve Tate's Cooper pair mass anomaly."}],
#    'imprints': [{'date': '2006-02-01'}],
#    'curated': True}}]

# %% [markdown]
# # From the previous JSON :
# ```
# 'authors': [{'raw_affiliations': [{'value': 'Austrian Academy of Sciences (AT)'}],
#      'full_name_unicode_normalized': 'hoch, michael',
#      'full_name': 'Hoch, Michael',
#      'record': {'$ref': 'https://inspirehep.net/api/authors/1005850'},
# ```
# we can get link to the author!!!
#
# and from that link we can get authors data like address, telephone number or email

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# 1)  En un notebook de jupyter desarrolle los siguientes pasos
#
# ```
# Descargue el JSON con la lista de paises del siguiente link:
# https://datahub.io/core/country-list/r/data.json
# y escoja aleatoriamente un país de Europa
# (Ejemplo que es abajo usa Colombia pero con pais de europa es mas facil)
#
# Use los diferentes API endpoints de inspire-hep
# https://inspirehep.net/
#
# Para extraer la lista de investigadores de una institución de ese país  en esa base de datos.
#
#
# Para ello:
#
# A) Use el API de institutions para extraer la lista de instituciones del país, por ejemplo: colombia (mejor si es Europa, por completo de datos )
# https://inspirehep.net/api/institutions?q=colombia
#
#
# Para la primera institución con
#
# number_of_papers > 0
#
#
# Obtenga el valor
#
# legacy_ICN:
#
#
# Por ejemplo:
# Colombia, U. Natl.
#
#
# Si ninguna institución satisface la condición number_of_papers > 0, escoja de nuevo otro país aleatorio y repita el proceso
#
# B) Con el API de literatura obtenga el JSON con los artículos de menos de 10 autores usando el "legacy_ICN" de la siguiente manera
#
# https://inspirehep.net/api/literature?sort=mostrecent&page=1&q=aff+Colombia,+U.+Natl.+and+ac+1->+10
#
#
# aff: usa el valor de legacy_ICN
# and: es un operador lógico
# ac: establece los autores entre 1 y 10
#
# C) Para al menos un artículo de esa institución, extraiga el URL del perfil de cada autor de esa institución que se encuentra dentro del campo "authors" en "record" y luego en "$ref". Por ejemplo
#
# https://inspirehep.net/api/authors/1010271
#
#
# D) Con cada uno de los datos del resultado del API para cada perfil construya una tabla con los siguientes columnas (puede que alguno de los datos no esté disponible):
# Nombre Completo
# Correo electrónico
# posición más reciente (la primera  que aparece en la lista "positions" del JSON) con su correspondiente:
# rango
# institución
# fecha de inicio
# fecha de finalización
# ```
