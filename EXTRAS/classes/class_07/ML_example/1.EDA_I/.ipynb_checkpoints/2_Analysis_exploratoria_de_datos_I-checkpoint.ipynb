# %% [markdown]
# # 1. Análisis exploratorio de datos - EDA - I

# %% [markdown]
# <a id="introduction"></a>
# ## Analisis exploratorio de datos - introducción

# %% [markdown]
# Imagine que quiere predecir el precio de la casa en función de sus características, como el tamaño de la casa, el número de habitaciones, el número de baños, la localización, etc., sabiendo los precios y ventas históricas.
# Entonces, necesita preparar estos datos para el algoritmo de aprendizaje automático. Así que el precio será el objetivo de datos (salida) y las características de la casa (número de habitaciones, tamaño, localización) serán la entrada. Como los algoritmos están ampliamente disponibles, el problema se reduce a preparar bien los datos.
#
# ¿Qué se necesita de los datos?
#
# * Asegurarse de que estén completos, que no falten características que influyan en el precio de la casa.
# * Que los datos no tengan errores, valores de error tipográfico, valores extraordinarios grandes o extraordinarios pequeños (valores atípicos).
# * Que las filas no se repiten.
# * Que las columnas no se repiten.
# * Que no hay valores vacíos en las columnas.
# * Que no hay correlación fuerte entre los datos de las columnas (si hay una columna con el tamaño de la casa en m^2 y otra columna con el tamaño de la casa en en pies^2, entonces una es redundante).
# * Cuáles variables son categóricas y cuáles son continuas.
# * Finalmente, no es posible realizar todas esas operaciones con los ojos vendados, para entender los datos debe visualizarlos, ordenarlos y agruparlos.
#
# Hacer todas esas operaciones se llama análisis exploratorio de datos. Este capítulo debería servir, más bien, como referencia del curso completo, porque no hay reglas estrictas para seguir dicho análisis.

# %% [markdown]
# <a id="steps"></a>
# ## Elementos y funciones de Pandas para el análisis exploratorio de datos - I

# %% [markdown]
# Existen varios elementos del procedimiento exploratorio de los datos, los más importantes son:

# %% [markdown]
# 1. Para importar, leer e inspeccionar los datos se puede usar:
#   * `df.head(n)` - visualiza las primeras 'n' filas del conjunto de datos (por defecto n=5).
#   * `df.tail(n)` - visualiza las últimas 'n' filas del conjunto de datos (por defecto n=5).
#   * `df.columns()` - visualiza los nombres de las columnas.
#   * `df.describe()` - devuelve una tabla que contiene un resumen estadístico básico de los datos.
#   * `df.info()` - devuelve información sobre tipos de datos en cada columna.
#   * `df[mascara]` - seleciona filas usando "máscara" (ejemplo de máscara (condición lógica): `df['id']>100`), combinando los dos: `df[df['id']>100]` devuelve todas las filas donde columna `id` tiene valor más grande que `100` (otro ejemplo: `df[df['id']==df['id'].min()]`, devuelve todas las filas donde columna `id` tiene valor minimo).
#   *  `df['nombre_columna 1']` o `df[['nombre_columna 1','nombre_columna 2']]` - visualiza una o mas columnas
#
# 2. Para completar los datos y organizar las columnas:
#   * `df.merge()` - une conjuntos de datos
#   * `df[df.duplicated()] ` - visualiza filas con valores duplicados a través de todas las columnas.
#   * `df.drop_duplicates(subset=['nombre_columna'])` - elimina valores duplicados en la columna.
#   * `df.drop(['nombre_columna'], axis=1)`           - elimina columna.
#   * `df['nueva_columna']=df['columna']/10.764` añade otros nuevos (utilizando cálculos).
#   * `df.rename(columns={'nombre_columna_vieja': 'nombre_columna_nueva'})` cambia el nombre de las columnas.
#   * `df['nombre_columna'] = df['nombre_columna'].astype(str)` - cambia tipo de valores de la columna.
#   * `df['nombre_columna'] = df['nombre_columna'].replace(list_val_old,list_val_new)` - reemplaza los valores en la columna
#   * `df['nombre_columna'] = df['nombre_columna'].apply(funcion)` - aplica funcion a los valores en la columna
#
# 3. para comprobar los tipos de datos y eliminar de los valores repetidos y `NaN` (Not-A-Number: vacías):
#   * `df.info()` - devuelve información sobre tipos de datos en cada columna.
#   * `df.isna().sum()`  - suma de todos los valores NaN en cada columna.
#   * `df['sqft_lot'].isna()` - máscara lógica de todos valores `NaN` útil combinando con `df[mascara]`, combinando los dos: `df[df['nombre_columna'].isna()]` devuelve todas filas NaN de columna `nombre_columna`.
#   * `df.dropna()` - elimina valores `NaN`, parámetro `axis=0`, lo que significa eliminar todas filas con valor NaN
#
# 4. Para revisar y comprender los datos:
#   * `df['nombre_columna'].unique()`      - visualiza valores únicos de la columna.
#   * `df['nombre_columna'].nunique()`      - cuenta valores únicos de la columna
#   * `df['nombre_columna'].value_counts()` - suma frecuencia de valores de la columna (se usa para columnas con valores discretos).
#   * `df.groupby(['nombre_columna_1']).mean()` - agrupa los datos de `nombre_columna_1` y devuelve los valores promedios de todas las otras columnas con respecto a la agrupación.
#   * `df.groupby(['nombre_columna_1','nombre_columna_2']).mean()`  - agrupa los datos de `nombre_columna_1` y `nombre_columna_2`
#   * `df['nombre_columna'].nlargest(10)` - visualiza los 10 valores numéricos más grandes de la columna.
#  * `sns.countplot()` - visualiza las frecuencias de observaciones de la variable discreta.
#  * `sns.histplot()`  - visualiza los recuentos de observaciones de la variable continua.
#  * `sns.scatterplot()` - visualiza la relación entre dos variables.
#  * `sns.boxplot()` - visualiza la distribucion con respecto a las categorías de la variable
#  * `sns.jointplot()` - visualiza la relación entre dos variables junto con las distribuciones.
#  * `sns.pairplot()` - visualiza la relación entre distintas variables en forma de matriz.
#
# 5. Para analizar series de tiempo:
#   * `pd.to_datetime()` - convierte la columna que contiene valores de fecha y tiempo a formato entendido para Pandas, por ejemplo: `df['date'] = pd.to_datetime(df['date'])`
#   * `pd.DatetimeIndex()` - permite extración de año, mes, día y horario de formato de fecha,  por ejemplo: `df['year'] = pd.DatetimeIndex(df['date']).year` - crea una nueva columna que contiene el valor del año extraído de la columna con el formato de fecha completa.
#   * `df.between()` - permite selecionar el rango de fechas (horas).

# %% [markdown]
# <a id="example"></a>
# ## Ejemplo de analisis exploratorio de datos

# %% [markdown]
# En el conjunto `kc_house_data.csv'` de datos están presentes los precios de venta de las casas en el condado de King, Estados Unidos. Incluye casas vendidas entre mayo de 2014 y mayo de 2015. Primero se debe saber sobre el conjunto de datos, ¿qué contiene?, ¿cuáles son sus características y cuál es la estructura de los datos?

# %% [markdown]
# ## 1. Importar, leer e inspeccionar los datos.

# %% [markdown]
# Se inicia importando todas las bibliotecas y cargando el conjunto de datos como se muestra en el módulo anterior:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #visualisation
import seaborn as sns           #visualisation

# %%
import pandas as pd
#df=pd.read_csv('data/kc_house_data.csv',sep=',')
df=pd.read_csv('https://raw.githubusercontent.com/mhemmg/datasets/master/housing/kc_house_data_D.csv',sep=',')

# %% [markdown]
# Es útil para ver el tamaño del conjunto de datos, saber cuántas columnas y filas tiene, y cuáles son los nombres de todas las columnas.

# %%
print('Numero de filas:',df.shape[0])
print('Numero de columnas:',df.shape[1])
print('Nombres de las columnas:',df.columns)
# Out:
# Numero de filas: 21615
# Numero de columnas: 21
# Nombres de las columnas: Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition str', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# Puede verse que el conjunto de datos contiene 21613 observaciones con 20 características, más el precio de la vivienda. Los nombres de las columnas con descripción son los siguientes:

# %% [markdown]
#     * "id": número de identificación de la vivienda
#     * "Date": fecha en que se vendió la casa
#     * "Price": el precio es el objetivo de predicción
#     * "Bedrooms": número de dormitorios/casa
#     * "Bathrooms": número de baños/casa
#     * "Sqft_Living": pies cuadrados de la casa
#     * "Sqft_Lot": pies cuadrados del lote
#     * "Floors": total de pisos o niveles en casa
#     * "Waterfront": casa que tiene vista a la costanera
#     * "View": ha sido vista
#     * "Condition": qué tan buena es la condición general
#     * "Grade": calificación de vivienda, según el sistema del condado de King
#     * "Sqft_above": pies cuadrados de la casa aparte del sótano
#     * "Sqft_Basement": pies cuadrados del sótano
#     * "Yr_Built": año de construcción
#     * "Yr_Renovated": año en que se renovó la casa
#     * "Zipcode": código postal
#     * "Lat": coordenada de latitud
#     * "Long": coordenada de longitud
#     * "Sqft_Living15": área de la sala de estar en 2015 o implica algunas renovaciones
#     * "Sqft_Lot15": área del tamaño del lote en 2015 o implica algunas renovaciones

# %% [markdown]
# Aquí pueden verse las tres primeras filas de los datos para tener una idea de cómo están organizados:

# %%
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ... grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...     7        1180              0
# 1    7242.0     2.0           0     0  ...     7        2170            400
# 2   10000.0     1.0           0     0  ...     6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# [3 rows x 21 columns]

# %% [markdown]
# O las últimas tres filas:

# %%
df.tail(3) # mostrar ultimas 3 filas del conjunto
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300141  20140623T000000  402101.0         2       0.75
# 21613   291310100  20150116T000000  400000.0         3       2.50
# 21614  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ... grade  sqft_above  \
# 21612         1020    1350.0     2.0           0     0  ...     7        1020
# 21613         1600    2388.0     2.0           0     0  ...     8        1600
# 21614         1020    1076.0     2.0           0     0  ...     7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21612              0      2009             0    98144  47.5944 -122.299
# 21613              0      2004             0    98027  47.5345 -122.069
# 21614              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21612           1020        2007
# 21613           1410        1287
# 21614           1020        1357
#
# [3 rows x 21 columns]

# %% [markdown]
# Pueden realizarse operaciones sencillas para visualizar ciertas columnas y filas.
#
# Las columnas se pueden visualizar utilizando la notación con notación del punto `.` o entre corchetes `['nombre']`:

# %%
df.price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21610    360000.0
# 21611    400000.0
# 21612    402101.0
# 21613    400000.0
# 21614    325000.0
# Name: price, Length: 21615, dtype: float64

# %%
df['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21610    360000.0
# 21611    400000.0
# 21612    402101.0
# 21613    400000.0
# 21614    325000.0
# Name: price, Length: 21615, dtype: float64

# %%
df['price'][0:5]
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %% [markdown]
# *Es importante tener en cuenta que la impresión de una sola columna no produce un nueva `DataFrame`, sino un objeto llamado `DataSeries`. Puede verificarlo usted mismo guardando la salida de seleccionar una sola columna en una nueva variable y verificando su tipo usando función `type()`. Series es una estructura de datos de Pandas que representa un objeto unidimensional similar a una matriz de datos indexados. La diferencia entre Series y DatFrame es analógica a matriz y vector. No se profundizará en DataSeries en este curso.

# %% [markdown]
# La selección de filas y columnas en DataFrame se puede hacer de dos maneras: utilizando método `.loc[]` y método `.iloc[]`

# %% [markdown]
# * El método `.loc[]` necesita nombres de las filas y columnas. Los nombres de las columnas son visibles, pero los nombres de las filas son los números que se almacenan en la primera columna del DataFrame (0,1,2,3,... los números no siempre tienen que comenzar desde 0!)
#
# Por ejemplo:

# %%
df.loc[0:3]
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
#
#    sqft_lot  floors  waterfront  view  ... grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...     7        1180              0
# 1    7242.0     2.0           0     0  ...     7        2170            400
# 2   10000.0     1.0           0     0  ...     6         770              0
# 3    5000.0     1.0           0     0  ...     7        1050            910
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
#
# [4 rows x 21 columns]

# %% [markdown]
# *Tenga en cuenta que con `.loc()` se muestra la última fila a la que se hace referencia (0:3).

# %%
df.loc[0:3,'price'] # antes de la coma cortamos las filas, después de la coma cortamos las columnas
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# Name: price, dtype: float64

# %% [markdown]
# * Por otro lado, el método `.iloc()` necesita índices (números enteros) de las filas y columnas). Por ejemplo:

# %%
df.iloc[0:3]
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ... grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...     7        1180              0
# 1    7242.0     2.0           0     0  ...     7        2170            400
# 2   10000.0     1.0           0     0  ...     6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# [3 rows x 21 columns]

# %%
df.iloc[0:3,0]  # antes de la coma se cortan las filas, después de la coma las columnas
# Out:
# 0    7129300520
# 1    6414100192
# 2    5631500400
# Name: id, dtype: int64

# %% [markdown]
# *Observe que usando `.iloc`' no se ve la última fila referenciada (como en el `range()` de métodos y el corte...)

# %% [markdown]
# A continuación, más operaciones interesantes que pueden hacerse con Pandas:

# %% [markdown]
# Ahora, se obtiene el resumen estadístico de los conjuntos de datos.
#
# Si el DataFrame contiene datos numéricos, la descripción contiene esta información para cada columna:

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161500e+04  2.161500e+04  21615.000000  21615.000000  21615.000000
# mean   4.579945e+09  5.400672e+05      3.370807      2.114724   2079.874763
# std    2.876672e+09  3.671167e+05      0.930026      0.770136    918.402073
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.215000e+05      3.000000      1.750000   1428.500000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view         grade  \
# count  2.161400e+04  21615.000000  21615.000000  21615.000000  21615.000000
# mean   1.511002e+04      1.494263      0.007541      0.234282      7.656812
# std    4.142026e+04      0.539985      0.086513      0.766285      1.175421
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      7.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      7.000000
# 75%    1.069350e+04      2.000000      0.000000      0.000000      8.000000
# max    1.651359e+06      3.500000      1.000000      4.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21615.000000   21615.000000  21615.000000  21615.000000  21615.000000
# mean    1788.337173     291.537590   1971.005968     84.394448  98077.936109
# std      828.071354     442.564514     29.372179    401.661476     53.503930
# min      290.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21615.000000  21615.000000   21615.000000   21615.000000
# mean      47.560039   -122.213873    1986.521351   12779.768864
# std        0.138565      0.140843     685.367239   27328.234764
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.470850   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.230000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10085.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
df[df['price']==df['price'].max()]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7254  6762700020  20141013T000000  7700000.0         6        8.0
#
#       sqft_living  sqft_lot  floors  waterfront  view  ... grade  sqft_above  \
# 7254        12050   27600.0     2.5           0     3  ...    13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7254           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7254           3940        8800
#
# [1 rows x 21 columns]

# %% [markdown]
# Para entender mejor `df.describe()` se va a descifrar la información que devolvió:

# %% [markdown]
# * count - el número de valores no vacíos
# * mean - el valor promedio (por ejemplo, valor promedio del precio de la casa es 5.400881e+05 USD)
# * std - la desviación estándar (por ejemplo, desviación del precio promedio de la casa es 3.671272e+05 USD)
# * min - el valor mínimo (por ejemplo valor mínimo del precio de la casa es 7.500000e+04 USD)
# * 25% - (percentil) significa, por ejemplo, que 25% de los precios son menores que 3.219500e+05
# * 50% - (percentil) significa, por ejemplo, que 50% de los precios son menores que 4.500000e+05
# * 75% - (percentil) significa, por ejemplo, que 75% de los precios son menores que 6.450000e+05
# * max - el valor máximo (por ejemplo, valor máximo del precio de la casa es 7.700000e+06 USD)

# %% [markdown]
# `df.describe()` permite ver, de forma rápida, que el número máximo de dormitorios es 33 - lo que puede indicar un error en los datos.

# %% [markdown]
# También se pueden extraer todas las filas en las que la columna `dormitorios` tiene un valor extraordinario, por ejemplo, mayor que 10

# %%
df[df['bedrooms']>10] # donde df['bedrooms']>10 es una mascara logica
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8759   1773100755  20140821T000000  520000.0        11       3.00
# 15872  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ... grade  sqft_above  \
# 8759          3000    4960.0     2.0           0     0  ...     7        2400
# 15872         1620    6000.0     1.0           0     0  ...     7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8759             600      1918          1999    98106  47.5560 -122.363
# 15872            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 8759            1420        4960
# 15872           1330        4700
#
# [2 rows x 21 columns]

# %% [markdown]
# Finalmente, se oberva que hay dos casas donde hay un gran número inusual de dormitorios. Luego eliminarse esas filas.

# %% [markdown]
# ## 2. Completar los datos y organizar las columnas.

# %% [markdown]
# El conjunto de datos tiene un código postal (`zipcode`) de columna, pero no se sabe a qué ciudad corresponde. No obstante, puede usarse otro conjunto de datos que contenga códigos postales y ciudades correspondientes y combinar las dos tablas.

# %%
import pandas as pd
df_addresses=pd.read_csv('data/zipcode_city.csv',sep=',',index_col=[0])

# %%
df_addresses.head()
# Out:
#    zipcode       city
# 0    98178    Seattle
# 1    98125    Seattle
# 2    98028    Kenmore
# 3    98136    Seattle
# 4    98074  Sammamish

# %%
df_addresses.shape
# Out:
# (501, 2)

# %% [markdown]
# El segundo conjunto de datos `df_addresses` tiene valores repetidos del código postal (501 filas!), por lo que deben eliminarse dichos valores.

# %%
df_addresses=df_addresses.drop_duplicates(subset=['zipcode'])

# %%
df_addresses.shape
# Out:
# (76, 2)

# %% [markdown]
# Antes de fusionar los dos conjuntos de datos `df` y `df_addresses` basados en la columna `zipcode`, es recomendable convertir esas columnas a una cadena.

# %%
df_addresses['zipcode'] = df_addresses['zipcode'].astype(str)
df['zipcode'] = df['zipcode'].astype(str)

# %% [markdown]
# Ahora se fusionan los conjuntos de datos. Parámetro `left` (izquierda) significa que para cada valor en la tabla izquierda `df` se busca un valor correspondiente en la tabla derecha `df_addresses`.

# %%
df = pd.merge(df, df_addresses, how="left", on="zipcode")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ... sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...       1180              0
# 1    7242.0     2.0           0     0  ...       2170            400
# 2   10000.0     1.0           0     0  ...        770              0
# 3    5000.0     1.0           0     0  ...       1050            910
# 4    8080.0     1.0           0     0  ...       1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15       city
# 0        5650    Seattle
# 1        7639    Seattle
# 2        8062    Kenmore
# 3        5000    Seattle
# 4        7503  Sammamish
#
# [5 rows x 22 columns]

# %% [markdown]
# Teniendo el conjunto de datos completo se eliminan algunas columnas, por ejemplo, columna: `id`; el parámetro `axis=1` se refiere a columna.

# %%
df = df.drop(['id'], axis=1)

# %% [markdown]
# Luego, se cambian los nombres de las columnas que parecen crípticas

# %%
df = df.rename(columns={'yr_build': 'year_build', 'yr_renovated': 'year_renovated'})

# %%
print('Numero de columnas:',df.shape[1])
# Out:
# Numero de columnas: 21

# %% [markdown]
# Se cambia, de nuevo, el tipo del valor del código postal a entero

# %%
df['zipcode'] = df['zipcode'].astype(int)

# %%
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180    5650.0
# 1  20141209T000000  538000.0         3       2.25         2570    7242.0
# 2  20150225T000000  180000.0         2       1.00          770   10000.0
# 3  20141209T000000  604000.0         4       3.00         1960    5000.0
# 4  20150218T000000  510000.0         3       2.00         1680    8080.0
#
#    floors  waterfront  view condition str  ...  sqft_above  sqft_basement  \
# 0     1.0           0     0          good  ...        1180              0
# 1     2.0           0     0          good  ...        2170            400
# 2     1.0           0     0          good  ...         770              0
# 3     1.0           0     0     excellent  ...        1050            910
# 4     1.0           0     0          good  ...        1680              0
#
#    yr_built  year_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955               0    98178  47.5112 -122.257           1340
# 1      1951            1991    98125  47.7210 -122.319           1690
# 2      1933               0    98028  47.7379 -122.233           2720
# 3      1965               0    98136  47.5208 -122.393           1360
# 4      1987               0    98074  47.6168 -122.045           1800
#
#    sqft_lot15       city
# 0        5650    Seattle
# 1        7639    Seattle
# 2        8062    Kenmore
# 3        5000    Seattle
# 4        7503  Sammamish
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 3. Comprobar los tipos de datos, eliminar de los valores repetidos y `Nan`.

# %% [markdown]
# Después de combinar y completar los datos, se revisará el conjunto en el término de tipos de datos y valor non-numerical `NaN` (**N**ot-**a**-**N**umber)
#
# Con función `info()` pueden verse las columnas, el total de filas y la cantidad de filas sin nulos. También los tipos de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21615 entries, 0 to 21614
# Data columns (total 21 columns):
# date              21615 non-null object
# price             21615 non-null float64
# bedrooms          21615 non-null int64
# bathrooms         21615 non-null float64
# sqft_living       21615 non-null int64
# sqft_lot          21614 non-null float64
# floors            21615 non-null float64
# waterfront        21615 non-null int64
# view              21615 non-null int64
# condition str     21615 non-null object
# grade             21615 non-null int64
# sqft_above        21615 non-null int64
# sqft_basement     21615 non-null int64
# yr_built          21615 non-null int64
# year_renovated    21615 non-null int64
# zipcode           21615 non-null int64
# lat               21615 non-null float64
# long              21615 non-null float64
# sqft_living15     21615 non-null int64
# sqft_lot15        21615 non-null int64
# city              21615 non-null object
# dtypes: float64(6), int64(12), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# Puede observarse que la mayoría de las columnas tienen 21615 valores no vacíos, excepto la columna `sqft_lot` que muestra 21614 valores no vacíos, lo que significa que en esta columna hay un valor no vacío. Para analizar el caso más de cerca:

# %%
df.isna().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          1
# floors            0
# waterfront        0
# view              0
# condition str     0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# year_renovated    0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# city              0
# dtype: int64

# %% [markdown]
# La columna `sqft_lot` contiene un valor nonumérico `Nan`

# %% [markdown]
# Puede visualizarse esta fila en particular usando el enmascaramiento lógico

# %%
df[df['sqft_lot'].isna()]
# Out:
#                 date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 109  20140723T000000  188500.0         2       1.75         1240       NaN
#
#      floors  waterfront  view condition str  ...  sqft_above  sqft_basement  \
# 109     1.0           0     0         great  ...        1240              0
#
#      yr_built  year_renovated  zipcode      lat     long  sqft_living15  \
# 109      1985               0    98198  47.3813 -122.322           1270
#
#      sqft_lot15        city
# 109        4966  Des Moines
#
# [1 rows x 21 columns]

# %% [markdown]
# Y eliminar esta fila con valor NaN

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (21614, 21)

# %%
df[df['sqft_lot'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition str, grade, sqft_above, sqft_basement, yr_built, year_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, city]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #### Comentarios sobre NaN y valores faltantes
#
# * Pandas puede marcar automáticamente los datos faltantes como valores `NaN` mientras carga el conjunto de datos, pero a veces hay valores que no solo están vacíos sino que tienen valores como `?`. En ese caso, puede usarse un método muy poderoso `df.replace()`: `df = df.replace(r'?',np.nan)` para reemplazar `?` con `NaN`. Posteriormente, pueden eliminase todos los `NaN` con el método `dropna()` (`NaN` no es una cadena, es un valor especial en numpy: `np.nan`).
#
# * No siempre es buena idea eliminar filas que contienen valores NaN. Por ejemplo, si hay un valor de NaN en la columna que no se necesitará, entonces es mejor eliminar solo esa columna. O si analizamos los datos de los medallistas deportivos y algunos deportistas tienen valores de NaN, tal vez signifique que no obtuvieron la medalla. Eliminar todo el registro NaN también sesgaría los datos.

# %% [markdown]
# Se verifica si el conjunto de datos tiene filas o columnas completamente repetidas

# %%
df[df.duplicated()]
# Out:
#                 date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 99   20140711T000000  314000.0         3       1.75         1810   41800.0
# 100  20140711T000000  314000.0         3       1.75         1810   41800.0
#
#      floors  waterfront  view condition str  ...  sqft_above  sqft_basement  \
# 99      1.0           0     0     excellent  ...        1210            600
# 100     1.0           0     0     excellent  ...        1210            600
#
#      yr_built  year_renovated  zipcode      lat     long  sqft_living15  \
# 99       1980               0    98038  47.4109 -121.958           1650
# 100      1980               0    98038  47.4109 -121.958           1650
#
#      sqft_lot15          city
# 99       135036  Maple Valley
# 100      135036  Maple Valley
#
# [2 rows x 21 columns]

# %%
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape[0])
# Out:
# number of duplicate rows:  2

# %% [markdown]
# Como hay filas duplicadas, se eliminan

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (21612, 21)

# %% [markdown]
# También puede eliminarse la fila con la casa que tiene 33 dormitorios

# %%
df[(df['bedrooms']<10) & (df['bedrooms']>5)] # Notam dos condiciones están entre paréntesis separados
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 211    20140717T000000   464000.0         6       3.00         2300    3404.0
# 234    20141121T000000   315000.0         6       2.75         2940    7350.0
# 241    20140529T000000   472000.0         6       2.50         4410   14034.0
# 333    20150416T000000   279000.0         6       1.75         2240   11180.0
# 488    20140711T000000  1067000.0         6       3.50         4860   11793.0
# ...                ...        ...       ...        ...          ...       ...
# 20986  20141015T000000   343000.0         6       5.00         2732    7655.0
# 21087  20150318T000000   677790.0         6       3.00         2800    4213.0
# 21188  20150114T000000   303500.0         6       4.50         3390    7200.0
# 21377  20140717T000000  1174660.0         6       3.50         4310    7760.0
# 21524  20150302T000000   462500.0         6       3.00         2390    4000.0
#
#        floors  waterfront  view condition str  ...  sqft_above  sqft_basement  \
# 211       2.0           0     0          good  ...        1600            700
# 234       1.0           0     0          good  ...        1780           1160
# 241       1.0           0     2         great  ...        2350           2060
# 333       2.0           0     0         great  ...        2240              0
# 488       2.0           0     0          good  ...        3860           1000
# ...       ...         ...   ...           ...  ...         ...            ...
# 20986     2.0           0     0          good  ...        2732              0
# 21087     2.0           0     0          good  ...        2800              0
# 21188     2.0           0     0          good  ...        2440            950
# 21377     2.0           0     0          good  ...        3260           1050
# 21524     2.0           0     0          good  ...        2390              0
#
#        yr_built  year_renovated  zipcode      lat     long  sqft_living15  \
# 211        1920            1994    98133  47.7067 -122.343           1560
# 234        1978               0    98023  47.3103 -122.339           2120
# 241        1965               0    98003  47.3376 -122.324           2600
# 333        1955               0    98198  47.4200 -122.323           1590
# 488        1998               0    98006  47.5521 -122.137           3600
# ...         ...             ...      ...      ...      ...            ...
# 20986      2009               0    98002  47.3045 -122.211           3078
# 21087      1998               0    98117  47.6892 -122.389           1440
# 21188      2007               0    98118  47.5205 -122.288           2040
# 21377      2013               0    98059  47.5297 -122.155           4620
# 21524      2014               0    98118  47.5173 -122.286           1680
#
#        sqft_lot15         city
# 211          1312      Seattle
# 234          8236  Federal Way
# 241         13988  Federal Way
# 333          7955   Des Moines
# 488         11793     Bellevue
# ...           ...          ...
# 20986       69993       Auburn
# 21087        3960      Seattle
# 21188        7214      Seattle
# 21377       10217       Renton
# 21524        5000      Seattle
#
# [329 rows x 21 columns]

# %%
#df=df[df['bedrooms']<30]

# %%
#df.shape

# %% [markdown]
# ## 4. Revisar y comprender los datos seleccionados en términos de tamaño y tipo de datos usando número y nombre de las columnas.

# %% [markdown]
# Después de fusionarlos, es posible saber en qué ciudades están las casas.  Las ciudades son:

# %%
df['city'].unique()
# Out:
# array(['Seattle', 'Kenmore', 'Sammamish', 'Union Hill-Novelty Hill',
#        'Federal Way', 'Des Moines', 'Maple Valley', 'Bellevue', 'Duvall',
#        'Auburn', 'Mercer Island', 'Kent', 'Redmond', 'Issaquah', 'Renton',
#        'Newcastle', 'Normandy Park', 'Vashon', 'Covington', 'Kirkland',
#        'Black Diamond', 'North Bend', 'Woodinville', 'Burien',
#        'Snoqualmie', 'Enumclaw', 'Shoreline', 'Fall City', 'Bothell',
#        'Seatac', 'Carnation', 'Medina'], dtype=object)

# %% [markdown]
# Ahora, se cuentan:

# %%
df['city'].unique().shape
#len(df['city'].unique())
# Out:
# (32,)

# %% [markdown]
# Para ver cuántas de las casas se vendieron en cada ciudad:

# %%
df['city'].value_counts()
# Out:
# Seattle                    7535
# Bellevue                   1407
# Renton                     1191
# Auburn                     1037
# Kirkland                    977
# Sammamish                   800
# Federal Way                 779
# Issaquah                    733
# Maple Valley                590
# Redmond                     574
# Covington                   548
# Kent                        530
# Woodinville                 471
# Shoreline                   446
# Newcastle                   406
# Union Hill-Novelty Hill     405
# Des Moines                  336
# Snoqualmie                  310
# Kenmore                     283
# Mercer Island               282
# Burien                      269
# Normandy Park               254
# Enumclaw                    234
# North Bend                  221
# Bothell                     195
# Duvall                      190
# Seatac                      136
# Carnation                   124
# Vashon                      118
# Black Diamond               100
# Fall City                    81
# Medina                       50
# Name: city, dtype: int64

# %% [markdown]
# En este caso, interesan las primeras 10 ciudades donde se vendieron más casas:

# %%
df['city'].value_counts().nlargest(10)
# Out:
# Seattle         7535
# Bellevue        1407
# Renton          1191
# Auburn          1037
# Kirkland         977
# Sammamish        800
# Federal Way      779
# Issaquah         733
# Maple Valley     590
# Redmond          574
# Name: city, dtype: int64

# %%
# o por el contrario:

df['city'].value_counts().nsmallest(10)
# Out:
# Medina            50
# Fall City         81
# Black Diamond    100
# Vashon           118
# Carnation        124
# Seatac           136
# Duvall           190
# Bothell          195
# North Bend       221
# Enumclaw         234
# Name: city, dtype: int64

# %% [markdown]
# Solamente en ciudad `Seattle`

# %%
df['city'].value_counts()['Seattle']
# Out:
# 7535

# %% [markdown]
# A continuación, se utilizará una herramienta más potente llamada `groupby`, para organizar y extraer la información. Entonces, se agrupa todo el conjunto de datos en términos de ciudad y se encuentran los valores medios - `mean` (`max` o `min`) de cada columna.

# %%
df.groupby(['city']).mean()
# Out:
#                                 price  bedrooms  bathrooms  sqft_living  \
# city
# Auburn                   2.866376e+05  3.413693   2.017358  1928.605593
# Bellevue                 8.981876e+05  3.821606   2.401386  2642.721393
# Black Diamond            4.236660e+05  3.290000   2.027500  2137.590000
# Bothell                  4.903515e+05  3.548718   2.278205  2253.097436
# Burien                   2.403284e+05  2.996283   1.433086  1468.624535
# Carnation                4.556171e+05  3.000000   2.048387  2117.967742
# Covington                3.116321e+05  3.397810   2.126825  1982.259124
# Des Moines               3.001708e+05  3.178571   1.789435  1723.991071
# Duvall                   4.247887e+05  3.363158   2.290789  2171.557895
# Enumclaw                 3.157093e+05  3.149573   1.910256  1832.324786
# Fall City                5.805268e+05  3.296296   2.163580  2337.469136
# Federal Way              2.893849e+05  3.400513   2.056483  1967.858793
# Issaquah                 6.150913e+05  3.488404   2.525580  2413.709413
# Kenmore                  4.624800e+05  3.480565   2.143110  2122.724382
# Kent                     2.984378e+05  3.492453   2.154717  1946.539623
# Kirkland                 6.463742e+05  3.508700   2.216479  2156.711361
# Maple Valley             3.668676e+05  3.435593   2.375847  2147.715254
# Medina                   2.160607e+06  4.060000   3.200000  3800.900000
# Mercer Island            1.194230e+06  4.028369   2.716312  3106.833333
# Newcastle                4.208905e+05  3.435961   2.044951  2017.096059
# Normandy Park            4.642318e+05  3.377953   1.911417  2067.905512
# North Bend               4.394711e+05  3.230769   2.110860  2063.823529
# Redmond                  6.452315e+05  3.616725   2.364547  2363.655052
# Renton                   3.974952e+05  3.532326   2.159110  2129.121746
# Sammamish                7.327115e+05  3.728750   2.605625  2812.132500
# Seatac                   2.890783e+05  3.433824   1.863971  1802.772059
# Seattle                  5.694047e+05  3.154479   1.919608  1801.347976
# Shoreline                4.237257e+05  3.322870   1.815022  1786.614350
# Snoqualmie               5.279612e+05  3.522581   2.545161  2571.322581
# Union Hill-Novelty Hill  6.781631e+05  3.212346   2.448148  2620.879012
# Vashon                   4.874796e+05  2.754237   1.900424  1880.271186
# Woodinville              6.173845e+05  3.520170   2.336518  2575.715499
#
#                               sqft_lot    floors  waterfront      view  \
# city
# Auburn                    18906.898746  1.445034    0.000000  0.093539
# Bellevue                  13186.778252  1.371357    0.009950  0.403696
# Black Diamond             55465.300000  1.480000    0.000000  0.100000
# Bothell                   11314.138462  1.502564    0.000000  0.061538
# Medina                     3132.200000  17291.100000
# Mercer Island              2898.744681  12801.283688
# Newcastle                  1906.736453   7828.660099
# Normandy Park              1886.850394  12694.322835
# North Bend                 1913.778281  32183.325792
# Redmond                    2333.726481  10065.177700
# Renton                     2079.863140  11942.722082
# Sammamish                  2762.422500  14021.308750
# Seatac                     1636.279412   9752.801471
# Seattle                    1681.861447   5412.456669
# Shoreline                  1716.710762   9812.881166
# Snoqualmie                 2518.274194  11241.748387
# Union Hill-Novelty Hill    2475.049383  29086.414815
# Vashon                     1776.949153  81290.864407
# Woodinville                2535.562633  33020.301486

# %% [markdown]
# Parece demasiada información. Ahora, se verá cuál fue el precio más alto que alguien pagó en cada ciudad:

# %%
df.groupby(['city']).max()['price']
# Out:
# city
# Auburn                      930000.0
# Bellevue                   7062500.0
# Black Diamond               935000.0
# Bothell                    1075000.0
# Burien                      600000.0
# Carnation                  1680000.0
# Covington                   859000.0
# Des Moines                 1350000.0
# Duvall                     1015000.0
# Enumclaw                    858000.0
# Fall City                  1862000.0
# Federal Way                1275000.0
# Issaquah                   2700000.0
# Kenmore                    1600000.0
# Kent                        800000.0
# Kirkland                   5110800.0
# Maple Valley               1350000.0
# Medina                     6885000.0
# Mercer Island              5300000.0
# Newcastle                  3000000.0
# Normandy Park              2510000.0
# North Bend                 1950000.0
# Redmond                    2200000.0
# Renton                     1780000.0
# Sammamish                  3200000.0
# Seatac                      707000.0
# Seattle                    7700000.0
# Shoreline                  4500000.0
# Snoqualmie                 1998000.0
# Union Hill-Novelty Hill    2280000.0
# Vashon                     1379900.0
# Woodinville                1920000.0
# Name: price, dtype: float64

# %% [markdown]
# El resultado, como se mencionó anteriormente, no es un DataFrame, sino un DataSeries

# %%
type(df.groupby(['city']).max()['price'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Para convertir el resultado del `groupby` en un DataFrame podemos añadir al final metodo `.reset_index()`

# %%
# método: .reset_index() después de aplicar 'groupby' creará un nuevo marco de datos Pandas con un nuevo índice.
df.groupby(['city']).max()['price'].reset_index()
# Out:
#                        city      price
# 0                    Auburn   930000.0
# 1                  Bellevue  7062500.0
# 2             Black Diamond   935000.0
# 3                   Bothell  1075000.0
# 4                    Burien   600000.0
# 5                 Carnation  1680000.0
# 6                 Covington   859000.0
# 7                Des Moines  1350000.0
# 8                    Duvall  1015000.0
# 9                  Enumclaw   858000.0
# 10                Fall City  1862000.0
# 11              Federal Way  1275000.0
# 12                 Issaquah  2700000.0
# 13                  Kenmore  1600000.0
# 14                     Kent   800000.0
# 15                 Kirkland  5110800.0
# 16             Maple Valley  1350000.0
# 17                   Medina  6885000.0
# 18            Mercer Island  5300000.0
# 19                Newcastle  3000000.0
# 20            Normandy Park  2510000.0
# 21               North Bend  1950000.0
# 22                  Redmond  2200000.0
# 23                   Renton  1780000.0
# 24                Sammamish  3200000.0
# 25                   Seatac   707000.0
# 26                  Seattle  7700000.0
# 27                Shoreline  4500000.0
# 28               Snoqualmie  1998000.0
# 29  Union Hill-Novelty Hill  2280000.0
# 30                   Vashon  1379900.0
# 31              Woodinville  1920000.0

# %%
type(df.groupby(['city']).max()['price'].reset_index())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# También podemos encontrar valores `nlargest` en el subconjunto seleccionado:

# %%
df.groupby(['city']).max()['price'].nlargest(10)
# Out:
# city
# Seattle          7700000.0
# Bellevue         7062500.0
# Medina           6885000.0
# Mercer Island    5300000.0
# Kirkland         5110800.0
# Shoreline        4500000.0
# Sammamish        3200000.0
# Newcastle        3000000.0
# Issaquah         2700000.0
# Normandy Park    2510000.0
# Name: price, dtype: float64

# %% [markdown]
# En esas ciudades las casas se vendieron por más de un millón de dólares.

# %% [markdown]
# *Es importante tener en cuenta que tanto `groupby` como todo el paquete Pandas no son fáciles, pero con un poco de práctica tendrá una herramienta poderosa a su disposición.

# %% [markdown]
# Acá se observa cómo se distribuyeron los precios máximos entre el número de habitaciones:

# %%
df.groupby(['city']).mean()
# Out:
#                                 price  bedrooms  bathrooms  sqft_living  \
# city
# Auburn                   2.866376e+05  3.413693   2.017358  1928.605593
# Bellevue                 8.981876e+05  3.821606   2.401386  2642.721393
# Black Diamond            4.236660e+05  3.290000   2.027500  2137.590000
# Bothell                  4.903515e+05  3.548718   2.278205  2253.097436
# Burien                   2.403284e+05  2.996283   1.433086  1468.624535
# Carnation                4.556171e+05  3.000000   2.048387  2117.967742
# Covington                3.116321e+05  3.397810   2.126825  1982.259124
# Des Moines               3.001708e+05  3.178571   1.789435  1723.991071
# Duvall                   4.247887e+05  3.363158   2.290789  2171.557895
# Enumclaw                 3.157093e+05  3.149573   1.910256  1832.324786
# Fall City                5.805268e+05  3.296296   2.163580  2337.469136
# Federal Way              2.893849e+05  3.400513   2.056483  1967.858793
# Issaquah                 6.150913e+05  3.488404   2.525580  2413.709413
# Kenmore                  4.624800e+05  3.480565   2.143110  2122.724382
# Kent                     2.984378e+05  3.492453   2.154717  1946.539623
# Kirkland                 6.463742e+05  3.508700   2.216479  2156.711361
# Maple Valley             3.668676e+05  3.435593   2.375847  2147.715254
# Medina                   2.160607e+06  4.060000   3.200000  3800.900000
# Mercer Island            1.194230e+06  4.028369   2.716312  3106.833333
# Newcastle                4.208905e+05  3.435961   2.044951  2017.096059
# Normandy Park            4.642318e+05  3.377953   1.911417  2067.905512
# North Bend               4.394711e+05  3.230769   2.110860  2063.823529
# Redmond                  6.452315e+05  3.616725   2.364547  2363.655052
# Renton                   3.974952e+05  3.532326   2.159110  2129.121746
# Sammamish                7.327115e+05  3.728750   2.605625  2812.132500
# Seatac                   2.890783e+05  3.433824   1.863971  1802.772059
# Seattle                  5.694047e+05  3.154479   1.919608  1801.347976
# Shoreline                4.237257e+05  3.322870   1.815022  1786.614350
# Snoqualmie               5.279612e+05  3.522581   2.545161  2571.322581
# Union Hill-Novelty Hill  6.781631e+05  3.212346   2.448148  2620.879012
# Vashon                   4.874796e+05  2.754237   1.900424  1880.271186
# Woodinville              6.173845e+05  3.520170   2.336518  2575.715499
#
#                               sqft_lot    floors  waterfront      view  \
# city
# Auburn                    18906.898746  1.445034    0.000000  0.093539
# Bellevue                  13186.778252  1.371357    0.009950  0.403696
# Black Diamond             55465.300000  1.480000    0.000000  0.100000
# Kirkland                   2044.541453   9124.615148
# Maple Valley               2118.422034  20054.767797
# Medina                     3132.200000  17291.100000
# Mercer Island              2898.744681  12801.283688
# Newcastle                  1906.736453   7828.660099
# Normandy Park              1886.850394  12694.322835
# North Bend                 1913.778281  32183.325792
# Redmond                    2333.726481  10065.177700
# Renton                     2079.863140  11942.722082
# Sammamish                  2762.422500  14021.308750
# Seatac                     1636.279412   9752.801471
# Seattle                    1681.861447   5412.456669
# Shoreline                  1716.710762   9812.881166
# Snoqualmie                 2518.274194  11241.748387
# Union Hill-Novelty Hill    2475.049383  29086.414815
# Vashon                     1776.949153  81290.864407
# Woodinville                2535.562633  33020.301486

# %%
df.groupby(['city','bedrooms']).max()['price'].nlargest(10)
# Out:
# city           bedrooms
# Seattle        6           7700000.0
# Bellevue       5           7062500.0
# Medina         6           6885000.0
#                5           5570000.0
# Mercer Island  6           5300000.0
# Kirkland       5           5110800.0
# Mercer Island  5           4668000.0
# Shoreline      5           4500000.0
# Bellevue       4           4489000.0
# Medina         4           4000000.0
# Name: price, dtype: float64

# %% [markdown]
# Y, aquí, las casas más vendidas con respecto al número de habitaciones:

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2759
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# A veces es más fácil comprender las cosas visualizándolas; el paquete Seaborn es excelente para esta tarea, ya que está bien integrado con Pandas. Para mostrar la frecuencia del valor discreto, se usará seaborn countplot `sns.countplot`, los parámetros son: `data=df`. Lo que significa que se quiere usar todo el conjunto de datos de Panda y x=`bedrooms` es el nombre de la columna.

# %%
sns.set(rc={"figure.figsize":(10, 6)}) # tamano del plot
sns.countplot(data=df, x='bedrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# Luego, se observa qué rango de precios en los que se vendieron las casas fueron los más comunes. Como los precios no son variables discretas sino continuas, puede usarse `sns.histplot`

# %%
sns.set(rc={"figure.figsize":(10, 6)})
sns.histplot(data=df, x="price", bins=30)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# Una de las características más importantes que influye en el precio de la casa es su tamaño. Aquí se visualiza usando `sns.scatterplot`:

# %%
df.columns

# columns_list=df.columns.to_list() # si es necesario, podemos convertir los nombres de las columnas en una lista
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition str', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'year_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'city'],
#       dtype='object')

# %%
sns.set(rc={"figure.figsize":(10, 6)})
sns.scatterplot(data=df, x='sqft_living',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# La dependencia de precio de la casa de su tamaño es fuerte y es casi lineal.

# %% [markdown]
# También, es interesante ver cómo la ubicación geográfica de la casa influye en su popularidad. Seguidamente, se grafica la longitud frente a la latitud, pero incluyendo la distribución usando `sns.jointplot()`:

# %%
sns.set(rc={"figure.figsize":(10, 6)})
sns.jointplot(data=df, x="lat", y="long")

# %% [markdown]
# Para la latitud entre -47.7 y -48.8 hay muchas casas, lo que significaría que, tal vez, sea una ubicación ideal. Pero cuando hablamos de longitud puede verse que la concentración es alta entre -122.2 a -122.4. Es decir, que la mayoría de las compras han sido para esta ubicación en particular.

# %% [markdown]
# Para ver la dependencia entre varias características de la casa deben seleccionarse las características que son de interés y trazar todas las combinaciones posibles usando `sns.pairplot()`.

# %%
df_selection=df[['price', 'bedrooms','sqft_living']]

# %%
sns.set(rc={"figure.figsize":(10, 6)})
sns.pairplot(df_selection)

# %% [markdown]
# En este apartado pudo verse cómo cada variable depende una de la otra. Por ejemplo, se ve claramente la distribución del precio de la vivienda con respecto al número de dormitorios. Pero también, que el tamaño de la casa, en promedio, depende del número de dormitorios.

# %% [markdown]
# #### Modificación de los valores dentro de Pandas mediante funciones:

# %% [markdown]
# Veamos la columna `['condición']`. Podemos ver cuántos valores únicos tiene esta columna usando `unique()`:

# %%
df['condition str'].unique()
# Out:
# array(['good', 'excellent', 'great', 'bad', 'moderate'], dtype=object)

# %% [markdown]
# y podemos contarlos con `nunique()`

# %%
df['condition str'].nunique()
# Out:
# 5

# %% [markdown]
# Grafiquemos la distribución de las casas con cada condición usando `sns.boxplot()` (con una línea de valor medio (roja))

# %%
sns.set(rc={"figure.figsize":(10, 6)})
ax=sns.boxplot(x='condition str',y='price',data=df)
ax.axhline(df['price'].mean(),color='r',linestyle='dashed',linewidth=2) # linear roja con valor promedio
ax.set_ylim([0,2.0e6])
# Out:
# (0.0, 2000000.0)

# %% [markdown]
# Al aprendizaje automático le gustan los valores numéricos, por lo que podemos cambiar las cadenas en la columna ['condición str'] a valores numéricos ['condición']. En pandas tenemos varias formas de modificar los datos dentro:

# %% [markdown]
# * método `df['column_name].replace([list_values_old],[list_values_new])`

# %%
df['condition'] = df['condition str'].replace(['bad','moderate','good','great','excellent'],[1,2,3,4,5])

# %%
df[['condition str','condition']]
# Out:
#       condition str  condition
# 0              good          3
# 1              good          3
# 2              good          3
# 3         excellent          5
# 4              good          3
# ...             ...        ...
# 21610          good          3
# 21611          good          3
# 21612          good          3
# 21613          good          3
# 21614          good          3
#
# [21612 rows x 2 columns]

# %% [markdown]
# * método `function + apply`.
#
# Hay un método más versátil. Se basa en el uso de una función en cada valor de la columna dada. Primero debemos definir la función que recibe un valor de cada celda de una columna dada y luego devolver un nuevo valor. Despues podemos llamar a esa función en los valores de una columna usando el método `apply`. Usando el mismo ejemplo que antes:

# %%
def my_func(val):
    new_val=0
    if val=='excellent':
        new_val=5
    elif val=='great':
        new_val=4
    elif val=='good':
        new_val=3
    elif val=='moderate':
        new_val=2
    elif val=='bad':
        new_val=1
    return new_val

# %%
df['condition'] = df['condition str'].apply(my_func)

# %%
df[['condition str','condition']]
# Out:
#       condition str  condition
# 0              good          3
# 1              good          3
# 2              good          3
# 3         excellent          5
# 4              good          3
# ...             ...        ...
# 21610          good          3
# 21611          good          3
# 21612          good          3
# 21613          good          3
# 21614          good          3
#
# [21612 rows x 2 columns]

# %% [markdown]
# El uso de un método de función y `apply` es muy poderoso porque permite cualquier operación en la celda, ya sea una simple multiplicación o extracción de texto!
