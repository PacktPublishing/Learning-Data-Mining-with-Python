# %%
import pandas as pd
import numpy as np

# %%
url1 = "https://raw.githubusercontent.com/mhemmg/datasets/master/car_emission/cars_CO2_emissions_D.csv"
url2 = "https://raw.githubusercontent.com/mhemmg/datasets/master/car_emission/car_brands_countries.csv"

# %%
df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)

# %%
df1
# Out:
#        Make             Model   Vehicle Class Engine Size(L)  Cylinders  \
# 0     ACURA               ILX         COMPACT            2.0        4.0
# 1     ACURA               ILX         COMPACT            2.4        4.0
# 2     ACURA        ILX HYBRID         COMPACT            1.5        4.0
# 3     ACURA           MDX 4WD     SUV - SMALL            3.5        6.0
# 4     ACURA           RDX AWD     SUV - SMALL            3.5        6.0
# ...     ...               ...             ...            ...        ...
# 6272  VOLVO       XC60 T5 AWD     SUV - SMALL            2.0        4.0
# 6273  VOLVO       XC60 T6 AWD     SUV - SMALL            2.0        4.0
# 6274  VOLVO       XC90 T5 AWD  SUV - STANDARD            2.0        4.0
# 6275  VOLVO       XC90 T6 AWD  SUV - STANDARD            2.0        4.0
# 6276  SMART  FORTWO CABRIOLET      TWO-SEATER            0.9       12.0
#
#      Transmission         Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
df2
# Out:
#              Make        Country Continent
# 0           ACURA            USA   America
# 1      ALFA ROMEO          Italy    Europe
# 2    ASTON MARTIN  Great Britain    Europe
# 3            AUDI        Germany    Europe
# 4         BENTLEY  Great Britain    Europe
# 5             BMW        Germany    Europe
# 6           BUICK            USA   America
# 7        CADILLAC            USA   America
# 8       CHEVROLET            USA   America
# 9        CHRYSLER            USA   America
# 10          DODGE            USA   America
# 11           FIAT          Italy    Europe
# 12           FORD            USA   America
# 13            GMC            USA   America
# 14          HONDA          Japan      Asia
# 15        HYUNDAI          Korea      Asia
# 16       INFINITI            USA   America
# 17         JAGUAR  Great Britain    Europe
# 18           JEEP            USA   America
# 19            KIA          Korea      Asia
# 20    LAMBORGHINI          Italy    Europe
# ...

# %% [markdown]
# ## 1. Carga y limpieza de los datos

# %%
# Both DataFrames have the same values in the Make column
df2['Make'].unique() == df1['Make'].unique()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
# Making a merge between df1 and df2
df_ = df1.merge(df2)

# %%
# Printing the first 10 rows
df_.head(10)
# Out:
#     Make       Model Vehicle Class Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT            2.0        4.0          AS5
# 1  ACURA         ILX       COMPACT            2.4        4.0           M6
# 2  ACURA  ILX HYBRID       COMPACT            1.5        4.0          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL            3.5        6.0          AS6
# 4  ACURA     RDX AWD   SUV - SMALL            3.5        6.0          AS6
# 5  ACURA         RLX      MID-SIZE            3.5        6.0          AS6
# 6  ACURA          TL      MID-SIZE            3.5        6.0          AS6
# 7  ACURA      TL AWD      MID-SIZE            3.7        6.0          AS6
# 8  ACURA      TL AWD      MID-SIZE            3.7        6.0           M6
# 9  ACURA         TSX       COMPACT            2.4        4.0          AS5
#
#           Fuel Type  Fuel Consumption City (L/100 km)  \
# 0  premium gasoline                               9.9
# ...

# %%
# Printing the last 10 rows
df_.tail(10)
# Out:
#          Make    Model Vehicle Class Engine Size(L)  Cylinders Transmission  \
# 6267  GENESIS  G80 AWD     FULL-SIZE            5.0        8.0          AS8
# 6268  GENESIS      G70       COMPACT            2.0        4.0           M6
# 6269  GENESIS  G70 AWD       COMPACT            2.0        4.0          AS8
# 6270  GENESIS  G70 AWD       COMPACT            3.3        6.0          AS8
# 6271  GENESIS  G70 AWD       COMPACT            2.0        4.0          AS8
# 6272  GENESIS  G70 AWD       COMPACT            3.3        6.0          AS8
# 6273  GENESIS  G90 AWD     FULL-SIZE            3.3        6.0          AS8
# 6274  GENESIS  G90 AWD     FULL-SIZE            5.0        8.0          AS8
# 6275  BUGATTI   CHIRON    TWO-SEATER            8.0       16.0          AM7
# 6276  BUGATTI   Chiron    TWO-SEATER            8.0       16.0          AM7
#
#              Fuel Type  Fuel Consumption City (L/100 km)  \
# 6267  premium gasoline                              15.6
# ...

# %%
# Columns' names of the DataFrame
print(f"There are {len(df_.columns)} columns in the dataframe")
df_.columns
# Out:
# There are 14 columns in the dataframe
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)', 'Country',
#        'Continent'],
#       dtype='object')

# %%
rows, columns = df_.shape
print('Number of rows (registers): ', rows)
print('Number of columns:', columns)
# Out:
# Number of rows (registers):  6277
# Number of columns: 14

# %%
# Show the total NaN in the DataFrame
df_.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    1
# Fuel Consumption Hwy (L/100 km)     2
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# Country                             0
# Continent                           0
# dtype: int64

# %%
# Number of total NaN values in the Dataframe
df_.isnull().sum().sum()
# Out:
# 3

# %%
# Replacing the string '?' for NaN
df = df_.replace(r"?", np.nan)

# %%
# There were 3 values with ? string
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      1
# Cylinders                           0
# Transmission                        2
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    1
# Fuel Consumption Hwy (L/100 km)     2
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# Country                             0
# Continent                           0
# dtype: int64

# %%
# Number of total NaN values in the Dataframe
df.isnull().sum().sum()
# Out:
# 6

# %%
# Delete the rows with NaN values
df = df.dropna()

# %%
# There were 6 rows with any NaN value
df.shape
# Out:
# (6271, 14)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# Lower case for strings in the DataFrame 
for col in df.columns:
    try:
        df[col] = df[col].str.lower()
    except:
        pass

# %%
# There are duplicate rows
df[df.duplicated(keep=False)]
# Out:
#             Make                    Model          Vehicle Class  \
# 31         acura           mdx hybrid awd            suv - small
# 36         acura               rlx hybrid               mid-size
# 44         acura           mdx hybrid awd            suv - small
# 47         acura               rlx hybrid               mid-size
# 53    alfa romeo                4c spider             two-seater
# ...          ...                      ...                    ...
# 6125  volkswagen  golf sportwagen 4motion  station wagon - small
# 6126  volkswagen  golf sportwagen 4motion  station wagon - small
# 6131  volkswagen                   passat               mid-size
# 6275     bugatti                   chiron             two-seater
# 6276     bugatti                   chiron             two-seater
#
#      Engine Size(L)  Cylinders Transmission         Fuel Type  \
# 31              3.0        6.0          am7  premium gasoline
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#          Make       Model Vehicle Class Engine Size(L)  Cylinders  \
# 0       acura         ilx       compact            2.0        4.0
# 1       acura         ilx       compact            2.4        4.0
# 2       acura  ilx hybrid       compact            1.5        4.0
# 3       acura     mdx 4wd   suv - small            3.5        6.0
# 4       acura     rdx awd   suv - small            3.5        6.0
# ...       ...         ...           ...            ...        ...
# 6271  genesis     g70 awd       compact            2.0        4.0
# 6272  genesis     g70 awd       compact            3.3        6.0
# 6273  genesis     g90 awd     full-size            3.3        6.0
# 6274  genesis     g90 awd     full-size            5.0        8.0
# 6275  bugatti      chiron    two-seater            8.0       16.0
#
#      Transmission         Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             as5  premium gasoline                               9.9
# ...

# %%
# Without duplicated rows
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km), Country, Continent]
# Index: []

# %% [markdown]
# ## 2. Adición y cambio de las características

# %%
df['Fuel Type'].unique()
# Out:
# array(['premium gasoline', 'diesel', 'regular gasoline', 'ethanol',
#        'natural gas'], dtype=object)

# %%
# Function to convert the values of the column Fuel Type
# X = gasolina regular, Z = gasolina premium, D = diesel, E = etanol (E85), N = gas natural
def convert(string):
    
    new_string = ''
    
    if string == 'regular gasoline':
        new_string = 'X'
    if string == 'premium gasoline':
        new_string = 'Z'
    if string == 'diesel':
        new_string = 'D'
    if string == 'ethanol':
        new_string = 'E'
    if string == 'natural gas':
        new_string = 'N'
        
    return new_string

# %%
# %time
new_fueltype_column = list(map(convert, df['Fuel Type']))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.63 µs

# %%
# %time
s = df['Fuel Type'].apply(convert)
# Out:
# CPU times: user 9 µs, sys: 1 µs, total: 10 µs
# Wall time: 19.6 µs

# %%
df['Fuel Type'] = df['Fuel Type'].apply(convert)

# %%
df
# Out:
#          Make       Model Vehicle Class Engine Size(L)  Cylinders  \
# 0       acura         ilx       compact            2.0        4.0
# 1       acura         ilx       compact            2.4        4.0
# 2       acura  ilx hybrid       compact            1.5        4.0
# 3       acura     mdx 4wd   suv - small            3.5        6.0
# 4       acura     rdx awd   suv - small            3.5        6.0
# ...       ...         ...           ...            ...        ...
# 6271  genesis     g70 awd       compact            2.0        4.0
# 6272  genesis     g70 awd       compact            3.3        6.0
# 6273  genesis     g90 awd     full-size            3.3        6.0
# 6274  genesis     g90 awd     full-size            5.0        8.0
# 6275  bugatti      chiron    two-seater            8.0       16.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             as5         Z                               9.9
# ...

# %%
df['Fuel Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['as5', 'm6', 'av7', 'as6', 'am7', 'am8', 'as9', 'am9', 'as10',
#        'am6', 'a8', 'a6', 'm7', 'av8', 'as8', 'a7', 'as7', 'a9', 'av',
#        'a10', 'a4', 'm5', 'a5', 'av6', 'av10', 'as4', 'am5'], dtype=object)

# %%
# Function to convert the strings with 'a' (automatic) with 'A' and Manual with 'M'
def func(word):
    if 'a' in word:
        return 'A'
    else:
        return 'M'

# %%
df['Automatic / Manual'] = df['Transmission'].apply(func)

# %%
df
# Out:
#          Make       Model Vehicle Class Engine Size(L)  Cylinders  \
# 0       acura         ilx       compact            2.0        4.0
# 1       acura         ilx       compact            2.4        4.0
# 2       acura  ilx hybrid       compact            1.5        4.0
# 3       acura     mdx 4wd   suv - small            3.5        6.0
# 4       acura     rdx awd   suv - small            3.5        6.0
# ...       ...         ...           ...            ...        ...
# 6271  genesis     g70 awd       compact            2.0        4.0
# 6272  genesis     g70 awd       compact            3.3        6.0
# 6273  genesis     g90 awd     full-size            3.3        6.0
# 6274  genesis     g90 awd     full-size            5.0        8.0
# 6275  bugatti      chiron    two-seater            8.0       16.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             as5         Z                               9.9
# ...

# %%
df['A/M digital'] = df['Automatic / Manual'].replace(r"A", 1)
df['A/M digital'] = df['A/M digital'].replace(r"M", 0)

# %%
df
# Out:
#          Make       Model Vehicle Class Engine Size(L)  Cylinders  \
# 0       acura         ilx       compact            2.0        4.0
# 1       acura         ilx       compact            2.4        4.0
# 2       acura  ilx hybrid       compact            1.5        4.0
# 3       acura     mdx 4wd   suv - small            3.5        6.0
# 4       acura     rdx awd   suv - small            3.5        6.0
# ...       ...         ...           ...            ...        ...
# 6271  genesis     g70 awd       compact            2.0        4.0
# 6272  genesis     g70 awd       compact            3.3        6.0
# 6273  genesis     g90 awd     full-size            3.3        6.0
# 6274  genesis     g90 awd     full-size            5.0        8.0
# 6275  bugatti      chiron    two-seater            8.0       16.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             as5         Z                               9.9
# ...

# %% [markdown]
# ## 3. Extracción de información

# %%
df['Make'].unique()
# Out:
# array(['acura', 'alfa romeo', 'aston martin', 'audi', 'bentley', 'bmw',
#        'buick', 'cadillac', 'chevrolet', 'chrysler', 'dodge', 'fiat',
#        'ford', 'gmc', 'honda', 'hyundai', 'infiniti', 'jaguar', 'jeep',
#        'kia', 'lamborghini', 'land rover', 'lexus', 'lincoln', 'maserati',
#        'mazda', 'mercedes-benz', 'mini', 'mitsubishi', 'nissan',
#        'porsche', 'ram', 'rolls-royce', 'scion', 'smart', 'srt', 'subaru',
#        'toyota', 'volkswagen', 'volvo', 'genesis', 'bugatti'],
#       dtype=object)

# %%
# Number of cars brands
df['Make'].nunique()
# Out:
# 42

# %%
marc_cars = df.groupby(['Make']).count()
# Cars numbers for marc
marc_cars['Model']
# Out:
# Make
# acura             48
# alfa romeo        13
# aston martin      39
# audi             261
# bentley           35
# bmw              488
# bugatti            1
# buick             91
# cadillac         139
# chevrolet        503
# chrysler          62
# dodge            151
# fiat              54
# ford             563
# genesis           14
# gmc              278
# honda            144
# hyundai          171
# infiniti          86
# jaguar           101
# jeep             188
# kia              182
# lamborghini       37
# land rover        73
# lexus            129
# lincoln           78
# maserati          49
# mazda            125
# mercedes-benz    362
# mini             187
# mitsubishi        71
# nissan           192
# porsche          257
# ram               71
# rolls-royce       44
# scion             21
# smart              8
# srt                2
# subaru           112
# toyota           252
# volkswagen       180
# volvo            118
# ...

# %%
# The 10 most common brands
marc_cars['Model'].nlargest(10)
# Out:
# Make
# ford             563
# chevrolet        503
# bmw              488
# mercedes-benz    362
# gmc              278
# audi             261
# porsche          257
# toyota           252
# nissan           192
# jeep             188
# Name: Model, dtype: int64

# %%
# The 10 less common brands
marc_cars['Model'].nsmallest(10)
# Out:
# Make
# bugatti          1
# srt              2
# smart            8
# alfa romeo      13
# genesis         14
# scion           21
# bentley         35
# lamborghini     37
# aston martin    39
# rolls-royce     44
# Name: Model, dtype: int64

# %%
# The car with the less emission of CO2
# df[df['CO2 Emissions(g/km)'] == df['CO2 Emissions(g/km)'].min()].iloc[0]
df[df['CO2 Emissions(g/km)'] == df['CO2 Emissions(g/km)'].min()]
# Out:
#          Make       Model Vehicle Class Engine Size(L)  Cylinders  \
# 3078  hyundai  ioniq blue     full-size            1.6        4.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3078          am6         X                               4.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 3078                              4.0                               4.1
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km) Country Continent  \
# 3078                         69.0                 96.0   korea      asia
#
#      Automatic / Manual  A/M digital
# 3078                  A            1

# %%
# The car with the most emission of CO2
df[df['CO2 Emissions(g/km)'] == df['CO2 Emissions(g/km)'].max()]
# Out:
#          Make   Model Vehicle Class Engine Size(L)  Cylinders Transmission  \
# 6275  bugatti  chiron    two-seater            8.0       16.0          am7
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 6275         Z                              26.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 6275                             16.6                              22.2
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km) Country Continent  \
# 6275                         13.0                522.0   italy    europe
#
#      Automatic / Manual  A/M digital
# 6275                  A            1

# %%
# Mean of C02 emission for brand of car
df.groupby(['Make']).mean()['CO2 Emissions(g/km)']
# Out:
# Make
# acura            222.020833
# alfa romeo       236.384615
# aston martin     344.282051
# audi             252.318008
# bentley          367.914286
# bmw              252.709016
# bugatti          522.000000
# buick            233.747253
# cadillac         266.366906
# chevrolet        264.669980
# chrysler         243.725806
# dodge            275.562914
# fiat             192.518519
# ford             261.591474
# genesis          282.571429
# gmc              301.910072
# honda            190.923611
# hyundai          210.549708
# infiniti         253.953488
# jaguar           273.138614
# jeep             249.627660
# kia              215.445055
# lamborghini      402.270270
# land rover       290.301370
# lexus            242.124031
# lincoln          266.974359
# maserati         319.612245
# mazda            192.680000
# mercedes-benz    278.729282
# mini             196.165775
# mitsubishi       199.704225
# nissan           237.104167
# porsche          261.482490
# ...

# %%
# Mean of C02 emission for continent
df.groupby(['Continent']).mean()['CO2 Emissions(g/km)']
# Out:
# Continent
# america    266.177221
# asia       216.318084
# europe     258.690941
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# ## 4. Trazado

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(13,8)})
mean_Co2_emission = df['CO2 Emissions(g/km)'].mean()
sns.boxplot(x='Continent', y='CO2 Emissions(g/km)', data=df)
plt.hlines(mean_Co2_emission, xmin=-0.5, xmax=2.5, color='red', linestyles='--')

# %% [markdown]
# A través del boxplot anterior se puede inferir que el continente con un promedio más alto en la emisión de CO2 a causa de los automoviles es `América`, y que el que menos emisión tiene es `Asia`

# %%
sns.boxplot(x='Automatic / Manual', y='CO2 Emissions(g/km)', data=df)
plt.hlines(mean_Co2_emission, xmin=-0.5, xmax=1.5, color='red', linestyles='--')

# %% [markdown]
# A través de la grafica se deduce que los carros automaticos son los que más emiten CO2 a comparación con los de transmisión  manual.

# %%
sns.boxplot(x='Fuel Type', y='CO2 Emissions(g/km)', data=df)
plt.hlines(mean_Co2_emission, xmin=-0.5, xmax=4.5, color='red', linestyles='--')

# %% [markdown]
# Segun el diagrama el tipo de combustible que más emisión de CO2 genera es `E=Etanol`

# %%
sns.countplot(x='Automatic / Manual', data=df)
# Out:
# <AxesSubplot:xlabel='Automatic / Manual', ylabel='count'>

# %% [markdown]
# Lo dicho de que los automoviles automaticos generan mas CO2 es porque hay mucha más cantidad de ellas en el `DataFrame` que los manuales.

# %%
sns.barplot(x='CO2 Emissions(g/km)', y='Make', data=df, order=df.groupby(['Make']).mean()['CO2 Emissions(g/km)'].sort_values(ascending=True).index)
# Out:
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Make'>

# %%
# Ordering alphabetical the brands
df = df.sort_values('Make').reset_index()
df.drop(columns='index', inplace=True)
df
# Out:
#        Make                   Model Vehicle Class Engine Size(L)  Cylinders  \
# 0     acura                     ilx       compact            2.0        4.0
# 1     acura                     tlx       compact            2.4        4.0
# 2     acura              tlx sh-awd       compact            3.5        6.0
# 3     acura                     ilx       compact            2.4        4.0
# 4     acura              mdx sh-awd   suv - small            3.5        6.0
# ...     ...                     ...           ...            ...        ...
# 5975  volvo              s60 t5 awd       compact            2.5        5.0
# 5976  volvo                  s60 t5       compact            2.0        4.0
# 5977  volvo  s60 inscription t5 awd       compact            2.5        5.0
# 5978  volvo                 xc60 t5   suv - small            2.0        4.0
# 5979  volvo                 xc60 t5   suv - small            2.0        4.0
#
# ...

# %%
# Brands ordered alphabetical
sorted_brands = df['Make'].unique()
sorted_brands.sort()

# Empty DataFrame
DF = pd.DataFrame()

# For each brand, ordering from smallest to largest CO2 EMISSION
for mark in sorted_brands:
    DF = pd.concat([DF, df[df['Make']==mark].sort_values('CO2 Emissions(g/km)')])

# %%
DF = DF.reset_index()
DF.drop(columns='index', inplace=True)

# %%
DF
# Out:
#        Make          Model   Vehicle Class Engine Size(L)  Cylinders  \
# 0     acura     ilx hybrid         compact            1.5        4.0
# 1     acura     ilx hybrid         compact            1.5        4.0
# 2     acura     rlx hybrid        mid-size            3.5        6.0
# 3     acura     rlx hybrid        mid-size            3.5        6.0
# 4     acura            ilx         compact            2.4        4.0
# ...     ...            ...             ...            ...        ...
# 5975  volvo       xc70 awd     suv - small            3.0        6.0
# 5976  volvo    xc70 t6 awd     suv - small            3.0        6.0
# 5977  volvo    xc60 t6 awd     suv - small            3.0        6.0
# 5978  volvo  xc60 3.0t awd     suv - small            3.0        6.0
# 5979  volvo       xc90 awd  suv - standard            3.2        6.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             av7         Z                               6.0
# ...

# %%
DF.to_csv('CO2_cars.csv', index=False)

# %%
pd.read_csv('CO2_cars.csv')
# Out:
#        Make          Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     acura     ilx hybrid         compact             1.5        4.0
# 1     acura     ilx hybrid         compact             1.5        4.0
# 2     acura     rlx hybrid        mid-size             3.5        6.0
# 3     acura     rlx hybrid        mid-size             3.5        6.0
# 4     acura            ilx         compact             2.4        4.0
# ...     ...            ...             ...             ...        ...
# 5975  volvo       xc70 awd     suv - small             3.0        6.0
# 5976  volvo    xc70 t6 awd     suv - small             3.0        6.0
# 5977  volvo    xc60 t6 awd     suv - small             3.0        6.0
# 5978  volvo  xc60 3.0t awd     suv - small             3.0        6.0
# 5979  volvo       xc90 awd  suv - standard             3.2        6.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             av7         Z                               6.0
# ...

# %% [markdown]
# # Ejercicio II: utilice este gran conjunto de datos históricos sobre los Juegos Olímpicos modernos, incluidos todos los Juegos desde Atenas 1896 hasta Río 2016.

# %%
url = "https://raw.githubusercontent.com/mhemmg/datasets/master/sport/athlete_events.csv"

# %%
df_sports = pd.read_csv(url)

# %%
df_sports
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Information about this dataset
df_sports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# Statistics of the dataset
df_sports.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# The youngest athlete in the Olympic Games
df_sports[df_sports['Age']==min(df_sports['Age'])]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
# The oldest athlete in the Olympic Games
df_sports[df_sports['Age']==max(df_sports['Age'])]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
# The smallest athletes in the Olympic Games
df_sports[df_sports['Height']==min(df_sports['Height'])]
# Out:
#            ID                   Name Sex   Age  Height  Weight    Team  NOC  \
# 29333   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 29334   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 29335   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 29336   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 29337   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 29338   15150        Rosario Briones   F  15.0   127.0    42.0  Mexico  MEX
# 164821  82769  Lyton Levison Mphande   M  25.0   127.0    62.0  Malawi  MAW
#
#               Games  Year  Season         City       Sport  \
# 29333   1968 Summer  1968  Summer  Mexico City  Gymnastics
# 29334   1968 Summer  1968  Summer  Mexico City  Gymnastics
# 29335   1968 Summer  1968  Summer  Mexico City  Gymnastics
# 29336   1968 Summer  1968  Summer  Mexico City  Gymnastics
# 29337   1968 Summer  1968  Summer  Mexico City  Gymnastics
# ...

# %%
# The tallest athlete in the Olympic Games
df_sports[df_sports['Height']==max(df_sports['Height'])]
# Out:
#             ID      Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 265040  132627  Yao Ming   M  20.0   226.0   141.0  China  CHN  2000 Summer
# 265041  132627  Yao Ming   M  23.0   226.0   141.0  China  CHN  2004 Summer
# 265042  132627  Yao Ming   M  27.0   226.0   141.0  China  CHN  2008 Summer
#
#         Year  Season     City       Sport                        Event Medal
# 265040  2000  Summer   Sydney  Basketball  Basketball Men's Basketball   NaN
# 265041  2004  Summer   Athina  Basketball  Basketball Men's Basketball   NaN
# 265042  2008  Summer  Beijing  Basketball  Basketball Men's Basketball   NaN

# %%
df_sports[(df_sports['Team']=='Colombia') & (df_sports['Medal']=='Gold')]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 69147    35261  scar Albeyro Figueroa Mosquera   M  33.0   159.0    62.0
# 101862   51514            Caterine Ibargn Mena   F  32.0   185.0    70.0
# 180331   90631             Mariana Pajn Londoo   F  20.0   158.0    50.0
# 180332   90631             Mariana Pajn Londoo   F  24.0   158.0    50.0
# 246669  123513        Mara Isabel Urrutia Ocor   F  35.0   170.0    78.0
#
#             Team  NOC        Games  Year  Season            City  \
# 69147   Colombia  COL  2016 Summer  2016  Summer  Rio de Janeiro
# 101862  Colombia  COL  2016 Summer  2016  Summer  Rio de Janeiro
# 180331  Colombia  COL  2012 Summer  2012  Summer          London
# 180332  Colombia  COL  2016 Summer  2016  Summer  Rio de Janeiro
# 246669  Colombia  COL  2000 Summer  2000  Summer          Sydney
#
#                 Sport                              Event Medal
# 69147   Weightlifting  Weightlifting Men's Featherweight  Gold
# ...

# %% [markdown]
# ## 1. Mirando un deporte particular: remo - rowing, ver si la edad de las medallistas de oro femeninas está aumentando o disminuyendo a través de los tiempos. Realize un plot para muestrar la tendencia (si hay una)

# %%
df_sports['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
# Female winning-gold athletes in Remo-rowing
df_remo_f = df_sports[(df_sports['Sport']=='Rowing') & (df_sports['Sex']=='F') & (df_sports['Medal']=='Gold')]
df_remo_f
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 2577      1443             Brigitte Ahrenholz   F  23.0   178.0    85.0
# 4380      2495     Larisa Aleksandrova-Popova   F  23.0   180.0    83.0
# 8547      4701  Chira Irina Apostol (-Stoian)   F  24.0   180.0    78.0
# 8879      4876             Rodica Arba-Pucatu   F  22.0   179.0    75.0
# 8880      4876             Rodica Arba-Pucatu   F  26.0   179.0    75.0
# ...        ...                            ...  ..   ...     ...     ...
# 266039  133101              Zdravka Yordanova   F  25.0   168.0    62.0
# 268301  134246     Judith Zeidler (-Ungemach)   F  21.0   182.0    81.0
# 269002  134592                 Zhang Yangyang   F  19.0   185.0    80.0
# 270207  135178    Roswietha Zobelt (Reichel-)   F  21.0   188.0    83.0
# 270208  135178    Roswietha Zobelt (Reichel-)   F  25.0   188.0    83.0
#
#                 Team  NOC        Games  Year  Season         City   Sport  \
# ...

# %%
df_remo_f.plot(x='Year', y='Age', kind='scatter', c='green')
plt.show()

# %%
sns.regplot(data=df_remo_f, x="Year", y="Age", color='green')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Age'>

# %% [markdown]
# Se observa que para las mujeres ganadoras de medallas de oro en el deporte `Rowing` hay una tendencia minima a ser mayores en edad a medida que pasa el tiempo. Pues para el año `1986` se observa que hay ganadoras de oro menores a los `20 años` y no mayores de `25 años` mientras que para el año `2016` las ganadoras de oro superan la edad de `21 años` hasta llegar a los `33 años`.

# %%
df_sports
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
Gold_medals = df_sports[df_sports['Medal']=='Gold'].groupby(['Team']).count()['Medal'].sort_values()

# %%
Gold_medals
# Out:
# Team
# Belgium-1           1
# Femur-1             1
# Fantlet-7           1
# Bonaparte           1
# Syria               1
#                  ...
# Great Britain     519
# Italy             535
# Germany           679
# Soviet Union     1058
# United States    2474
# Name: Medal, Length: 242, dtype: int64

# %%
plt.scatter(Gold_medals.index, Gold_medals.values)

# %%
# The country with more Gold medals of the world
Gold_medals[Gold_medals.values == Gold_medals.max()]
# Out:
# Team
# United States    2474
# Name: Medal, dtype: int64

# %%
df_sports
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Dataframe without NaN values in the Medal column
olympic_medals = df_sports[df_sports['Medal'].notna()]

# %%
olympic_medals
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
olympic_medals.groupby('Sex').count()
# Out:
#         ID   Name    Age  Height  Weight   Team    NOC  Games   Year  Season  \
# Sex
# F    11253  11253  11236   10478   10352  11253  11253  11253  11253   11253
# M    28530  28530  27815   20594   20104  28530  28530  28530  28530   28530
#
#       City  Sport  Event  Medal
# Sex
# F    11253  11253  11253  11253
# M    28530  28530  28530  28530

# %% [markdown]
# Se observa a través del conjunto de datos que de los `39783` medallas olimpicas obtenidas `11253` pertenecen a las mujeres y `28530` a los hombres.

# %%
# Number of Medals for genre (Male or Female) for country
olympic_medals.groupby(['Team', 'Sex']).count()['Medal'].sort_values()
# Out:
# Team           Sex
# Iran           F         1
# Nadine         M         1
# Sudan          M         1
# Carabinier-15  M         1
# Sunrise        F         1
#                       ...
# Germany        M      1327
# France         M      1329
# United States  F      1756
# Soviet Union   M      1784
# United States  M      3463
# Name: Medal, Length: 643, dtype: int64
