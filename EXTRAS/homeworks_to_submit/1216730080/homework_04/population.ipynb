# %%
# %pylab inline
import re
from bs4 import BeautifulSoup
import requests
import keyboard
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def population(url='https://countrymeters.info/en/World', τ=10):
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'html.parser')
    #tag = soup.select("td.counter div#cp1")
    tag = soup.find('div', id='cp1').text
    tag = int(tag.replace(',',''))
    return tag

# %%
pop = []
for i in range(0,10):
    a = population()
    print(a)
    pop.append(a)
# Out:
# 8010181263
# 8010181269
# 8010181275
# 8010181281
# 8010181288
# 8010181294
# 8010181300
# 8010181310
# 8010181316
# 8010181322

# %%
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
# %matplotlib notebook
  
x = []
y = []
  
figure, ax = plt.subplots()
  
# Setting limits for x and y axis
ax.set_xlim(0, 100)
ax.set_ylim(0, 12)
  
# Since plotting a single graph
line,  = ax.plot(0, 0) 
  
def animation_function(i):
    x.append(i * 15)
    y.append(i)
  
    line.set_xdata(x)
    line.set_ydata(y)
    return line,
  
animation = FuncAnimation(figure,
                          func = animation_function,
                          frames = np.arange(0, 10, 0.1), 
                          interval = 10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Traceback (most recent call last):
#   File "/home/joshep/.local/lib/python3.5/site-packages/matplotlib/cbook/__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "/home/joshep/.local/lib/python3.5/site-packages/matplotlib/animation.py", line 1478, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
plt.plot([1,2,3],[1,2,3],'ro--')
