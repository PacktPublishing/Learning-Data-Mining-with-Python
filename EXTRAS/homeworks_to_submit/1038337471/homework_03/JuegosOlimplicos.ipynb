# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# 1. Mirando un deporte particular: remo - rowing, ver si la edad de las medallistas de oro femeninas está aumentando o disminuyendo a través de los tiempos. Realize un plot para muestrar la tendencia (si hay una)

# %%
df_athlete=pd.read_csv("athlete_events.csv")

# %%
df_athlete
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#df_athlete['Event'].unique()

# %%
df=df_athlete[(df_athlete['Sex']=="F")] # Extraemos a las mujeres
df
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 4            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5             Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
df=df[(df['Medal']=="Gold")] # Filtramos solo las que tienen medalla de oro
df
# Out:
#             ID                                       Name Sex   Age  Height  \
# 79          21                  Ragnhild Margrethe Aamodt   F  27.0   163.0
# 283        150              Margaret Ives Abbott (-Dunne)   F  23.0     NaN
# 1494       832                      Nicola Virginia Adams   F  29.0   164.0
# 1495       832                      Nicola Virginia Adams   F  33.0   164.0
# 1527       846       Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0
# ...        ...                                        ...  ..   ...     ...
# 270588  135331                 Olha Valentynivna Zubareva   F  22.0   182.0
# 270934  135488               Nataliya Vladimirovna Zuyeva   F  19.0   176.0
# 270970  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  39.0   183.0
# 271009  135520                                Julia Zwehl   F  28.0   167.0
# 271076  135553        Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0
#
# ...

# %%
#df = df[df['Event'].str.contains(r"\bRowing\b", regex=True)]
#df # Filtramos todos los deportes femeninos que coinciden con la palabra Rowing
df=df[(df['Sport']=="Rowing")] # Filtramos solo las que tienen medalla de oro
df
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 2577      1443             Brigitte Ahrenholz   F  23.0   178.0    85.0
# 4380      2495     Larisa Aleksandrova-Popova   F  23.0   180.0    83.0
# 8547      4701  Chira Irina Apostol (-Stoian)   F  24.0   180.0    78.0
# 8879      4876             Rodica Arba-Pucatu   F  22.0   179.0    75.0
# 8880      4876             Rodica Arba-Pucatu   F  26.0   179.0    75.0
# ...        ...                            ...  ..   ...     ...     ...
# 266039  133101              Zdravka Yordanova   F  25.0   168.0    62.0
# 268301  134246     Judith Zeidler (-Ungemach)   F  21.0   182.0    81.0
# 269002  134592                 Zhang Yangyang   F  19.0   185.0    80.0
# 270207  135178    Roswietha Zobelt (Reichel-)   F  21.0   188.0    83.0
# 270208  135178    Roswietha Zobelt (Reichel-)   F  25.0   188.0    83.0
#
#                 Team  NOC        Games  Year  Season         City   Sport  \
# ...

# %%
sns.scatterplot(data=df, x='Year',y='Age')

# %% [markdown]
# La edad de las medallistas que ganan oro aumenta en el tiempo

# %% [markdown]
# 2. Sea creativo y extrae algunas informaciones interesantes de este conjunto.

# %%
df['City'].value_counts()
# Out:
# Moskva            25
# Montreal          24
# Los Angeles       24
# Seoul             23
# Barcelona         22
# Rio de Janeiro    20
# London            20
# Atlanta           20
# Sydney            20
# Athina            20
# Beijing           20
# Name: City, dtype: int64

# %% [markdown]
# La mayor cantidad de medallas las tiene la ciudad de Moskva

# %%
df['Age'].value_counts()
# Out:
# 24.0    28
# 28.0    22
# 23.0    21
# 22.0    19
# 26.0    19
# 25.0    18
# 21.0    18
# 29.0    15
# 27.0    14
# 30.0    12
# 32.0    10
# 19.0    10
# 20.0     7
# 31.0     7
# 33.0     4
# 34.0     3
# 35.0     3
# 36.0     2
# 18.0     2
# 40.0     1
# 17.0     1
# 39.0     1
# 38.0     1
# Name: Age, dtype: int64

# %%
df['Age'].max() #Deportista mas vieja
# Out:
# 40.0

# %%
df['Age'].min() #Deportista mas joven
# Out:
# 17.0

# %%
df[df['Age']==40.0] # Informacion de la deportista mas vieja
# Out:
#           ID                     Name Sex   Age  Height  Weight     Team  NOC  \
# 77947  39581  Elena Georgescu-Nedelcu   F  40.0   160.0    55.0  Romania  ROU
#
#              Games  Year  Season    City   Sport                        Event  \
# 77947  2004 Summer  2004  Summer  Athina  Rowing  Rowing Women's Coxed Eights
#
#       Medal
# 77947  Gold

# %%
df[df['Age']==17.0] # Informacion de la deportista mas joven
# Out:
#           ID                   Name Sex   Age  Height  Weight          Team  \
# 95260  48244  Sabine He (-Schubert)   F  17.0   150.0    43.0  East Germany
#
#        NOC        Games  Year  Season      City   Sport  \
# 95260  GDR  1976 Summer  1976  Summer  Montreal  Rowing
#
#                             Event Medal
# 95260  Rowing Women's Coxed Fours  Gold

# %% [markdown]
# la mayor cantidad de deportistas que han obtenido medallas las han ganado a la edad de 24 años, la deportista mas joven que ha obtenido medalla tenia 17 años, se llama Sabine y era de Alemania y la mujer de más edad que ha ganado medalla tenia 40 años, se llamaba Elena y es de Romania.
